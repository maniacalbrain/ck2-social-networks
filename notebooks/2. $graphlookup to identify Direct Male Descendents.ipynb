# %% [markdown]
# # Direct Male Descent

# %% [markdown]
# The following code was the first I wrote after extracting the character data from the save file and before adding the arrays in cell 3 of the first script and using that to get descent through both male and female descendents. Because "fat" is used in the connectToField of the $graphLoopup it will get all of Charlemagne's children but will only get grandchildren where there father is one of Charlemagne's children. In script 3, using the "parents" or "rparents" array instead solves this.

# %%
from pymongo import MongoClient
import pandas as pd
import datetime

# %%
client = MongoClient()
characters = client.ck2.characters

# %% [markdown]
# ## Direct Descendents of Charlemagne

# %%
pipeline = [{
    "$match" : { "_id" : 6392} #Charlemagne
},
    {
    
      "$graphLookup": {
      "from": "characters",
      "startWith": "$_id",
      "connectFromField": "_id",
      "connectToField": "fat",
      "as": "descendent"
   }},
    {
        "$project" : { "bn" : 1, "descendents" : {"$size" : "$descendent"} }
    }
]

# %%
karl = characters.aggregate(pipeline)

# %%
for char in karl:
    print(char)
# Out:
# {'_id': 6392, 'bn': 'Charles', 'descendents': 430}

# %% [markdown]
# ## Direct Descendents Within 2 Generations

# %%
pipeline = [
    {
        "$match" : { "_id" : 6392}
    },
    {
        "$graphLookup": 
        {
            "from": "characters",
            "startWith": "$_id",
            "connectFromField": "_id",
            "connectToField": "fat",
            "as": "descendent",
            "maxDepth": 1,
            "depthField": "generation"
        }
    },
    {"$unwind" : "$descendent" },
    {"$sort" : {"descendent.b_d" : 1}}
]

# %%
karl = characters.aggregate(pipeline)

# %%
for char in karl:
    print(char)
    print("\n\n")
# Out:
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 194169, 'bn': 'Amaudru', 'hist': 1, 'fem': 1, 'b_d': datetime.datetime(767, 1, 1, 0, 0), 'd_d': datetime.datetime(821, 7, 18, 0, 0), 'c_d': 'death_trait', 'lge': 527132, 'fat': 6392, 'mot': 194168, 'dnt': 25061, 'spouse': [190229], 'parents': [6392, 194168], 'rparents': [6392, 194168], 'generation': 0}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 90094, 'bn': 'Pepin', 'hist': 1, 'b_d': datetime.datetime(769, 1, 1, 0, 0), 'd_d': datetime.datetime(795, 11, 19, 0, 0), 'c_d': 'death_trait', 'lge': 511930, 'fat': 6392, 'mot': 194168, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [511930], 'parents': [6392, 194168], 'rparents': [6392, 194168], 'generation': 0}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 508678, 'bn': 'Martinga', 'fem': 1, 'b_d': datetime.datetime(771, 3, 9, 0, 0), 'd_d': datetime.datetime(817, 9, 3, 0, 0), 'c_d': 'death_trait', 'lge': 510339, 'fat': 6392, 'mot': 190352, 'cul': 'lombard', 'dnt': 25061, 'spouse': [510377], 'parents': [6392, 190352], 'rparents': [6392, 190352], 'generation': 0}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 510022, 'bn': 'Ceslin', 'b_d': datetime.datetime(773, 1, 25, 0, 0), 'd_d': datetime.datetime(809, 6, 11, 0, 0), 'c_d': 'death_battle', 'killer': 530445, 'fat': 6392, 'mot': 509092, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [527728], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 510783, 'bn': 'Bertrada', 'fem': 1, 'b_d': datetime.datetime(774, 2, 25, 0, 0), 'd_d': datetime.datetime(840, 9, 8, 0, 0), 'c_d': 'death_trait', 'lge': 520610, 'fat': 6392, 'mot': 509092, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [520610], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 514936, 'bn': 'Grimald', 'nick': 'nick_the_holy', 'b_d': datetime.datetime(780, 9, 25, 0, 0), 'd_d': datetime.datetime(832, 2, 1, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 525936, 'fat': 6392, 'mot': 509092, 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [514586], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 516515, 'bn': 'Burchard', 'nick': 'nick_the_depraved', 'b_d': datetime.datetime(783, 7, 25, 0, 0), 'd_d': datetime.datetime(822, 9, 30, 0, 0), 'c_d': 'death_battle', 'killer': 540797, 'fat': 6392, 'mot': 509092, 'dnt': 25061, 'spouse': [522709, 540112], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 517169, 'bn': 'Theodelinda', 'fem': 1, 'b_d': datetime.datetime(784, 10, 25, 0, 0), 'd_d': datetime.datetime(848, 8, 10, 0, 0), 'c_d': 'death_trait', 'lge': 534463, 'fat': 6392, 'mot': 509092, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [520402], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 522094, 'bn': 'Heilwiva', 'fem': 1, 'b_d': datetime.datetime(793, 5, 29, 0, 0), 'd_d': datetime.datetime(835, 6, 7, 0, 0), 'c_d': 'death_trait', 'lge': 528981, 'fat': 90094, 'rfat': 190512, 'mot': 511930, 'cul': 'old_frankish', 'dnt': 1044033, 'spouse': [521793, 528981], 'parents': [90094, 511930], 'rparents': [190512, 511930], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 523304, 'bn': 'Elisabeth', 'fem': 1, 'b_d': datetime.datetime(795, 4, 25, 0, 0), 'd_d': datetime.datetime(795, 6, 1, 0, 0), 'c_d': 'death_trait', 'lge': 6392, 'fat': 6392, 'mot': 509092, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 525158, 'bn': 'Aude', 'fem': 1, 'b_d': datetime.datetime(798, 1, 17, 0, 0), 'd_d': datetime.datetime(865, 8, 19, 0, 0), 'lge': 539938, 'fat': 6392, 'rfat': 512975, 'mot': 524280, 'cul': 'frankish', 'dnt': 25061, 'spouse': [523815], 'parents': [6392, 524280], 'rparents': [512975, 524280], 'generation': 0}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 528641, 'bn': 'Charles', 'nick': 'nick_the_monster', 'b_d': datetime.datetime(803, 2, 3, 0, 0), 'd_d': datetime.datetime(853, 11, 26, 0, 0), 'c_d': 'death_battle', 'killer': 554473, 'fat': 514936, 'mot': 514586, 'cul': 'italian', 'dnt': 25061, 'spouse': [517583, 540756], 'parents': [514936, 514586], 'rparents': [514936, 514586], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 528813, 'bn': 'Eleonora', 'fem': 1, 'b_d': datetime.datetime(803, 5, 13, 0, 0), 'd_d': datetime.datetime(871, 12, 6, 0, 0), 'c_d': 'death_trait', 'lge': 541095, 'fat': 510022, 'mot': 527728, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [527805], 'parents': [510022, 527728], 'rparents': [510022, 527728], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 529737, 'bn': 'Karel', 'nick': 'nick_the_drunkard', 'b_d': datetime.datetime(804, 9, 3, 0, 0), 'd_d': datetime.datetime(864, 4, 6, 0, 0), 'fat': 514936, 'mot': 514586, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [527032, 555847], 'parents': [514936, 514586], 'rparents': [514936, 514586], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 531797, 'bn': 'Gyrið', 'fem': 1, 'b_d': datetime.datetime(807, 10, 3, 0, 0), 'd_d': datetime.datetime(875, 6, 22, 0, 0), 'lge': 560064, 'fat': 514936, 'mot': 514586, 'cul': 'italian', 'dnt': 25061, 'spouse': [532697], 'parents': [514936, 514586], 'rparents': [514936, 514586], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 533280, 'bn': 'Ceslin', 'b_d': datetime.datetime(809, 11, 13, 0, 0), 'd_d': datetime.datetime(843, 4, 11, 0, 0), 'c_d': 'death_murder', 'killer': 514586, 'fat': 510022, 'mot': 527728, 'cul': 'frankish', 'dnt': 25061, 'spouse': [533489], 'parents': [510022, 527728], 'rparents': [510022, 527728], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 534136, 'bn': 'Engilbert', 'b_d': datetime.datetime(811, 3, 6, 0, 0), 'd_d': datetime.datetime(811, 5, 9, 0, 0), 'c_d': 'death_trait', 'lge': 516515, 'fat': 516515, 'mot': 522709, 'cul': 'saxon', 'dnt': 25061, 'parents': [516515, 522709], 'rparents': [516515, 522709], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 535802, 'bn': 'Morberga', 'fem': 1, 'b_d': datetime.datetime(813, 7, 20, 0, 0), 'd_d': datetime.datetime(859, 6, 23, 0, 0), 'c_d': 'death_trait', 'lge': 560227, 'fat': 514936, 'mot': 525273, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [535219], 'parents': [514936, 525273], 'rparents': [514936, 525273], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 541336, 'bn': 'Goiswinth', 'fem': 1, 'b_d': datetime.datetime(822, 3, 2, 0, 0), 'd_d': datetime.datetime(843, 9, 13, 0, 0), 'c_d': 'death_childbirth', 'lge': 539205, 'fat': 514936, 'mot': 527032, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [539205], 'parents': [514936, 527032], 'rparents': [514936, 527032], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 541883, 'bn': 'Karl', 'b_d': datetime.datetime(823, 1, 21, 0, 0), 'd_d': datetime.datetime(830, 12, 18, 0, 0), 'c_d': 'death_murder_fall', 'killer': 517095, 'lge': 518940, 'fat': 516515, 'mot': 540112, 'dnt': 25061, 'parents': [516515, 540112], 'rparents': [516515, 540112], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 545819, 'bn': 'Ermengarde', 'fem': 1, 'b_d': datetime.datetime(829, 2, 8, 0, 0), 'd_d': datetime.datetime(880, 4, 16, 0, 0), 'c_d': 'death_trait', 'lge': 556682, 'fat': 514936, 'mot': 537607, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [514936, 537607], 'rparents': [514936, 537607], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 546220, 'bn': 'Eustadiola', 'fem': 1, 'b_d': datetime.datetime(829, 9, 10, 0, 0), 'd_d': datetime.datetime(885, 3, 25, 0, 0), 'lge': 542048, 'fat': 514936, 'mot': 544057, 'dnt': 25061, 'spouse': [544952], 'parents': [514936, 544057], 'rparents': [514936, 544057], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 547004, 'bn': 'Cumman', 'fem': 1, 'b_d': datetime.datetime(830, 11, 11, 0, 0), 'd_d': datetime.datetime(883, 11, 25, 0, 0), 'lge': 558756, 'fat': 514936, 'mot': 522546, 'dnt': 25061, 'spouse': [550312], 'parents': [514936, 522546], 'rparents': [514936, 522546], 'generation': 1}}
#
#
#
# {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'descendent': {'_id': 548212, 'bn': 'Karl', 'b_d': datetime.datetime(832, 8, 25, 0, 0), 'd_d': datetime.datetime(856, 4, 1, 0, 0), 'c_d': 'death_trait', 'lge': 540529, 'fat': 514936, 'mot': 536231, 'cul': 'old_frankish', 'dnt': 10290924, 'parents': [514936, 536231], 'rparents': [514936, 536231], 'generation': 1}}

# %% [markdown]
# ## Total Generations

# %% [markdown]
# In this case depthField adds a field called generation which increments each step it takes from the starting node. Charlemagne's children have a value of 0, his grandchildren have a value of 1 and so on. In this game Charlemagne has a 23 x Great Grandchild.

# %%
pipeline = [
    {
        "$match" : { "_id" : 6392}
    },
    {
        "$graphLookup": 
        {
            "from": "characters",
            "startWith": "$_id",
            "connectFromField": "_id",
            "connectToField": "fat",
            "as": "descendent",
            #"maxDepth": 1,
            "depthField": "generation"
        }
    },
    {"$unwind" : "$descendent" },
    {"$group" : {"_id" : None, "maxGen" : {"$max" : "$descendent.generation"} }}
]

# %%
karl = characters.aggregate(pipeline)

# %%
for char in karl:
    print(char)
    print("\n\n")
# Out:
# {'_id': None, 'maxGen': 25}

# %% [markdown]
# ## Ancestors of a character

# %% [markdown]
# Same calculation above but in reverse. Starting node is Pierre, an 8 x Grandson of Charlemagne. His father is at generation 0 and his lineage can be traced back 17 generations in total to Arnold, born in 557.

# %%
pipeline = [{
    "$match" : { "_id" : 712365} #Pierre, 8 x Great grandson of Charlemagne
},
    {
    
      "$graphLookup": {
      "from": "characters",
      "startWith": "$fat",
      "connectFromField": "fat",
      "connectToField": "_id",
      "as": "ancestor",
      "depthField": "generation"
   }},
    {"$unwind" : "$ancestor"},
    {"$sort" : { "ancestor.generation": -1 }},
    {"$project" : {"_id" : 0, "ancestor" : 1}}
]

# %%
karl = characters.aggregate(pipeline)

# %%
for char in karl:
    print(char)
    print("\n")
# Out:
# {'ancestor': {'_id': 190412, 'bn': 'Arnold', 'hist': 1, 'b_d': datetime.datetime(557, 1, 1, 0, 0), 'd_d': datetime.datetime(602, 1, 1, 0, 0), 'dnt': 25061, 'parents': [None, None], 'rparents': [None, None], 'generation': 16}}
#
#
# {'ancestor': {'_id': 190413, 'bn': 'Arnulf', 'hist': 1, 'b_d': datetime.datetime(580, 1, 1, 0, 0), 'd_d': datetime.datetime(640, 7, 18, 0, 0), 'fat': 190412, 'dnt': 25061, 'parents': [190412, None], 'rparents': [190412, None], 'generation': 15}}
#
#
# {'ancestor': {'_id': 190417, 'bn': 'Ansegisel', 'hist': 1, 'b_d': datetime.datetime(612, 1, 1, 0, 0), 'd_d': datetime.datetime(662, 1, 1, 0, 0), 'fat': 190413, 'dnt': 25061, 'spouse': [91404], 'parents': [190413, None], 'rparents': [190413, None], 'generation': 14}}
#
#
# {'ancestor': {'_id': 131720, 'bn': 'Pepin', 'hist': 1, 'b_d': datetime.datetime(636, 1, 2, 0, 0), 'd_d': datetime.datetime(714, 1, 17, 0, 0), 'fat': 190417, 'mot': 91404, 'dnt': 25061, 'spouse': [190420], 'parents': [190417, 91404], 'rparents': [190417, 91404], 'generation': 13}}
#
#
# {'ancestor': {'_id': 131721, 'bn': 'Karl', 'hist': 1, 'b_d': datetime.datetime(686, 8, 23, 0, 0), 'd_d': datetime.datetime(741, 1, 23, 0, 0), 'fat': 131720, 'mot': 190420, 'dnt': 25061, 'spouse': [190426], 'parents': [131720, 190420], 'rparents': [131720, 190420], 'generation': 12}}
#
#
# {'ancestor': {'_id': 131722, 'bn': 'Pepin', 'hist': 1, 'b_d': datetime.datetime(714, 1, 1, 0, 0), 'd_d': datetime.datetime(768, 9, 24, 0, 0), 'fat': 131721, 'mot': 190425, 'dnt': 25061, 'spouse': [190429], 'parents': [131721, 190425], 'rparents': [131721, 190425], 'generation': 11}}
#
#
# {'ancestor': {'_id': 6392, 'bn': 'Charles', 'hist': 1, 'b_d': datetime.datetime(742, 1, 2, 0, 0), 'd_d': datetime.datetime(801, 10, 19, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 190454, 'fat': 131722, 'mot': 190429, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [509092, 524280], 'parents': [131722, 190429], 'rparents': [131722, 190429], 'generation': 10}}
#
#
# {'ancestor': {'_id': 514936, 'bn': 'Grimald', 'nick': 'nick_the_holy', 'b_d': datetime.datetime(780, 9, 25, 0, 0), 'd_d': datetime.datetime(832, 2, 1, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 525936, 'fat': 6392, 'mot': 509092, 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [514586], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 9}}
#
#
# {'ancestor': {'_id': 528641, 'bn': 'Charles', 'nick': 'nick_the_monster', 'b_d': datetime.datetime(803, 2, 3, 0, 0), 'd_d': datetime.datetime(853, 11, 26, 0, 0), 'c_d': 'death_battle', 'killer': 554473, 'fat': 514936, 'mot': 514586, 'cul': 'italian', 'dnt': 25061, 'spouse': [517583, 540756], 'parents': [514936, 514586], 'rparents': [514936, 514586], 'generation': 8}}
#
#
# {'ancestor': {'_id': 562370, 'bn': 'Manassès', 'nick': 'nick_the_great', 'b_d': datetime.datetime(853, 3, 21, 0, 0), 'd_d': datetime.datetime(924, 11, 19, 0, 0), 'fat': 528641, 'mot': 540756, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [572787, 600018, 609278], 'parents': [528641, 540756], 'rparents': [528641, 540756], 'generation': 7}}
#
#
# {'ancestor': {'_id': 577938, 'bn': 'Reinoud', 'b_d': datetime.datetime(875, 10, 20, 0, 0), 'd_d': datetime.datetime(901, 3, 8, 0, 0), 'c_d': 'death_duel', 'killer': 576020, 'lge': 562370, 'fat': 562370, 'mot': 572787, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [569064, 581216], 'parents': [562370, 572787], 'rparents': [562370, 572787], 'generation': 6}}
#
#
# {'ancestor': {'_id': 591244, 'bn': 'Raynaud', 'nick': 'nick_the_tyrant', 'b_d': datetime.datetime(895, 7, 21, 0, 0), 'd_d': datetime.datetime(965, 11, 25, 0, 0), 'c_d': 'death_trait', 'fat': 577938, 'mot': 569064, 'cul': 'khazar', 'dnt': 25061, 'spouse': [594644, 613994], 'parents': [577938, 569064], 'rparents': [577938, 569064], 'generation': 5}}
#
#
# {'ancestor': {'_id': 611878, 'bn': 'Raynaud', 'b_d': datetime.datetime(925, 7, 9, 0, 0), 'd_d': datetime.datetime(957, 6, 23, 0, 0), 'c_d': 'death_poor_health', 'lge': 591244, 'fat': 591244, 'mot': 594644, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [607149, 613895, 618426], 'parents': [591244, 594644], 'rparents': [591244, 594644], 'generation': 4}}
#
#
# {'ancestor': {'_id': 631169, 'bn': 'Raynaud', 'nick': 'nick_the_cruel', 'b_d': datetime.datetime(953, 2, 24, 0, 0), 'd_d': datetime.datetime(996, 2, 22, 0, 0), 'c_d': 'death_trait', 'fat': 611878, 'mot': 613895, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [630756, 654543], 'parents': [611878, 613895], 'rparents': [611878, 613895], 'generation': 3}}
#
#
# {'ancestor': {'_id': 650835, 'bn': 'Arnaud', 'nick': 'nick_the_usurper', 'b_d': datetime.datetime(980, 10, 1, 0, 0), 'd_d': datetime.datetime(1031, 3, 4, 0, 0), 'c_d': 'death_trait', 'fat': 631169, 'mot': 630756, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [650777, 649791, 666051], 'parents': [631169, 630756], 'rparents': [631169, 630756], 'generation': 2}}
#
#
# {'ancestor': {'_id': 681175, 'bn': 'Pierre', 'nick': 'nick_the_holy', 'b_d': datetime.datetime(1015, 2, 16, 0, 0), 'd_d': datetime.datetime(1062, 4, 20, 0, 0), 'c_d': 'death_trait', 'fat': 650835, 'mot': 666051, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [680419, 695650], 'parents': [650835, 666051], 'rparents': [650835, 666051], 'generation': 1}}
#
#
# {'ancestor': {'_id': 694313, 'bn': 'Arnaud', 'nick': 'nick_the_monster', 'b_d': datetime.datetime(1033, 2, 20, 0, 0), 'd_d': datetime.datetime(1072, 7, 26, 0, 0), 'c_d': 'death_trait', 'fat': 681175, 'mot': 680419, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [697208], 'parents': [681175, 680419], 'rparents': [681175, 680419], 'generation': 0}}

# %% [markdown]
# ## All Direct Descendents of Charlemagne

# %%
pipeline = [{
    "$match" : { "_id" : 6392}
},
    {
    
      "$graphLookup": {
      "from": "characters",
      "startWith": "$_id",
      "connectFromField": "_id",
      "connectToField": "fat",
      "as": "descendent",
      "depthField": "generation"
   }},
    {"$unwind" : "$descendent"},
    {"$sort" : { "descendent.b_d": -1 }},
    {"$project" : {"_id" : 0, "descendent" : 1}}
]

# %%
karl = characters.aggregate(pipeline)

# %%
for char in karl:
    print(char)
    print("\n\n")
# Out:
# {'descendent': {'_id': 1045441, 'bn': 'Cúánán', 'b_d': datetime.datetime(1459, 5, 21, 0, 0), 'fat': 1014184, 'mot': 1011996, 'rel': 'catholic', 'cul': 'pictish', 'dnt': 9230, 'emp': 1014184, 'host': 1014184, 'parents': [1014184, 1011996], 'rparents': [1014184, 1011996], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 1043726, 'bn': 'Adalmode', 'fem': 1, 'b_d': datetime.datetime(1457, 6, 5, 0, 0), 'fat': 995217, 'mot': 1041436, 'cul': 'frankish', 'dnt': 25061, 'emp': 995217, 'host': 995217, 'parents': [995217, 1041436], 'rparents': [995217, 1041436], 'generation': 24}}
#
#
#
# {'descendent': {'_id': 1042687, 'bn': 'Alf', 'b_d': datetime.datetime(1456, 2, 19, 0, 0), 'fat': 1017356, 'mot': 1034002, 'cul': 'welsh', 'dnt': 10324999, 'emp': 1017356, 'host': 1017356, 'parents': [1017356, 1034002], 'rparents': [1017356, 1034002], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 1041004, 'bn': 'Halsten', 'b_d': datetime.datetime(1454, 3, 9, 0, 0), 'fat': 1018658, 'mot': 1036484, 'cul': 'welsh', 'dnt': 10325248, 'emp': 1018658, 'host': 1018658, 'parents': [1018658, 1036484], 'rparents': [1018658, 1036484], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 1040399, 'bn': 'Raymonde', 'fem': 1, 'b_d': datetime.datetime(1453, 7, 18, 0, 0), 'fat': 995217, 'mot': 1038481, 'cul': 'frankish', 'dnt': 25061, 'emp': 995217, 'host': 995217, 'parents': [995217, 1038481], 'rparents': [995217, 1038481], 'generation': 24}}
#
#
#
# {'descendent': {'_id': 1039576, 'bn': 'Rikissa', 'fem': 1, 'b_d': datetime.datetime(1452, 7, 19, 0, 0), 'fat': 1017356, 'mot': 1034002, 'cul': 'pictish', 'dnt': 10324999, 'emp': 1017356, 'host': 1014184, 'parents': [1017356, 1034002], 'rparents': [1017356, 1034002], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 1038336, 'bn': 'Olaf', 'b_d': datetime.datetime(1451, 2, 19, 0, 0), 'd_d': datetime.datetime(1453, 5, 13, 0, 0), 'c_d': 'death_trait', 'lge': 1014184, 'fat': 1017356, 'mot': 1034002, 'cul': 'pictish', 'dnt': 10324999, 'parents': [1017356, 1034002], 'rparents': [1017356, 1034002], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 1037501, 'bn': 'Anne', 'fem': 1, 'b_d': datetime.datetime(1450, 1, 27, 0, 0), 'fat': 1017458, 'mot': 1017126, 'cul': 'frankish', 'dnt': 25061, 'bstd': 1, 'emp': 1017458, 'host': 1017458, 'parents': [1017458, 1017126], 'rparents': [1017458, 1017126], 'generation': 24}}
#
#
#
# {'descendent': {'_id': 1037186, 'bn': 'Crístina', 'fem': 1, 'b_d': datetime.datetime(1449, 9, 19, 0, 0), 'fat': 1017356, 'mot': 1034002, 'cul': 'pictish', 'dnt': 10324999, 'emp': 1017356, 'host': 1014184, 'parents': [1017356, 1034002], 'rparents': [1017356, 1034002], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 1036099, 'bn': 'Bertrand', 'b_d': datetime.datetime(1448, 5, 27, 0, 0), 'fat': 1017458, 'mot': 1017126, 'cul': 'frankish', 'dnt': 25061, 'bstd': 1, 'emp': 1017458, 'host': 1017458, 'parents': [1017458, 1017126], 'rparents': [1017458, 1017126], 'generation': 24}}
#
#
#
# {'descendent': {'_id': 1035248, 'bn': 'Ingvar', 'b_d': datetime.datetime(1447, 5, 26, 0, 0), 'fat': 1019304, 'mot': 1005673, 'rel': 'catholic', 'cul': 'pictish', 'dnt': 9230, 'emp': 1019304, 'host': 1014184, 'parents': [1019304, 1005673], 'rparents': [1019304, 1005673], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 1034506, 'bn': 'Asta', 'fem': 1, 'b_d': datetime.datetime(1446, 6, 21, 0, 0), 'fat': 1014184, 'mot': 1011996, 'rel': 'catholic', 'cul': 'swedish', 'dnt': 9230, 'emp': 1014184, 'host': 1014184, 'parents': [1014184, 1011996], 'rparents': [1014184, 1011996], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 1033964, 'bn': 'Berthe', 'fem': 1, 'b_d': datetime.datetime(1445, 11, 2, 0, 0), 'fat': 1017458, 'mot': 1017126, 'cul': 'frankish', 'dnt': 25061, 'bstd': 1, 'emp': 1017458, 'host': 1017458, 'parents': [1017458, 1017126], 'rparents': [1017458, 1017126], 'generation': 24}}
#
#
#
# {'descendent': {'_id': 1033011, 'bn': 'Arnault', 'b_d': datetime.datetime(1444, 9, 15, 0, 0), 'fat': 995217, 'mot': 994378, 'cul': 'frankish', 'dnt': 25061, 'emp': 1045139, 'host': 1010082, 'parents': [995217, 994378], 'rparents': [995217, 994378], 'generation': 24}}
#
#
#
# {'descendent': {'_id': 1031469, 'bn': 'Guillaume', 'b_d': datetime.datetime(1443, 1, 6, 0, 0), 'fat': 985060, 'mot': 1011721, 'cul': 'frankish', 'dnt': 25061, 'bstd': 1, 'emp': 1017458, 'host': 1017458, 'parents': [985060, 1011721], 'rparents': [985060, 1011721], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1029240, 'bn': 'Tiburge', 'fem': 1, 'b_d': datetime.datetime(1440, 6, 12, 0, 0), 'd_d': datetime.datetime(1455, 5, 21, 0, 0), 'c_d': 'death_execution_eaten', 'killer': 1017458, 'lge': 1017458, 'fat': 1002826, 'rfat': 985060, 'mot': 995941, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [1002826, 995941], 'rparents': [985060, 995941], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 1029210, 'bn': 'Guichard', 'b_d': datetime.datetime(1440, 6, 1, 0, 0), 'fat': 1001885, 'mot': 1023652, 'rel': 'catholic', 'cul': 'frankish', 'dnt': 9230, 'emp': 1029210, 'host': 1016162, 'spouse': [1045703], 'parents': [1001885, 1023652], 'rparents': [1001885, 1023652], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 1029129, 'bn': 'Harald', 'b_d': datetime.datetime(1440, 5, 4, 0, 0), 'fat': 994796, 'mot': 1012315, 'rel': 'catholic', 'cul': 'swedish', 'bstd': 1, 'emp': 1014184, 'host': 1014184, 'parents': [994796, 1012315], 'rparents': [994796, 1012315], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1028213, 'bn': 'Linda', 'fem': 1, 'b_d': datetime.datetime(1439, 4, 21, 0, 0), 'fat': 994796, 'mot': 1011996, 'rel': 'catholic', 'cul': 'pictish', 'dnt': 9230, 'bstd': 1, 'emp': 1031565, 'host': 1031565, 'spouse': [1031565], 'parents': [994796, 1011996], 'rparents': [994796, 1011996], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1027638, 'bn': 'Adèle', 'fem': 1, 'b_d': datetime.datetime(1438, 9, 1, 0, 0), 'fat': 1001885, 'mot': 1023652, 'rel': 'catholic', 'cul': 'frankish', 'dnt': 9230, 'emp': 1029210, 'host': 1029210, 'parents': [1001885, 1023652], 'rparents': [1001885, 1023652], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 1025211, 'bn': 'Herbert', 'b_d': datetime.datetime(1436, 1, 6, 0, 0), 'fat': 985060, 'mot': 988349, 'cul': 'frankish', 'dnt': 25061, 'bstd': 1, 'emp': 1025211, 'host': 1025211, 'parents': [985060, 988349], 'rparents': [985060, 988349], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1025080, 'bn': 'Érrard', 'b_d': datetime.datetime(1435, 11, 15, 0, 0), 'fat': 1009318, 'mot': 1008798, 'cul': 'frankish', 'dnt': 25061, 'emp': 1010082, 'host': 1010082, 'parents': [1009318, 1008798], 'rparents': [1009318, 1008798], 'generation': 25}}
#
#
#
# {'descendent': {'_id': 1025069, 'bn': 'Bernard', 'b_d': datetime.datetime(1435, 11, 12, 0, 0), 'fat': 1010082, 'mot': 1000451, 'cul': 'old_frankish', 'dnt': 25061, 'emp': 1010082, 'host': 1010082, 'spouse': [1013205], 'parents': [1010082, 1000451], 'rparents': [1010082, 1000451], 'generation': 25}}
#
#
#
# {'descendent': {'_id': 1022841, 'bn': 'Perinne', 'fem': 1, 'b_d': datetime.datetime(1433, 4, 3, 0, 0), 'fat': 985060, 'mot': 1006546, 'cul': 'frankish', 'dnt': 25061, 'emp': 1035185, 'host': 1035185, 'spouse': [1008646], 'parents': [985060, 1006546], 'rparents': [985060, 1006546], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1021434, 'bn': 'Ingemar', 'b_d': datetime.datetime(1431, 8, 4, 0, 0), 'd_d': datetime.datetime(1455, 12, 23, 0, 0), 'c_d': 'death_trait', 'lge': 1011300, 'fat': 994796, 'mot': 1012315, 'rel': 'catholic', 'cul': 'pictish', 'dnt': 9230, 'parents': [994796, 1012315], 'rparents': [994796, 1012315], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1021195, 'bn': 'Åke', 'b_d': datetime.datetime(1431, 5, 1, 0, 0), 'd_d': datetime.datetime(1450, 4, 16, 0, 0), 'c_d': 'death_battle', 'killer': 1012771, 'lge': 1014184, 'fat': 994796, 'mot': 1008532, 'rel': 'catholic', 'cul': 'pictish', 'dnt': 9230, 'parents': [994796, 1008532], 'rparents': [994796, 1008532], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1019304, 'bn': 'Markus', 'b_d': datetime.datetime(1429, 3, 1, 0, 0), 'fat': 994796, 'mot': 1008532, 'rel': 'catholic', 'cul': 'pictish', 'dnt': 9230, 'emp': 1019304, 'host': 1014184, 'parents': [994796, 1008532], 'rparents': [994796, 1008532], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1018921, 'bn': 'Eve', 'fem': 1, 'b_d': datetime.datetime(1428, 9, 10, 0, 0), 'fat': 1002826, 'mot': 995941, 'cul': 'frankish', 'dnt': 25061, 'emp': 1017458, 'host': 1017458, 'parents': [1002826, 995941], 'rparents': [1002826, 995941], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 1018658, 'bn': 'Sigurd', 'b_d': datetime.datetime(1428, 6, 4, 0, 0), 'fat': 994796, 'mot': 1012315, 'cul': 'pictish', 'dnt': 10325248, 'bstd': 1, 'emp': 1018658, 'host': 1014184, 'parents': [994796, 1012315], 'rparents': [994796, 1012315], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1017458, 'bn': 'Aldéric', 'nick': 'nick_the_just', 'b_d': datetime.datetime(1427, 2, 10, 0, 0), 'fat': 1002826, 'mot': 995941, 'cul': 'frankish', 'dnt': 25061, 'emp': 1017458, 'host': 995217, 'spouse': [994242], 'parents': [1002826, 995941], 'rparents': [1002826, 995941], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 1017356, 'bn': 'Torsten', 'b_d': datetime.datetime(1427, 1, 4, 0, 0), 'fat': 994796, 'mot': 1012315, 'cul': 'pictish', 'dnt': 10324999, 'bstd': 1, 'emp': 1017356, 'host': 1014184, 'parents': [994796, 1012315], 'rparents': [994796, 1012315], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1015214, 'bn': 'Roubaud', 'b_d': datetime.datetime(1424, 7, 13, 0, 0), 'fat': 995216, 'mot': 995272, 'cul': 'frankish', 'dnt': 25061, 'emp': 1011300, 'host': 1011300, 'parents': [995216, 995272], 'rparents': [995216, 995272], 'generation': 24}}
#
#
#
# {'descendent': {'_id': 1014184, 'bn': 'Grim', 'nick': 'nick_the_drunkard', 'b_d': datetime.datetime(1423, 5, 1, 0, 0), 'fat': 994796, 'mot': 1008532, 'rel': 'catholic', 'cul': 'pictish', 'dnt': 9230, 'emp': 1014184, 'host': 1014184, 'spouse': [1011996], 'parents': [994796, 1008532], 'rparents': [994796, 1008532], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1014141, 'bn': 'Emma', 'fem': 1, 'b_d': datetime.datetime(1423, 4, 13, 0, 0), 'fat': 995216, 'mot': 995272, 'cul': 'frankish', 'dnt': 25061, 'emp': 1010082, 'host': 1010082, 'parents': [995216, 995272], 'rparents': [995216, 995272], 'generation': 24}}
#
#
#
# {'descendent': {'_id': 1013500, 'bn': 'Bourguigne', 'fem': 1, 'b_d': datetime.datetime(1422, 6, 15, 0, 0), 'fat': 995217, 'mot': 994378, 'cul': 'mongol', 'dnt': 25061, 'emp': 1010082, 'host': 1010082, 'parents': [995217, 994378], 'rparents': [995217, 994378], 'generation': 24}}
#
#
#
# {'descendent': {'_id': 1013087, 'bn': 'Holmfrid', 'fem': 1, 'b_d': datetime.datetime(1421, 12, 15, 0, 0), 'fat': 994796, 'mot': 1012315, 'rel': 'catholic', 'cul': 'swedish', 'dnt': 9230, 'bstd': 1, 'emp': 1015617, 'host': 1015617, 'spouse': [1024206], 'parents': [994796, 1012315], 'rparents': [994796, 1012315], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1010082, 'bn': 'Aldéric', 'nick': 'nick_the_drunkard', 'b_d': datetime.datetime(1418, 7, 14, 0, 0), 'fat': 993555, 'mot': 990905, 'cul': 'old_frankish', 'dnt': 25061, 'emp': 1010082, 'host': 1459, 'spouse': [1000451], 'parents': [993555, 990905], 'rparents': [993555, 990905], 'generation': 24}}
#
#
#
# {'descendent': {'_id': 1009318, 'bn': 'Thiébaut', 'b_d': datetime.datetime(1417, 9, 13, 0, 0), 'd_d': datetime.datetime(1459, 5, 3, 0, 0), 'c_d': 'death_trait', 'lge': 995216, 'fat': 995216, 'mot': 995272, 'cul': 'frankish', 'dnt': 25061, 'parents': [995216, 995272], 'rparents': [995216, 995272], 'generation': 24}}
#
#
#
# {'descendent': {'_id': 1006653, 'bn': 'Mathilde', 'fem': 1, 'b_d': datetime.datetime(1414, 7, 8, 0, 0), 'fat': 967392, 'mot': 979139, 'cul': 'frankish', 'dnt': 25061, 'emp': 1017458, 'host': 1017458, 'parents': [967392, 979139], 'rparents': [967392, 979139], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1003957, 'bn': 'Conchenn', 'fem': 1, 'b_d': datetime.datetime(1411, 4, 26, 0, 0), 'fat': 959150, 'mot': 996601, 'rel': 'catholic', 'cul': 'frankish', 'dnt': 9230, 'emp': 1029210, 'host': 1029210, 'parents': [959150, 996601], 'rparents': [959150, 996601], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 1002826, 'bn': 'Louis', 'nick': 'nick_the_chaste', 'b_d': datetime.datetime(1410, 1, 8, 0, 0), 'd_d': datetime.datetime(1443, 7, 7, 0, 0), 'c_d': 'death_trait', 'lge': 985060, 'fat': 967392, 'mot': 979139, 'cul': 'frankish', 'dnt': 25061, 'spouse': [995941], 'parents': [967392, 979139], 'rparents': [967392, 979139], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 1001885, 'bn': 'Torccán', 'b_d': datetime.datetime(1408, 10, 26, 0, 0), 'd_d': datetime.datetime(1459, 8, 18, 0, 0), 'lge': 1016162, 'fat': 959150, 'mot': 996601, 'rel': 'catholic', 'cul': 'frankish', 'dnt': 9230, 'spouse': [1023652], 'parents': [959150, 996601], 'rparents': [959150, 996601], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 999887, 'bn': 'Valeran', 'b_d': datetime.datetime(1406, 6, 7, 0, 0), 'fat': 972057, 'mot': 972782, 'cul': 'old_frankish', 'dnt': 25061, 'emp': 1042815, 'host': 1042815, 'parents': [972057, 972782], 'rparents': [972057, 972782], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 998751, 'bn': 'Guillaumette', 'fem': 1, 'b_d': datetime.datetime(1405, 1, 8, 0, 0), 'fat': 967392, 'mot': 979139, 'rel': 'shiite', 'cul': 'frankish', 'dnt': 25061, 'emp': 1015617, 'host': 1015617, 'spouse': [1017124, 999904], 'parents': [967392, 979139], 'rparents': [967392, 979139], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 997148, 'bn': 'Edla', 'fem': 1, 'b_d': datetime.datetime(1403, 2, 6, 0, 0), 'fat': 979011, 'mot': 969281, 'rel': 'catholic', 'cul': 'frankish', 'dnt': 9230, 'emp': 1016589, 'host': 1016589, 'spouse': [1013085], 'parents': [979011, 969281], 'rparents': [979011, 969281], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 995217, 'bn': 'Géraud', 'b_d': datetime.datetime(1400, 10, 4, 0, 0), 'fat': 970238, 'mot': 968635, 'cul': 'frankish', 'dnt': 25061, 'emp': 995217, 'host': 1010082, 'spouse': [1041436, 1038481], 'parents': [970238, 968635], 'rparents': [970238, 968635], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 995216, 'bn': 'Francés', 'nick': 'nick_the_evil', 'b_d': datetime.datetime(1400, 10, 4, 0, 0), 'fat': 970238, 'mot': 968635, 'cul': 'frankish', 'dnt': 25061, 'emp': 995216, 'host': 995216, 'parents': [970238, 968635], 'rparents': [970238, 968635], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 994796, 'bn': 'Åke', 'nick': 'nick_the_monster', 'b_d': datetime.datetime(1400, 4, 6, 0, 0), 'd_d': datetime.datetime(1439, 8, 13, 0, 0), 'c_d': 'death_poor_health', 'fat': 979011, 'mot': 969281, 'rel': 'catholic', 'cul': 'pictish', 'dnt': 9230, 'spawned_bastards': 1, 'spouse': [1008532], 'parents': [979011, 969281], 'rparents': [979011, 969281], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 993555, 'bn': 'Charles', 'b_d': datetime.datetime(1398, 11, 4, 0, 0), 'd_d': datetime.datetime(1418, 3, 4, 0, 0), 'c_d': 'death_trait', 'lge': 970238, 'fat': 970238, 'mot': 968635, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [990905], 'parents': [970238, 968635], 'rparents': [970238, 968635], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 992312, 'bn': 'Rorgues', 'b_d': datetime.datetime(1397, 5, 7, 0, 0), 'fat': 972057, 'mot': 972782, 'cul': 'frankish', 'dnt': 25061, 'emp': 1042815, 'host': 1042815, 'parents': [972057, 972782], 'rparents': [972057, 972782], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 990428, 'bn': 'Sophie', 'fem': 1, 'b_d': datetime.datetime(1395, 2, 11, 0, 0), 'd_d': datetime.datetime(1423, 6, 13, 0, 0), 'c_d': 'death_trait', 'lge': 1005891, 'fat': 939803, 'mot': 963630, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [959227], 'parents': [939803, 963630], 'rparents': [939803, 963630], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 988272, 'bn': 'Ida', 'fem': 1, 'b_d': datetime.datetime(1392, 6, 4, 0, 0), 'd_d': datetime.datetime(1441, 5, 16, 0, 0), 'c_d': 'death_murder', 'killer': 980989, 'lge': 980989, 'fat': 970238, 'mot': 968635, 'cul': 'frankish', 'dnt': 25061, 'spouse': [980989], 'parents': [970238, 968635], 'rparents': [970238, 968635], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 987074, 'bn': 'Raymonde', 'fem': 1, 'b_d': datetime.datetime(1391, 1, 4, 0, 0), 'd_d': datetime.datetime(1424, 1, 19, 0, 0), 'c_d': 'death_trait', 'lge': 981149, 'fat': 970238, 'mot': 968635, 'cul': 'frankish', 'dnt': 25061, 'spouse': [995974], 'parents': [970238, 968635], 'rparents': [970238, 968635], 'generation': 23}}
#
#
#
# {'descendent': {'_id': 985886, 'bn': 'Roubaud', 'b_d': datetime.datetime(1389, 8, 9, 0, 0), 'd_d': datetime.datetime(1416, 7, 7, 0, 0), 'c_d': 'death_trait', 'lge': 970238, 'fat': 967392, 'mot': 954668, 'cul': 'frankish', 'dnt': 25061, 'spouse': [983275], 'parents': [967392, 954668], 'rparents': [967392, 954668], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 985060, 'bn': 'Othon', 'nick': 'nick_the_unchaste', 'b_d': datetime.datetime(1388, 8, 11, 0, 0), 'd_d': datetime.datetime(1454, 1, 21, 0, 0), 'lge': 995445, 'fat': 939803, 'mot': 963630, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [1006546], 'parents': [939803, 963630], 'rparents': [939803, 963630], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 983674, 'bn': 'Judith', 'fem': 1, 'b_d': datetime.datetime(1387, 1, 9, 0, 0), 'd_d': datetime.datetime(1419, 4, 7, 0, 0), 'c_d': 'death_trait', 'lge': 980647, 'fat': 967392, 'mot': 954668, 'cul': 'frankish', 'dnt': 25061, 'spouse': [980647], 'parents': [967392, 954668], 'rparents': [967392, 954668], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 980272, 'bn': 'Josselin', 'b_d': datetime.datetime(1382, 10, 11, 0, 0), 'd_d': datetime.datetime(1400, 6, 7, 0, 0), 'c_d': 'death_battle', 'killer': 985660, 'lge': 970238, 'fat': 939803, 'mot': 963630, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [939803, 963630], 'rparents': [939803, 963630], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 979011, 'bn': 'Ioseph', 'nick': 'nick_the_bear', 'b_d': datetime.datetime(1381, 3, 18, 0, 0), 'd_d': datetime.datetime(1420, 12, 20, 0, 0), 'c_d': 'death_trait', 'fat': 958043, 'mot': 960753, 'rel': 'fraticelli', 'cul': 'pictish', 'dnt': 9230, 'spouse': [969281], 'parents': [958043, 960753], 'rparents': [958043, 960753], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 974979, 'bn': 'Erik', 'b_d': datetime.datetime(1376, 4, 18, 0, 0), 'd_d': datetime.datetime(1380, 7, 31, 0, 0), 'c_d': 'death_murder', 'killer': 952127, 'lge': 958043, 'fat': 958043, 'mot': 960753, 'rel': 'fraticelli', 'cul': 'saxon', 'dnt': 9230, 'parents': [958043, 960753], 'rparents': [958043, 960753], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 973432, 'bn': 'Saga', 'fem': 1, 'b_d': datetime.datetime(1374, 5, 16, 0, 0), 'd_d': datetime.datetime(1445, 1, 13, 0, 0), 'lge': 1014184, 'fat': 942132, 'mot': 952127, 'rel': 'fraticelli', 'cul': 'frankish', 'dnt': 9230, 'parents': [942132, 952127], 'rparents': [942132, 952127], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 972782, 'bn': 'Elisabeth', 'fem': 1, 'b_d': datetime.datetime(1373, 8, 11, 0, 0), 'd_d': datetime.datetime(1444, 11, 7, 0, 0), 'lge': 1017458, 'fat': 953636, 'mot': 941846, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [988435], 'parents': [953636, 941846], 'rparents': [953636, 941846], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 972057, 'bn': 'Rorgues', 'b_d': datetime.datetime(1372, 10, 8, 0, 0), 'd_d': datetime.datetime(1417, 10, 10, 0, 0), 'c_d': 'death_trait', 'lge': 1002826, 'fat': 938463, 'mot': 948003, 'cul': 'frankish', 'dnt': 25061, 'parents': [938463, 948003], 'rparents': [938463, 948003], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 971333, 'bn': 'Helena', 'fem': 1, 'b_d': datetime.datetime(1371, 11, 16, 0, 0), 'd_d': datetime.datetime(1436, 4, 14, 0, 0), 'lge': 994796, 'fat': 942132, 'mot': 952127, 'rel': 'catholic', 'cul': 'frankish', 'dnt': 9230, 'parents': [942132, 952127], 'rparents': [942132, 952127], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 970532, 'bn': 'Antoine', 'b_d': datetime.datetime(1370, 11, 17, 0, 0), 'd_d': datetime.datetime(1390, 7, 10, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 970238, 'lge': 970238, 'fat': 939803, 'mot': 948180, 'cul': 'frankish', 'dnt': 25061, 'parents': [939803, 948180], 'rparents': [939803, 948180], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 970239, 'bn': 'Eve', 'fem': 1, 'b_d': datetime.datetime(1370, 7, 11, 0, 0), 'd_d': datetime.datetime(1421, 8, 12, 0, 0), 'c_d': 'death_trait', 'lge': 971263, 'fat': 953636, 'mot': 941846, 'cul': 'frankish', 'dnt': 25061, 'spouse': [968876, 971263], 'parents': [953636, 941846], 'rparents': [953636, 941846], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 970238, 'bn': 'Aldéric', 'nick': 'nick_the_frail', 'b_d': datetime.datetime(1370, 7, 11, 0, 0), 'd_d': datetime.datetime(1435, 7, 11, 0, 0), 'c_d': 'death_trait', 'lge': 985060, 'fat': 953636, 'mot': 941846, 'cul': 'frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [968635], 'parents': [953636, 941846], 'rparents': [953636, 941846], 'generation': 22}}
#
#
#
# {'descendent': {'_id': 969593, 'bn': 'Elisabeth', 'fem': 1, 'b_d': datetime.datetime(1369, 10, 8, 0, 0), 'd_d': datetime.datetime(1398, 6, 10, 0, 0), 'c_d': 'death_execution_eaten', 'killer': 957199, 'lge': 957199, 'fat': 938463, 'mot': 948003, 'cul': 'frankish', 'dnt': 25061, 'spouse': [975433], 'parents': [938463, 948003], 'rparents': [938463, 948003], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 969281, 'bn': 'Linda', 'fem': 1, 'b_d': datetime.datetime(1369, 5, 16, 0, 0), 'd_d': datetime.datetime(1435, 10, 6, 0, 0), 'lge': 994796, 'fat': 942132, 'mot': 952127, 'rel': 'fraticelli', 'cul': 'frankish', 'dnt': 9230, 'spouse': [979011], 'parents': [942132, 952127], 'rparents': [942132, 952127], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 967392, 'bn': 'Aldéric', 'nick': 'nick_the_shadow', 'b_d': datetime.datetime(1367, 2, 19, 0, 0), 'd_d': datetime.datetime(1415, 4, 21, 0, 0), 'c_d': 'death_trait', 'lge': 970238, 'fat': 944316, 'mot': 929226, 'cul': 'frankish', 'dnt': 25061, 'spouse': [954668, 973262, 979139], 'parents': [944316, 929226], 'rparents': [944316, 929226], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 962613, 'bn': 'Folke', 'b_d': datetime.datetime(1361, 6, 14, 0, 0), 'd_d': datetime.datetime(1389, 3, 7, 0, 0), 'c_d': 'death_battle', 'killer': 983359, 'lge': 979011, 'fat': 942132, 'mot': 936165, 'rel': 'fraticelli', 'cul': 'saxon', 'dnt': 9230, 'spouse': [960621], 'parents': [942132, 936165], 'rparents': [942132, 936165], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 961859, 'bn': 'Arnoul', 'b_d': datetime.datetime(1360, 7, 26, 0, 0), 'd_d': datetime.datetime(1412, 1, 4, 0, 0), 'c_d': 'death_trait', 'fat': 939803, 'mot': 940685, 'cul': 'frankish', 'dnt': 25061, 'parents': [939803, 940685], 'rparents': [939803, 940685], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 960734, 'bn': 'Ben-Muman', 'fem': 1, 'b_d': datetime.datetime(1359, 4, 3, 0, 0), 'd_d': datetime.datetime(1409, 10, 27, 0, 0), 'c_d': 'death_trait', 'lge': 959150, 'fat': 944629, 'mot': 958414, 'rel': 'catholic', 'cul': 'frankish', 'dnt': 9230, 'parents': [944629, 958414], 'rparents': [944629, 958414], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 959450, 'bn': 'Amelie', 'fem': 1, 'b_d': datetime.datetime(1357, 9, 11, 0, 0), 'd_d': datetime.datetime(1431, 10, 3, 0, 0), 'lge': 975743, 'fat': 915400, 'mot': 940698, 'cul': 'frankish', 'dnt': 25061, 'spouse': [954679], 'parents': [915400, 940698], 'rparents': [915400, 940698], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 959150, 'bn': 'Fiachnae', 'b_d': datetime.datetime(1357, 5, 3, 0, 0), 'd_d': datetime.datetime(1434, 2, 11, 0, 0), 'lge': 991160, 'fat': 944629, 'mot': 958414, 'rel': 'catholic', 'cul': 'frankish', 'dnt': 9230, 'spouse': [996601], 'parents': [944629, 958414], 'rparents': [944629, 958414], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 958353, 'bn': 'Tiburge', 'fem': 1, 'b_d': datetime.datetime(1356, 5, 26, 0, 0), 'd_d': datetime.datetime(1412, 7, 26, 0, 0), 'lge': 971263, 'fat': 939803, 'mot': 940685, 'cul': 'frankish', 'dnt': 25061, 'spouse': [954661], 'parents': [939803, 940685], 'rparents': [939803, 940685], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 958043, 'bn': 'Ulf', 'b_d': datetime.datetime(1356, 1, 14, 0, 0), 'd_d': datetime.datetime(1382, 7, 10, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 959150, 'lge': 953636, 'fat': 942132, 'mot': 936165, 'rel': 'fraticelli', 'cul': 'saxon', 'dnt': 9230, 'spouse': [960753], 'parents': [942132, 936165], 'rparents': [942132, 936165], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 953636, 'bn': 'Charles', 'b_d': datetime.datetime(1350, 12, 15, 0, 0), 'd_d': datetime.datetime(1387, 7, 4, 0, 0), 'c_d': 'death_battle', 'killer': 945624, 'fat': 930715, 'mot': 921410, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [941846], 'parents': [930715, 921410], 'rparents': [930715, 921410], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 952821, 'bn': 'Charlotte', 'fem': 1, 'b_d': datetime.datetime(1350, 3, 16, 0, 0), 'd_d': datetime.datetime(1371, 5, 10, 0, 0), 'c_d': 'death_childbirth', 'lge': 966894, 'fat': 906464, 'mot': 935775, 'rel': 'fraticelli', 'cul': 'frankish', 'dnt': 315, 'spouse': [966894], 'parents': [906464, 935775], 'rparents': [906464, 935775], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 952030, 'bn': 'Raymonde', 'fem': 1, 'b_d': datetime.datetime(1349, 3, 15, 0, 0), 'd_d': datetime.datetime(1368, 12, 3, 0, 0), 'c_d': 'death_trait', 'lge': 945641, 'fat': 930715, 'mot': 921410, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [951134], 'parents': [930715, 921410], 'rparents': [930715, 921410], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 948003, 'bn': 'Héloise', 'fem': 1, 'b_d': datetime.datetime(1344, 5, 27, 0, 0), 'd_d': datetime.datetime(1379, 5, 8, 0, 0), 'c_d': 'death_trait', 'lge': 944316, 'fat': 929665, 'mot': 928758, 'cul': 'frankish', 'dnt': 25061, 'spouse': [938463], 'parents': [929665, 928758], 'rparents': [929665, 928758], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 944629, 'bn': 'Torccán', 'b_d': datetime.datetime(1340, 6, 14, 0, 0), 'd_d': datetime.datetime(1402, 1, 22, 0, 0), 'lge': 970732, 'fat': 892219, 'mot': 909201, 'rel': 'catholic', 'cul': 'saxon', 'dnt': 9230, 'spouse': [958414], 'parents': [892219, 909201], 'rparents': [892219, 909201], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 944316, 'bn': 'Roubaud', 'nick': 'nick_the_ironside', 'b_d': datetime.datetime(1340, 1, 27, 0, 0), 'd_d': datetime.datetime(1389, 9, 17, 0, 0), 'c_d': 'death_trait', 'lge': 970238, 'fat': 929665, 'mot': 928758, 'cul': 'frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [929226, 952127], 'parents': [929665, 928758], 'rparents': [929665, 928758], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 943296, 'bn': 'Gisèle', 'fem': 1, 'b_d': datetime.datetime(1338, 11, 4, 0, 0), 'd_d': datetime.datetime(1367, 9, 5, 0, 0), 'c_d': 'death_trait', 'lge': 944316, 'fat': 926431, 'mot': 909695, 'cul': 'frankish', 'dnt': 25061, 'parents': [926431, 909695], 'rparents': [926431, 909695], 'generation': 21}}
#
#
#
# {'descendent': {'_id': 942132, 'bn': 'Ioseph', 'nick': 'nick_the_fat', 'b_d': datetime.datetime(1337, 5, 14, 0, 0), 'd_d': datetime.datetime(1380, 4, 1, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 928432, 'lge': 953636, 'fat': 892219, 'mot': 909201, 'rel': 'catholic', 'cul': 'saxon', 'dnt': 9230, 'spouse': [936165, 952127], 'parents': [892219, 909201], 'rparents': [892219, 909201], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 939802, 'bn': 'Péronelle', 'fem': 1, 'b_d': datetime.datetime(1334, 7, 14, 0, 0), 'd_d': datetime.datetime(1400, 1, 11, 0, 0), 'c_d': 'death_trait', 'lge': 960660, 'fat': 915400, 'mot': 913709, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [938596], 'parents': [915400, 913709], 'rparents': [915400, 913709], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 939803, 'bn': 'Guillaume', 'b_d': datetime.datetime(1334, 7, 14, 0, 0), 'd_d': datetime.datetime(1398, 4, 12, 0, 0), 'c_d': 'death_trait', 'lge': 970238, 'fat': 915400, 'mot': 913709, 'cul': 'frankish', 'dnt': 25061, 'spouse': [940685, 948180, 963630], 'parents': [915400, 913709], 'rparents': [915400, 913709], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 938463, 'bn': 'Alain', 'b_d': datetime.datetime(1332, 12, 11, 0, 0), 'd_d': datetime.datetime(1383, 5, 16, 0, 0), 'lge': 944316, 'fat': 910580, 'mot': 904858, 'cul': 'frankish', 'dnt': 25061, 'spouse': [948003], 'parents': [910580, 904858], 'rparents': [910580, 904858], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 937368, 'bn': 'Adèle', 'fem': 1, 'b_d': datetime.datetime(1331, 8, 11, 0, 0), 'd_d': datetime.datetime(1395, 6, 13, 0, 0), 'c_d': 'death_trait', 'lge': 967392, 'fat': 910580, 'mot': 904858, 'cul': 'frankish', 'dnt': 25061, 'parents': [910580, 904858], 'rparents': [910580, 904858], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 935070, 'bn': 'Emma', 'fem': 1, 'b_d': datetime.datetime(1328, 10, 15, 0, 0), 'd_d': datetime.datetime(1347, 8, 11, 0, 0), 'c_d': 'death_trait', 'lge': 919551, 'fat': 919551, 'mot': 933450, 'dnt': 315, 'parents': [919551, 933450], 'rparents': [919551, 933450], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 933763, 'bn': 'Manassès', 'b_d': datetime.datetime(1327, 3, 23, 0, 0), 'd_d': datetime.datetime(1354, 5, 20, 0, 0), 'c_d': 'death_trait', 'lge': 929665, 'fat': 910580, 'mot': 918854, 'cul': 'pictish', 'dnt': 25061, 'parents': [910580, 918854], 'rparents': [910580, 918854], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 932704, 'bn': 'Benoîte', 'fem': 1, 'b_d': datetime.datetime(1325, 12, 14, 0, 0), 'd_d': datetime.datetime(1380, 8, 25, 0, 0), 'c_d': 'death_trait', 'lge': 957199, 'fat': 915400, 'mot': 913709, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [933703], 'parents': [915400, 913709], 'rparents': [915400, 913709], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 932337, 'bn': 'Eustachie', 'fem': 1, 'b_d': datetime.datetime(1325, 7, 1, 0, 0), 'd_d': datetime.datetime(1370, 12, 22, 0, 0), 'lge': 944316, 'fat': 911075, 'rfat': 910580, 'mot': 912912, 'cul': 'frankish', 'dnt': 25061, 'parents': [911075, 912912], 'rparents': [910580, 912912], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 932111, 'bn': 'Péronelle', 'fem': 1, 'b_d': datetime.datetime(1325, 3, 11, 0, 0), 'd_d': datetime.datetime(1365, 3, 20, 0, 0), 'c_d': 'death_trait', 'lge': 944316, 'fat': 910580, 'mot': 904858, 'cul': 'frankish', 'dnt': 25061, 'parents': [910580, 904858], 'rparents': [910580, 904858], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 931275, 'bn': 'Onfroy', 'b_d': datetime.datetime(1324, 3, 1, 0, 0), 'd_d': datetime.datetime(1378, 7, 24, 0, 0), 'c_d': 'death_trait', 'lge': 944316, 'fat': 911075, 'mot': 912912, 'cul': 'basque', 'dnt': 25061, 'spouse': [911259, 935775], 'parents': [911075, 912912], 'rparents': [911075, 912912], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 931135, 'bn': 'Léonard', 'b_d': datetime.datetime(1324, 1, 8, 0, 0), 'd_d': datetime.datetime(1340, 5, 24, 0, 0), 'c_d': 'death_trait', 'lge': 910580, 'fat': 878227, 'mot': 908075, 'cul': 'frankish', 'dnt': 25061, 'parents': [878227, 908075], 'rparents': [878227, 908075], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 930715, 'bn': 'Aldéric', 'b_d': datetime.datetime(1323, 7, 14, 0, 0), 'd_d': datetime.datetime(1351, 1, 6, 0, 0), 'c_d': 'death_murder_unknown_snakes', 'killer': 939802, 'lge': 915400, 'fat': 915400, 'mot': 913709, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [921410], 'parents': [915400, 913709], 'rparents': [915400, 913709], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 929665, 'bn': 'Ebbon', 'b_d': datetime.datetime(1322, 5, 4, 0, 0), 'd_d': datetime.datetime(1356, 4, 10, 0, 0), 'c_d': 'death_trait', 'lge': 915400, 'fat': 883846, 'mot': 910115, 'cul': 'frankish', 'dnt': 25061, 'spouse': [928758], 'parents': [883846, 910115], 'rparents': [883846, 910115], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 929226, 'bn': 'Judith', 'fem': 1, 'b_d': datetime.datetime(1321, 10, 7, 0, 0), 'd_d': datetime.datetime(1382, 2, 19, 0, 0), 'lge': 944316, 'fat': 893874, 'mot': 912582, 'cul': 'frankish', 'dnt': 25061, 'spouse': [944316], 'parents': [893874, 912582], 'rparents': [893874, 912582], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 928758, 'bn': 'Elisabeth', 'fem': 1, 'b_d': datetime.datetime(1321, 2, 23, 0, 0), 'd_d': datetime.datetime(1368, 3, 27, 0, 0), 'c_d': 'death_trait', 'lge': 944316, 'fat': 906464, 'mot': 901342, 'dnt': 315, 'spouse': [929665], 'parents': [906464, 901342], 'rparents': [906464, 901342], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 927396, 'bn': 'Constance', 'fem': 1, 'b_d': datetime.datetime(1319, 7, 11, 0, 0), 'd_d': datetime.datetime(1339, 6, 9, 0, 0), 'c_d': 'death_dungeon', 'killer': 892694, 'lge': 910580, 'fat': 910580, 'mot': 904858, 'cul': 'pictish', 'dnt': 25061, 'parents': [910580, 904858], 'rparents': [910580, 904858], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 926565, 'bn': 'Jean', 'b_d': datetime.datetime(1318, 7, 8, 0, 0), 'd_d': datetime.datetime(1319, 12, 18, 0, 0), 'c_d': 'death_trait', 'lge': 910580, 'fat': 878227, 'mot': 908075, 'cul': 'frankish', 'dnt': 25061, 'parents': [878227, 908075], 'rparents': [878227, 908075], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 926431, 'bn': 'Charles', 'b_d': datetime.datetime(1318, 5, 11, 0, 0), 'd_d': datetime.datetime(1348, 9, 24, 0, 0), 'c_d': 'death_trait', 'lge': 883846, 'fat': 910580, 'mot': 904858, 'cul': 'frankish', 'dnt': 25061, 'spouse': [909695], 'parents': [910580, 904858], 'rparents': [910580, 904858], 'generation': 20}}
#
#
#
# {'descendent': {'_id': 925423, 'bn': 'Julienne', 'fem': 1, 'b_d': datetime.datetime(1317, 3, 8, 0, 0), 'd_d': datetime.datetime(1395, 3, 24, 0, 0), 'lge': 967392, 'fat': 878227, 'mot': 908075, 'cul': 'pictish', 'dnt': 25061, 'parents': [878227, 908075], 'rparents': [878227, 908075], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 924229, 'bn': 'Elisabeth', 'fem': 1, 'b_d': datetime.datetime(1315, 10, 23, 0, 0), 'd_d': datetime.datetime(1395, 12, 6, 0, 0), 'lge': 967392, 'fat': 906464, 'mot': 901342, 'dnt': 315, 'spouse': [926590, 910580], 'parents': [906464, 901342], 'rparents': [906464, 901342], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 922328, 'bn': 'Mélusine', 'fem': 1, 'b_d': datetime.datetime(1313, 8, 4, 0, 0), 'd_d': datetime.datetime(1367, 7, 9, 0, 0), 'c_d': 'death_trait', 'lge': 944316, 'fat': 883846, 'mot': 910115, 'cul': 'frankish', 'dnt': 25061, 'parents': [883846, 910115], 'rparents': [883846, 910115], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 922238, 'bn': 'Raymond', 'nick': 'nick_the_tyrant', 'b_d': datetime.datetime(1313, 6, 23, 0, 0), 'd_d': datetime.datetime(1401, 10, 3, 0, 0), 'fat': 906464, 'mot': 901342, 'cul': 'swedish', 'dnt': 315, 'parents': [906464, 901342], 'rparents': [906464, 901342], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 922237, 'bn': 'Elisabeth', 'fem': 1, 'b_d': datetime.datetime(1313, 6, 23, 0, 0), 'd_d': datetime.datetime(1368, 4, 2, 0, 0), 'c_d': 'death_trait', 'lge': 957127, 'fat': 906464, 'mot': 901342, 'dnt': 315, 'spouse': [916059, 936457], 'parents': [906464, 901342], 'rparents': [906464, 901342], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 921410, 'bn': 'Eve', 'fem': 1, 'b_d': datetime.datetime(1312, 6, 19, 0, 0), 'd_d': datetime.datetime(1366, 11, 15, 0, 0), 'lge': 953636, 'fat': 898653, 'mot': 895430, 'cul': 'irish', 'dnt': 25061, 'spouse': [878581, 930715], 'parents': [898653, 895430], 'rparents': [898653, 895430], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 921320, 'bn': 'Aléarde', 'fem': 1, 'b_d': datetime.datetime(1312, 5, 4, 0, 0), 'd_d': datetime.datetime(1387, 5, 9, 0, 0), 'lge': 944316, 'fat': 883846, 'mot': 910115, 'cul': 'pictish', 'dnt': 25061, 'parents': [883846, 910115], 'rparents': [883846, 910115], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 919771, 'bn': 'Cathèrine', 'fem': 1, 'b_d': datetime.datetime(1310, 6, 7, 0, 0), 'd_d': datetime.datetime(1370, 8, 28, 0, 0), 'lge': 953636, 'fat': 893874, 'mot': 912582, 'cul': 'frankish', 'dnt': 25061, 'parents': [893874, 912582], 'rparents': [893874, 912582], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 919770, 'bn': 'Marie', 'fem': 1, 'b_d': datetime.datetime(1310, 6, 7, 0, 0), 'd_d': datetime.datetime(1364, 1, 27, 0, 0), 'c_d': 'death_trait', 'lge': 953636, 'fat': 893874, 'mot': 912582, 'cul': 'frankish', 'dnt': 25061, 'parents': [893874, 912582], 'rparents': [893874, 912582], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 919551, 'bn': 'Yves', 'b_d': datetime.datetime(1310, 2, 19, 0, 0), 'd_d': datetime.datetime(1354, 6, 4, 0, 0), 'c_d': 'death_trait', 'lge': 942035, 'fat': 883577, 'mot': 913602, 'cul': 'saxon', 'dnt': 315, 'spouse': [933450], 'parents': [883577, 913602], 'rparents': [883577, 913602], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 918854, 'bn': 'Marthe', 'fem': 1, 'b_d': datetime.datetime(1309, 4, 19, 0, 0), 'd_d': datetime.datetime(1380, 11, 7, 0, 0), 'c_d': 'death_trait', 'lge': 944316, 'fat': 898653, 'mot': 895430, 'cul': 'irish', 'dnt': 25061, 'parents': [898653, 895430], 'rparents': [898653, 895430], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 918728, 'bn': 'Mélusine', 'fem': 1, 'b_d': datetime.datetime(1309, 2, 19, 0, 0), 'd_d': datetime.datetime(1348, 1, 21, 0, 0), 'c_d': 'death_trait', 'lge': 915400, 'fat': 871707, 'mot': 890614, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [871707, 890614], 'rparents': [871707, 890614], 'generation': 17}}
#
#
#
# {'descendent': {'_id': 916630, 'bn': 'Clotaire', 'nick': 'nick_the_usurper', 'b_d': datetime.datetime(1306, 7, 16, 0, 0), 'd_d': datetime.datetime(1344, 11, 23, 0, 0), 'c_d': 'death_trait', 'fat': 893874, 'mot': 896519, 'cul': 'pictish', 'dnt': 25061, 'spouse': [918418, 930920], 'parents': [893874, 896519], 'rparents': [893874, 896519], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 915400, 'bn': 'Charles', 'b_d': datetime.datetime(1305, 2, 16, 0, 0), 'd_d': datetime.datetime(1357, 9, 25, 0, 0), 'c_d': 'death_trait', 'fat': 893874, 'mot': 896519, 'cul': 'frankish', 'dnt': 25061, 'spouse': [913709, 940698], 'parents': [893874, 896519], 'rparents': [893874, 896519], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 914859, 'bn': 'Cathèrine', 'fem': 1, 'b_d': datetime.datetime(1304, 6, 19, 0, 0), 'd_d': datetime.datetime(1368, 4, 16, 0, 0), 'c_d': 'death_trait', 'lge': 944629, 'fat': 883577, 'mot': 913602, 'dnt': 315, 'parents': [883577, 913602], 'rparents': [883577, 913602], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 914166, 'bn': 'Foulques', 'b_d': datetime.datetime(1303, 9, 4, 0, 0), 'd_d': datetime.datetime(1351, 10, 23, 0, 0), 'c_d': 'death_trait', 'lge': 929665, 'fat': 891871, 'mot': 888555, 'cul': 'frankish', 'dnt': 25061, 'parents': [891871, 888555], 'rparents': [891871, 888555], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 913709, 'bn': 'Benoîte', 'fem': 1, 'b_d': datetime.datetime(1303, 2, 20, 0, 0), 'd_d': datetime.datetime(1356, 1, 14, 0, 0), 'c_d': 'death_trait', 'lge': 915400, 'fat': 871701, 'mot': 904111, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [915400], 'parents': [871701, 904111], 'rparents': [871701, 904111], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 913081, 'bn': 'Solène', 'fem': 1, 'b_d': datetime.datetime(1302, 5, 27, 0, 0), 'd_d': datetime.datetime(1334, 2, 2, 0, 0), 'c_d': 'death_trait', 'lge': 925424, 'fat': 885264, 'mot': 905322, 'rel': 'catholic', 'cul': 'pictish', 'spouse': [919202], 'parents': [885264, 905322], 'rparents': [885264, 905322], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 912912, 'bn': 'Stéphanie', 'fem': 1, 'b_d': datetime.datetime(1302, 3, 4, 0, 0), 'd_d': datetime.datetime(1349, 8, 9, 0, 0), 'c_d': 'death_execution_burning', 'killer': 883846, 'lge': 883846, 'fat': 883846, 'mot': 910115, 'cul': 'frankish', 'dnt': 25061, 'spouse': [911075], 'parents': [883846, 910115], 'rparents': [883846, 910115], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 912271, 'bn': 'Constance', 'fem': 1, 'b_d': datetime.datetime(1301, 6, 4, 0, 0), 'd_d': datetime.datetime(1337, 8, 4, 0, 0), 'c_d': 'death_poor_health', 'lge': 883846, 'fat': 891871, 'mot': 888555, 'cul': 'basque', 'dnt': 25061, 'parents': [891871, 888555], 'rparents': [891871, 888555], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 911259, 'bn': 'Aude', 'fem': 1, 'b_d': datetime.datetime(1300, 3, 20, 0, 0), 'd_d': datetime.datetime(1351, 6, 28, 0, 0), 'lge': 929665, 'fat': 871701, 'mot': 904111, 'cul': 'frankish', 'dnt': 25061, 'spouse': [911792, 931275], 'parents': [871701, 904111], 'rparents': [871701, 904111], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 911075, 'bn': 'Renaud', 'b_d': datetime.datetime(1300, 1, 4, 0, 0), 'd_d': datetime.datetime(1333, 10, 11, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 916630, 'lge': 883846, 'fat': 891871, 'mot': 888555, 'cul': 'basque', 'dnt': 25061, 'spouse': [912912], 'parents': [891871, 888555], 'rparents': [891871, 888555], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 910580, 'bn': 'Rorgues', 'nick': 'nick_the_lame', 'b_d': datetime.datetime(1299, 5, 5, 0, 0), 'd_d': datetime.datetime(1367, 4, 21, 0, 0), 'lge': 944316, 'fat': 885264, 'mot': 885588, 'cul': 'pictish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [904858, 924229], 'parents': [885264, 885588], 'rparents': [885264, 885588], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 909849, 'bn': 'Charles', 'b_d': datetime.datetime(1298, 6, 23, 0, 0), 'd_d': datetime.datetime(1309, 2, 18, 0, 0), 'c_d': 'death_trait', 'lge': 871707, 'fat': 893495, 'mot': 894846, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [893495, 894846], 'rparents': [893495, 894846], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 909613, 'bn': 'Arsinde', 'fem': 1, 'b_d': datetime.datetime(1298, 3, 19, 0, 0), 'd_d': datetime.datetime(1314, 4, 6, 0, 0), 'c_d': 'death_trait', 'lge': 883846, 'fat': 883846, 'mot': 907638, 'cul': 'frankish', 'dnt': 25061, 'parents': [883846, 907638], 'rparents': [883846, 907638], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 908458, 'bn': 'Guilhem', 'b_d': datetime.datetime(1296, 11, 16, 0, 0), 'd_d': datetime.datetime(1301, 2, 27, 0, 0), 'c_d': 'death_trait', 'lge': 906464, 'fat': 892219, 'mot': 876051, 'dnt': 315, 'parents': [892219, 876051], 'rparents': [892219, 876051], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 908075, 'bn': 'Navar', 'fem': 1, 'b_d': datetime.datetime(1296, 6, 5, 0, 0), 'd_d': datetime.datetime(1335, 1, 8, 0, 0), 'c_d': 'death_poor_health', 'lge': 910580, 'fat': 885264, 'mot': 885588, 'cul': 'pictish', 'dnt': 25061, 'spouse': [878227], 'parents': [885264, 885588], 'rparents': [885264, 885588], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 907216, 'bn': 'Adèle', 'fem': 1, 'b_d': datetime.datetime(1295, 5, 30, 0, 0), 'd_d': datetime.datetime(1361, 10, 17, 0, 0), 'c_d': 'death_trait', 'lge': 948386, 'fat': 885264, 'mot': 902703, 'cul': 'frankish', 'dnt': 25061, 'spouse': [902172], 'parents': [885264, 902703], 'rparents': [885264, 902703], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 906464, 'bn': 'Rorgon', 'nick': 'nick_the_blessed', 'b_d': datetime.datetime(1294, 6, 2, 0, 0), 'd_d': datetime.datetime(1355, 2, 21, 0, 0), 'fat': 869263, 'mot': 884857, 'dnt': 315, 'spouse': [901342, 925153, 935775], 'parents': [869263, 884857], 'rparents': [869263, 884857], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 906203, 'bn': 'Isabeau', 'fem': 1, 'b_d': datetime.datetime(1294, 1, 22, 0, 0), 'd_d': datetime.datetime(1317, 4, 12, 0, 0), 'c_d': 'death_trait', 'lge': 915348, 'fat': 885264, 'mot': 883729, 'cul': 'pictish', 'dnt': 25061, 'parents': [885264, 883729], 'rparents': [885264, 883729], 'generation': 19}}
#
#
#
# {'descendent': {'_id': 904858, 'bn': 'Péronelle', 'fem': 1, 'b_d': datetime.datetime(1292, 6, 5, 0, 0), 'd_d': datetime.datetime(1347, 6, 30, 0, 0), 'c_d': 'death_execution_burning', 'killer': 906464, 'lge': 883846, 'fat': 871701, 'mot': 875452, 'cul': 'frankish', 'dnt': 25061, 'spouse': [871707, 910580], 'parents': [871701, 875452], 'rparents': [871701, 875452], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 900551, 'bn': 'Alphonse', 'b_d': datetime.datetime(1287, 2, 25, 0, 0), 'd_d': datetime.datetime(1304, 4, 16, 0, 0), 'c_d': 'death_trait', 'lge': 871707, 'fat': 871707, 'mot': 874940, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [882375], 'parents': [871707, 874940], 'rparents': [871707, 874940], 'generation': 17}}
#
#
#
# {'descendent': {'_id': 898653, 'bn': 'Alphonse', 'b_d': datetime.datetime(1285, 1, 28, 0, 0), 'd_d': datetime.datetime(1330, 5, 22, 0, 0), 'c_d': 'death_trait', 'lge': 883846, 'fat': 845225, 'rfat': 848696, 'mot': 865731, 'cul': 'irish', 'dnt': 25061, 'spouse': [895430], 'parents': [845225, 865731], 'rparents': [848696, 865731], 'generation': 17}}
#
#
#
# {'descendent': {'_id': 897406, 'bn': 'Julien', 'b_d': datetime.datetime(1283, 10, 10, 0, 0), 'd_d': datetime.datetime(1295, 11, 7, 0, 0), 'c_d': 'death_trait', 'fat': 869263, 'mot': 865321, 'cul': 'swedish', 'dnt': 315, 'parents': [869263, 865321], 'rparents': [869263, 865321], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 895551, 'bn': 'Perinne', 'fem': 1, 'b_d': datetime.datetime(1281, 10, 9, 0, 0), 'd_d': datetime.datetime(1354, 4, 28, 0, 0), 'c_d': 'death_trait', 'lge': 917841, 'fat': 881106, 'mot': 875820, 'dnt': 315, 'spouse': [855314, 900517], 'parents': [881106, 875820], 'rparents': [881106, 875820], 'generation': 17}}
#
#
#
# {'descendent': {'_id': 895550, 'bn': 'Gisèle', 'fem': 1, 'b_d': datetime.datetime(1281, 10, 9, 0, 0), 'd_d': datetime.datetime(1295, 12, 27, 0, 0), 'c_d': 'death_trait', 'lge': 906464, 'fat': 881106, 'mot': 875820, 'dnt': 315, 'parents': [881106, 875820], 'rparents': [881106, 875820], 'generation': 17}}
#
#
#
# {'descendent': {'_id': 894846, 'bn': 'Mélusine', 'fem': 1, 'b_d': datetime.datetime(1280, 12, 5, 0, 0), 'd_d': datetime.datetime(1339, 3, 23, 0, 0), 'c_d': 'death_trait', 'lge': 925424, 'fat': 871701, 'mot': 875452, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [893495, 898459], 'parents': [871701, 875452], 'rparents': [871701, 875452], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 893874, 'bn': 'Aldéric', 'b_d': datetime.datetime(1279, 10, 5, 0, 0), 'd_d': datetime.datetime(1322, 7, 7, 0, 0), 'c_d': 'death_murder_poison', 'killer': 898653, 'lge': 906464, 'fat': 871701, 'mot': 875452, 'cul': 'frankish', 'dnt': 25061, 'spouse': [890460, 896519, 912582], 'parents': [871701, 875452], 'rparents': [871701, 875452], 'generation': 18}}
#
#
#
# {'descendent': {'_id': 893495, 'bn': 'Robert', 'b_d': datetime.datetime(1279, 4, 25, 0, 0), 'd_d': datetime.datetime(1300, 12, 16, 0, 0), 'c_d': 'death_trait', 'lge': 871707, 'fat': 871707, 'mot': 874940, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [894846], 'parents': [871707, 874940], 'rparents': [871707, 874940], 'generation': 17}}
#
#
#
# {'descendent': {'_id': 892219, 'bn': 'Raynaud', 'b_d': datetime.datetime(1277, 11, 18, 0, 0), 'd_d': datetime.datetime(1342, 10, 28, 0, 0), 'c_d': 'death_trait', 'lge': 942132, 'fat': 878276, 'mot': 870033, 'cul': 'saxon', 'dnt': 315, 'spouse': [876051, 909201], 'parents': [878276, 870033], 'rparents': [878276, 870033], 'generation': 17}}
#
#
#
# {'descendent': {'_id': 892218, 'bn': 'Gilbert', 'b_d': datetime.datetime(1277, 11, 18, 0, 0), 'd_d': datetime.datetime(1339, 5, 27, 0, 0), 'c_d': 'death_trait', 'lge': 906464, 'fat': 878276, 'mot': 870033, 'dnt': 315, 'parents': [878276, 870033], 'rparents': [878276, 870033], 'generation': 17}}
#
#
#
# {'descendent': {'_id': 891871, 'bn': 'Robin', 'b_d': datetime.datetime(1277, 6, 28, 0, 0), 'd_d': datetime.datetime(1346, 3, 16, 0, 0), 'lge': 883846, 'fat': 845225, 'rfat': 848696, 'mot': 865731, 'cul': 'frankish', 'dnt': 25061, 'spouse': [888555], 'parents': [845225, 865731], 'rparents': [848696, 865731], 'generation': 17}}
#
#
#
# {'descendent': {'_id': 891861, 'bn': 'Thiébaut', 'b_d': datetime.datetime(1277, 6, 25, 0, 0), 'd_d': datetime.datetime(1294, 11, 6, 0, 0), 'c_d': 'death_trait', 'lge': 871707, 'fat': 871707, 'mot': 874940, 'cul': 'frankish', 'dnt': 25061, 'spouse': [882375], 'parents': [871707, 874940], 'rparents': [871707, 874940], 'generation': 17}}
#
#
#
# {'descendent': {'_id': 885264, 'bn': 'Manassès', 'nick': 'nick_the_lewd', 'b_d': datetime.datetime(1269, 6, 13, 0, 0), 'd_d': datetime.datetime(1301, 12, 17, 0, 0), 'c_d': 'death_trait', 'lge': 906464, 'fat': 861590, 'mot': 862748, 'cul': 'pictish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [872743, 885588], 'parents': [861590, 862748], 'rparents': [861590, 862748], 'generation': 18}}
#
#
#
# ...
#
#
#
# {'descendent': {'_id': 612768, 'bn': 'Helvis', 'fem': 1, 'b_d': datetime.datetime(926, 10, 9, 0, 0), 'd_d': datetime.datetime(990, 6, 17, 0, 0), 'c_d': 'death_trait', 'lge': 630179, 'fat': 591244, 'mot': 594644, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [630179], 'parents': [591244, 594644], 'rparents': [591244, 594644], 'generation': 5}}
#
#
#
# {'descendent': {'_id': 611878, 'bn': 'Raynaud', 'b_d': datetime.datetime(925, 7, 9, 0, 0), 'd_d': datetime.datetime(957, 6, 23, 0, 0), 'c_d': 'death_poor_health', 'lge': 591244, 'fat': 591244, 'mot': 594644, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [607149, 613895, 618426], 'parents': [591244, 594644], 'rparents': [591244, 594644], 'generation': 5}}
#
#
#
# {'descendent': {'_id': 610811, 'bn': 'Raynaud', 'nick': 'nick_the_monster', 'b_d': datetime.datetime(924, 2, 1, 0, 0), 'd_d': datetime.datetime(945, 12, 16, 0, 0), 'c_d': 'death_battle', 'killer': 620647, 'fat': 562370, 'rfat': 579771, 'mot': 600018, 'cul': 'german', 'dnt': 25061, 'spouse': [609767], 'parents': [562370, 600018], 'rparents': [579771, 600018], 'generation': 3}}
#
#
#
# {'descendent': {'_id': 606594, 'bn': 'Isabeau', 'fem': 1, 'b_d': datetime.datetime(918, 1, 9, 0, 0), 'd_d': datetime.datetime(980, 5, 3, 0, 0), 'lge': 621289, 'fat': 591244, 'mot': 594644, 'cul': 'khazar', 'dnt': 25061, 'spouse': [598115], 'parents': [591244, 594644], 'rparents': [591244, 594644], 'generation': 5}}
#
#
#
# {'descendent': {'_id': 605017, 'bn': 'Belleassez', 'fem': 1, 'b_d': datetime.datetime(915, 9, 7, 0, 0), 'd_d': datetime.datetime(946, 6, 5, 0, 0), 'c_d': 'death_suicide_hanging', 'lge': 605122, 'fat': 562370, 'mot': 600018, 'cul': 'levantine_arabic', 'dnt': 25061, 'spouse': [584214], 'parents': [562370, 600018], 'rparents': [562370, 600018], 'generation': 3}}
#
#
#
# {'descendent': {'_id': 603923, 'bn': 'Manassès', 'nick': 'nick_the_wise', 'b_d': datetime.datetime(914, 1, 8, 0, 0), 'd_d': datetime.datetime(987, 9, 20, 0, 0), 'c_d': 'death_trait', 'fat': 580537, 'mot': 583107, 'cul': 'frankish', 'dnt': 25061, 'spouse': [608155, 640348], 'parents': [580537, 583107], 'rparents': [580537, 583107], 'generation': 4}}
#
#
#
# {'descendent': {'_id': 602715, 'bn': 'Emma', 'fem': 1, 'b_d': datetime.datetime(912, 4, 7, 0, 0), 'd_d': datetime.datetime(975, 1, 16, 0, 0), 'lge': 607586, 'fat': 562370, 'mot': 600018, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [562370, 600018], 'rparents': [562370, 600018], 'generation': 3}}
#
#
#
# {'descendent': {'_id': 600079, 'bn': 'Perinne', 'fem': 1, 'b_d': datetime.datetime(908, 6, 8, 0, 0), 'd_d': datetime.datetime(930, 3, 12, 0, 0), 'c_d': 'death_childbirth', 'lge': 580537, 'fat': 580537, 'mot': 583107, 'cul': 'frisian', 'dnt': 25061, 'spouse': [614507], 'parents': [580537, 583107], 'rparents': [580537, 583107], 'generation': 4}}
#
#
#
# {'descendent': {'_id': 597370, 'bn': 'Solène', 'fem': 1, 'b_d': datetime.datetime(904, 7, 8, 0, 0), 'd_d': datetime.datetime(958, 9, 19, 0, 0), 'c_d': 'death_trait', 'lge': 615767, 'fat': 580537, 'rfat': 562370, 'mot': 583107, 'cul': 'frankish', 'dnt': 25061, 'spouse': [608911], 'parents': [580537, 583107], 'rparents': [562370, 583107], 'generation': 4}}
#
#
#
# {'descendent': {'_id': 596082, 'bn': 'Aléarde', 'fem': 1, 'b_d': datetime.datetime(902, 8, 8, 0, 0), 'd_d': datetime.datetime(973, 2, 19, 0, 0), 'lge': 615673, 'fat': 580537, 'rfat': 562370, 'mot': 583107, 'cul': 'frankish', 'dnt': 25061, 'spouse': [607580], 'parents': [580537, 583107], 'rparents': [562370, 583107], 'generation': 4}}
#
#
#
# {'descendent': {'_id': 594398, 'bn': 'Raimbaut', 'b_d': datetime.datetime(900, 3, 23, 0, 0), 'd_d': datetime.datetime(921, 12, 15, 0, 0), 'c_d': 'death_trait', 'lge': 562370, 'fat': 562370, 'mot': 583107, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [562370, 583107], 'rparents': [562370, 583107], 'generation': 3}}
#
#
#
# {'descendent': {'_id': 591244, 'bn': 'Raynaud', 'nick': 'nick_the_tyrant', 'b_d': datetime.datetime(895, 7, 21, 0, 0), 'd_d': datetime.datetime(965, 11, 25, 0, 0), 'c_d': 'death_trait', 'fat': 577938, 'mot': 569064, 'cul': 'khazar', 'dnt': 25061, 'spouse': [594644, 613994], 'parents': [577938, 569064], 'rparents': [577938, 569064], 'generation': 4}}
#
#
#
# {'descendent': {'_id': 584671, 'bn': 'Solène', 'fem': 1, 'b_d': datetime.datetime(885, 7, 20, 0, 0), 'd_d': datetime.datetime(951, 8, 4, 0, 0), 'lge': 603923, 'fat': 562370, 'mot': 572787, 'cul': 'frisian', 'dnt': 25061, 'spouse': [589909], 'parents': [562370, 572787], 'rparents': [562370, 572787], 'generation': 3}}
#
#
#
# {'descendent': {'_id': 583250, 'bn': 'Elisabeth', 'fem': 1, 'b_d': datetime.datetime(883, 6, 20, 0, 0), 'd_d': datetime.datetime(950, 3, 11, 0, 0), 'lge': 622498, 'fat': 562370, 'mot': 572787, 'cul': 'frisian', 'dnt': 25061, 'spouse': [588841], 'parents': [562370, 572787], 'rparents': [562370, 572787], 'generation': 3}}
#
#
#
# {'descendent': {'_id': 580537, 'bn': 'Charles', 'nick': 'nick_the_cruel', 'b_d': datetime.datetime(879, 7, 20, 0, 0), 'd_d': datetime.datetime(936, 12, 14, 0, 0), 'c_d': 'death_trait', 'fat': 562370, 'rfat': 555763, 'mot': 572787, 'cul': 'frisian', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [583107], 'parents': [562370, 572787], 'rparents': [555763, 572787], 'generation': 3}}
#
#
#
# {'descendent': {'_id': 577938, 'bn': 'Reinoud', 'b_d': datetime.datetime(875, 10, 20, 0, 0), 'd_d': datetime.datetime(901, 3, 8, 0, 0), 'c_d': 'death_duel', 'killer': 576020, 'lge': 562370, 'fat': 562370, 'mot': 572787, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [569064, 581216], 'parents': [562370, 572787], 'rparents': [562370, 572787], 'generation': 3}}
#
#
#
# {'descendent': {'_id': 575971, 'bn': 'Margareta', 'fem': 1, 'b_d': datetime.datetime(873, 1, 20, 0, 0), 'd_d': datetime.datetime(893, 8, 13, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 569502, 'lge': 569502, 'fat': 562370, 'mot': 572787, 'cul': 'frisian', 'dnt': 25061, 'spouse': [578051], 'parents': [562370, 572787], 'rparents': [562370, 572787], 'generation': 3}}
#
#
#
# {'descendent': {'_id': 574506, 'bn': 'Helvis', 'fem': 1, 'b_d': datetime.datetime(870, 11, 20, 0, 0), 'd_d': datetime.datetime(924, 9, 3, 0, 0), 'lge': 590885, 'fat': 562370, 'mot': 572787, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [574787], 'parents': [562370, 572787], 'rparents': [562370, 572787], 'generation': 3}}
#
#
#
# {'descendent': {'_id': 562370, 'bn': 'Manassès', 'nick': 'nick_the_great', 'b_d': datetime.datetime(853, 3, 21, 0, 0), 'd_d': datetime.datetime(924, 11, 19, 0, 0), 'fat': 528641, 'mot': 540756, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [572787, 600018, 609278], 'parents': [528641, 540756], 'rparents': [528641, 540756], 'generation': 2}}
#
#
#
# {'descendent': {'_id': 548212, 'bn': 'Karl', 'b_d': datetime.datetime(832, 8, 25, 0, 0), 'd_d': datetime.datetime(856, 4, 1, 0, 0), 'c_d': 'death_trait', 'lge': 540529, 'fat': 514936, 'mot': 536231, 'cul': 'old_frankish', 'dnt': 10290924, 'parents': [514936, 536231], 'rparents': [514936, 536231], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 547004, 'bn': 'Cumman', 'fem': 1, 'b_d': datetime.datetime(830, 11, 11, 0, 0), 'd_d': datetime.datetime(883, 11, 25, 0, 0), 'lge': 558756, 'fat': 514936, 'mot': 522546, 'dnt': 25061, 'spouse': [550312], 'parents': [514936, 522546], 'rparents': [514936, 522546], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 546220, 'bn': 'Eustadiola', 'fem': 1, 'b_d': datetime.datetime(829, 9, 10, 0, 0), 'd_d': datetime.datetime(885, 3, 25, 0, 0), 'lge': 542048, 'fat': 514936, 'mot': 544057, 'dnt': 25061, 'spouse': [544952], 'parents': [514936, 544057], 'rparents': [514936, 544057], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 545819, 'bn': 'Ermengarde', 'fem': 1, 'b_d': datetime.datetime(829, 2, 8, 0, 0), 'd_d': datetime.datetime(880, 4, 16, 0, 0), 'c_d': 'death_trait', 'lge': 556682, 'fat': 514936, 'mot': 537607, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [514936, 537607], 'rparents': [514936, 537607], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 544872, 'bn': 'Ragno', 'b_d': datetime.datetime(827, 9, 17, 0, 0), 'd_d': datetime.datetime(844, 1, 21, 0, 0), 'c_d': 'death_trait', 'lge': 528641, 'fat': 529737, 'rfat': 514936, 'mot': 527032, 'dnt': 25061, 'parents': [529737, 527032], 'rparents': [514936, 527032], 'generation': 2}}
#
#
#
# {'descendent': {'_id': 544164, 'bn': 'Berneri', 'b_d': datetime.datetime(826, 8, 17, 0, 0), 'd_d': datetime.datetime(862, 5, 1, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 529360, 'lge': 562370, 'fat': 529737, 'rfat': 514936, 'mot': 527032, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [542750], 'parents': [529737, 527032], 'rparents': [514936, 527032], 'generation': 2}}
#
#
#
# {'descendent': {'_id': 542242, 'bn': 'Ragambald', 'b_d': datetime.datetime(823, 8, 17, 0, 0), 'd_d': datetime.datetime(852, 7, 23, 0, 0), 'c_d': 'death_trait', 'lge': 528641, 'fat': 529737, 'mot': 527032, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [538505], 'parents': [529737, 527032], 'rparents': [529737, 527032], 'generation': 2}}
#
#
#
# {'descendent': {'_id': 541883, 'bn': 'Karl', 'b_d': datetime.datetime(823, 1, 21, 0, 0), 'd_d': datetime.datetime(830, 12, 18, 0, 0), 'c_d': 'death_murder_fall', 'killer': 517095, 'lge': 518940, 'fat': 516515, 'mot': 540112, 'dnt': 25061, 'parents': [516515, 540112], 'rparents': [516515, 540112], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 541336, 'bn': 'Goiswinth', 'fem': 1, 'b_d': datetime.datetime(822, 3, 2, 0, 0), 'd_d': datetime.datetime(843, 9, 13, 0, 0), 'c_d': 'death_childbirth', 'lge': 539205, 'fat': 514936, 'mot': 527032, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [539205], 'parents': [514936, 527032], 'rparents': [514936, 527032], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 535802, 'bn': 'Morberga', 'fem': 1, 'b_d': datetime.datetime(813, 7, 20, 0, 0), 'd_d': datetime.datetime(859, 6, 23, 0, 0), 'c_d': 'death_trait', 'lge': 560227, 'fat': 514936, 'mot': 525273, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [535219], 'parents': [514936, 525273], 'rparents': [514936, 525273], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 534136, 'bn': 'Engilbert', 'b_d': datetime.datetime(811, 3, 6, 0, 0), 'd_d': datetime.datetime(811, 5, 9, 0, 0), 'c_d': 'death_trait', 'lge': 516515, 'fat': 516515, 'mot': 522709, 'cul': 'saxon', 'dnt': 25061, 'parents': [516515, 522709], 'rparents': [516515, 522709], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 533280, 'bn': 'Ceslin', 'b_d': datetime.datetime(809, 11, 13, 0, 0), 'd_d': datetime.datetime(843, 4, 11, 0, 0), 'c_d': 'death_murder', 'killer': 514586, 'fat': 510022, 'mot': 527728, 'cul': 'frankish', 'dnt': 25061, 'spouse': [533489], 'parents': [510022, 527728], 'rparents': [510022, 527728], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 531797, 'bn': 'Gyrið', 'fem': 1, 'b_d': datetime.datetime(807, 10, 3, 0, 0), 'd_d': datetime.datetime(875, 6, 22, 0, 0), 'lge': 560064, 'fat': 514936, 'mot': 514586, 'cul': 'italian', 'dnt': 25061, 'spouse': [532697], 'parents': [514936, 514586], 'rparents': [514936, 514586], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 529737, 'bn': 'Karel', 'nick': 'nick_the_drunkard', 'b_d': datetime.datetime(804, 9, 3, 0, 0), 'd_d': datetime.datetime(864, 4, 6, 0, 0), 'fat': 514936, 'mot': 514586, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [527032, 555847], 'parents': [514936, 514586], 'rparents': [514936, 514586], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 528813, 'bn': 'Eleonora', 'fem': 1, 'b_d': datetime.datetime(803, 5, 13, 0, 0), 'd_d': datetime.datetime(871, 12, 6, 0, 0), 'c_d': 'death_trait', 'lge': 541095, 'fat': 510022, 'mot': 527728, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [527805], 'parents': [510022, 527728], 'rparents': [510022, 527728], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 528641, 'bn': 'Charles', 'nick': 'nick_the_monster', 'b_d': datetime.datetime(803, 2, 3, 0, 0), 'd_d': datetime.datetime(853, 11, 26, 0, 0), 'c_d': 'death_battle', 'killer': 554473, 'fat': 514936, 'mot': 514586, 'cul': 'italian', 'dnt': 25061, 'spouse': [517583, 540756], 'parents': [514936, 514586], 'rparents': [514936, 514586], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 525158, 'bn': 'Aude', 'fem': 1, 'b_d': datetime.datetime(798, 1, 17, 0, 0), 'd_d': datetime.datetime(865, 8, 19, 0, 0), 'lge': 539938, 'fat': 6392, 'rfat': 512975, 'mot': 524280, 'cul': 'frankish', 'dnt': 25061, 'spouse': [523815], 'parents': [6392, 524280], 'rparents': [512975, 524280], 'generation': 0}}
#
#
#
# {'descendent': {'_id': 523304, 'bn': 'Elisabeth', 'fem': 1, 'b_d': datetime.datetime(795, 4, 25, 0, 0), 'd_d': datetime.datetime(795, 6, 1, 0, 0), 'c_d': 'death_trait', 'lge': 6392, 'fat': 6392, 'mot': 509092, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
#
# {'descendent': {'_id': 522094, 'bn': 'Heilwiva', 'fem': 1, 'b_d': datetime.datetime(793, 5, 29, 0, 0), 'd_d': datetime.datetime(835, 6, 7, 0, 0), 'c_d': 'death_trait', 'lge': 528981, 'fat': 90094, 'rfat': 190512, 'mot': 511930, 'cul': 'old_frankish', 'dnt': 1044033, 'spouse': [521793, 528981], 'parents': [90094, 511930], 'rparents': [190512, 511930], 'generation': 1}}
#
#
#
# {'descendent': {'_id': 517169, 'bn': 'Theodelinda', 'fem': 1, 'b_d': datetime.datetime(784, 10, 25, 0, 0), 'd_d': datetime.datetime(848, 8, 10, 0, 0), 'c_d': 'death_trait', 'lge': 534463, 'fat': 6392, 'mot': 509092, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [520402], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
#
# {'descendent': {'_id': 516515, 'bn': 'Burchard', 'nick': 'nick_the_depraved', 'b_d': datetime.datetime(783, 7, 25, 0, 0), 'd_d': datetime.datetime(822, 9, 30, 0, 0), 'c_d': 'death_battle', 'killer': 540797, 'fat': 6392, 'mot': 509092, 'dnt': 25061, 'spouse': [522709, 540112], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
#
# {'descendent': {'_id': 514936, 'bn': 'Grimald', 'nick': 'nick_the_holy', 'b_d': datetime.datetime(780, 9, 25, 0, 0), 'd_d': datetime.datetime(832, 2, 1, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 525936, 'fat': 6392, 'mot': 509092, 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [514586], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
#
# {'descendent': {'_id': 510783, 'bn': 'Bertrada', 'fem': 1, 'b_d': datetime.datetime(774, 2, 25, 0, 0), 'd_d': datetime.datetime(840, 9, 8, 0, 0), 'c_d': 'death_trait', 'lge': 520610, 'fat': 6392, 'mot': 509092, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [520610], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
#
# {'descendent': {'_id': 510022, 'bn': 'Ceslin', 'b_d': datetime.datetime(773, 1, 25, 0, 0), 'd_d': datetime.datetime(809, 6, 11, 0, 0), 'c_d': 'death_battle', 'killer': 530445, 'fat': 6392, 'mot': 509092, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [527728], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
#
# {'descendent': {'_id': 508678, 'bn': 'Martinga', 'fem': 1, 'b_d': datetime.datetime(771, 3, 9, 0, 0), 'd_d': datetime.datetime(817, 9, 3, 0, 0), 'c_d': 'death_trait', 'lge': 510339, 'fat': 6392, 'mot': 190352, 'cul': 'lombard', 'dnt': 25061, 'spouse': [510377], 'parents': [6392, 190352], 'rparents': [6392, 190352], 'generation': 0}}
#
#
#
# {'descendent': {'_id': 90094, 'bn': 'Pepin', 'hist': 1, 'b_d': datetime.datetime(769, 1, 1, 0, 0), 'd_d': datetime.datetime(795, 11, 19, 0, 0), 'c_d': 'death_trait', 'lge': 511930, 'fat': 6392, 'mot': 194168, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [511930], 'parents': [6392, 194168], 'rparents': [6392, 194168], 'generation': 0}}
#
#
#
# {'descendent': {'_id': 194169, 'bn': 'Amaudru', 'hist': 1, 'fem': 1, 'b_d': datetime.datetime(767, 1, 1, 0, 0), 'd_d': datetime.datetime(821, 7, 18, 0, 0), 'c_d': 'death_trait', 'lge': 527132, 'fat': 6392, 'mot': 194168, 'dnt': 25061, 'spouse': [190229], 'parents': [6392, 194168], 'rparents': [6392, 194168], 'generation': 0}}

# %% [markdown]
# ## Find only descendents who have been killed

# %%
pipeline = [{
    "$match" : { "_id" : 6392}
},
    {
    
      "$graphLookup": {
      "from": "characters",
      "startWith": "$_id",
      "connectFromField": "_id",
      "connectToField": "fat",
      "as": "descendent",
      "depthField": "generation"
   }},
    {"$unwind" : "$descendent"},
    {"$sort" : { "descendent.b_d": -1 }},
    {"$match" : {"descendent.killer" : {"$exists" : True}}}, #Excludes all descendents who don't have the killer field set
    {"$project" : {"_id" : 0, "descendent" : 1}}
]

# %%
karl = characters.aggregate(pipeline)

# %%
for char in karl:
    print(char)
    print("\n")
# Out:
# {'descendent': {'_id': 1029240, 'bn': 'Tiburge', 'fem': 1, 'b_d': datetime.datetime(1440, 6, 12, 0, 0), 'd_d': datetime.datetime(1455, 5, 21, 0, 0), 'c_d': 'death_execution_eaten', 'killer': 1017458, 'lge': 1017458, 'fat': 1002826, 'rfat': 985060, 'mot': 995941, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [1002826, 995941], 'rparents': [985060, 995941], 'generation': 23}}
#
#
# {'descendent': {'_id': 1021195, 'bn': 'Åke', 'b_d': datetime.datetime(1431, 5, 1, 0, 0), 'd_d': datetime.datetime(1450, 4, 16, 0, 0), 'c_d': 'death_battle', 'killer': 1012771, 'lge': 1014184, 'fat': 994796, 'mot': 1008532, 'rel': 'catholic', 'cul': 'pictish', 'dnt': 9230, 'parents': [994796, 1008532], 'rparents': [994796, 1008532], 'generation': 22}}
#
#
# {'descendent': {'_id': 988272, 'bn': 'Ida', 'fem': 1, 'b_d': datetime.datetime(1392, 6, 4, 0, 0), 'd_d': datetime.datetime(1441, 5, 16, 0, 0), 'c_d': 'death_murder', 'killer': 980989, 'lge': 980989, 'fat': 970238, 'mot': 968635, 'cul': 'frankish', 'dnt': 25061, 'spouse': [980989], 'parents': [970238, 968635], 'rparents': [970238, 968635], 'generation': 23}}
#
#
# {'descendent': {'_id': 980272, 'bn': 'Josselin', 'b_d': datetime.datetime(1382, 10, 11, 0, 0), 'd_d': datetime.datetime(1400, 6, 7, 0, 0), 'c_d': 'death_battle', 'killer': 985660, 'lge': 970238, 'fat': 939803, 'mot': 963630, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [939803, 963630], 'rparents': [939803, 963630], 'generation': 21}}
#
#
# {'descendent': {'_id': 974979, 'bn': 'Erik', 'b_d': datetime.datetime(1376, 4, 18, 0, 0), 'd_d': datetime.datetime(1380, 7, 31, 0, 0), 'c_d': 'death_murder', 'killer': 952127, 'lge': 958043, 'fat': 958043, 'mot': 960753, 'rel': 'fraticelli', 'cul': 'saxon', 'dnt': 9230, 'parents': [958043, 960753], 'rparents': [958043, 960753], 'generation': 20}}
#
#
# {'descendent': {'_id': 970532, 'bn': 'Antoine', 'b_d': datetime.datetime(1370, 11, 17, 0, 0), 'd_d': datetime.datetime(1390, 7, 10, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 970238, 'lge': 970238, 'fat': 939803, 'mot': 948180, 'cul': 'frankish', 'dnt': 25061, 'parents': [939803, 948180], 'rparents': [939803, 948180], 'generation': 21}}
#
#
# {'descendent': {'_id': 969593, 'bn': 'Elisabeth', 'fem': 1, 'b_d': datetime.datetime(1369, 10, 8, 0, 0), 'd_d': datetime.datetime(1398, 6, 10, 0, 0), 'c_d': 'death_execution_eaten', 'killer': 957199, 'lge': 957199, 'fat': 938463, 'mot': 948003, 'cul': 'frankish', 'dnt': 25061, 'spouse': [975433], 'parents': [938463, 948003], 'rparents': [938463, 948003], 'generation': 21}}
#
#
# {'descendent': {'_id': 962613, 'bn': 'Folke', 'b_d': datetime.datetime(1361, 6, 14, 0, 0), 'd_d': datetime.datetime(1389, 3, 7, 0, 0), 'c_d': 'death_battle', 'killer': 983359, 'lge': 979011, 'fat': 942132, 'mot': 936165, 'rel': 'fraticelli', 'cul': 'saxon', 'dnt': 9230, 'spouse': [960621], 'parents': [942132, 936165], 'rparents': [942132, 936165], 'generation': 19}}
#
#
# {'descendent': {'_id': 958043, 'bn': 'Ulf', 'b_d': datetime.datetime(1356, 1, 14, 0, 0), 'd_d': datetime.datetime(1382, 7, 10, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 959150, 'lge': 953636, 'fat': 942132, 'mot': 936165, 'rel': 'fraticelli', 'cul': 'saxon', 'dnt': 9230, 'spouse': [960753], 'parents': [942132, 936165], 'rparents': [942132, 936165], 'generation': 19}}
#
#
# {'descendent': {'_id': 953636, 'bn': 'Charles', 'b_d': datetime.datetime(1350, 12, 15, 0, 0), 'd_d': datetime.datetime(1387, 7, 4, 0, 0), 'c_d': 'death_battle', 'killer': 945624, 'fat': 930715, 'mot': 921410, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [941846], 'parents': [930715, 921410], 'rparents': [930715, 921410], 'generation': 21}}
#
#
# {'descendent': {'_id': 942132, 'bn': 'Ioseph', 'nick': 'nick_the_fat', 'b_d': datetime.datetime(1337, 5, 14, 0, 0), 'd_d': datetime.datetime(1380, 4, 1, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 928432, 'lge': 953636, 'fat': 892219, 'mot': 909201, 'rel': 'catholic', 'cul': 'saxon', 'dnt': 9230, 'spouse': [936165, 952127], 'parents': [892219, 909201], 'rparents': [892219, 909201], 'generation': 18}}
#
#
# {'descendent': {'_id': 930715, 'bn': 'Aldéric', 'b_d': datetime.datetime(1323, 7, 14, 0, 0), 'd_d': datetime.datetime(1351, 1, 6, 0, 0), 'c_d': 'death_murder_unknown_snakes', 'killer': 939802, 'lge': 915400, 'fat': 915400, 'mot': 913709, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [921410], 'parents': [915400, 913709], 'rparents': [915400, 913709], 'generation': 20}}
#
#
# {'descendent': {'_id': 927396, 'bn': 'Constance', 'fem': 1, 'b_d': datetime.datetime(1319, 7, 11, 0, 0), 'd_d': datetime.datetime(1339, 6, 9, 0, 0), 'c_d': 'death_dungeon', 'killer': 892694, 'lge': 910580, 'fat': 910580, 'mot': 904858, 'cul': 'pictish', 'dnt': 25061, 'parents': [910580, 904858], 'rparents': [910580, 904858], 'generation': 20}}
#
#
# {'descendent': {'_id': 912912, 'bn': 'Stéphanie', 'fem': 1, 'b_d': datetime.datetime(1302, 3, 4, 0, 0), 'd_d': datetime.datetime(1349, 8, 9, 0, 0), 'c_d': 'death_execution_burning', 'killer': 883846, 'lge': 883846, 'fat': 883846, 'mot': 910115, 'cul': 'frankish', 'dnt': 25061, 'spouse': [911075], 'parents': [883846, 910115], 'rparents': [883846, 910115], 'generation': 19}}
#
#
# {'descendent': {'_id': 911075, 'bn': 'Renaud', 'b_d': datetime.datetime(1300, 1, 4, 0, 0), 'd_d': datetime.datetime(1333, 10, 11, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 916630, 'lge': 883846, 'fat': 891871, 'mot': 888555, 'cul': 'basque', 'dnt': 25061, 'spouse': [912912], 'parents': [891871, 888555], 'rparents': [891871, 888555], 'generation': 18}}
#
#
# {'descendent': {'_id': 904858, 'bn': 'Péronelle', 'fem': 1, 'b_d': datetime.datetime(1292, 6, 5, 0, 0), 'd_d': datetime.datetime(1347, 6, 30, 0, 0), 'c_d': 'death_execution_burning', 'killer': 906464, 'lge': 883846, 'fat': 871701, 'mot': 875452, 'cul': 'frankish', 'dnt': 25061, 'spouse': [871707, 910580], 'parents': [871701, 875452], 'rparents': [871701, 875452], 'generation': 18}}
#
#
# {'descendent': {'_id': 893874, 'bn': 'Aldéric', 'b_d': datetime.datetime(1279, 10, 5, 0, 0), 'd_d': datetime.datetime(1322, 7, 7, 0, 0), 'c_d': 'death_murder_poison', 'killer': 898653, 'lge': 906464, 'fat': 871701, 'mot': 875452, 'cul': 'frankish', 'dnt': 25061, 'spouse': [890460, 896519, 912582], 'parents': [871701, 875452], 'rparents': [871701, 875452], 'generation': 18}}
#
#
# {'descendent': {'_id': 883577, 'bn': 'Richard', 'b_d': datetime.datetime(1267, 5, 1, 0, 0), 'd_d': datetime.datetime(1310, 8, 15, 0, 0), 'c_d': 'death_battle', 'killer': 884622, 'lge': 892694, 'fat': 860123, 'mot': 862680, 'cul': 'saxon', 'dnt': 315, 'spouse': [913602], 'parents': [860123, 862680], 'rparents': [860123, 862680], 'generation': 17}}
#
#
# {'descendent': {'_id': 878276, 'bn': 'Guilhem', 'b_d': datetime.datetime(1260, 7, 15, 0, 0), 'd_d': datetime.datetime(1277, 5, 14, 0, 0), 'c_d': 'death_battle', 'killer': 851198, 'lge': 869263, 'fat': 837979, 'mot': 853930, 'dnt': 315, 'spouse': [870033], 'parents': [837979, 853930], 'rparents': [837979, 853930], 'generation': 16}}
#
#
# {'descendent': {'_id': 869407, 'bn': 'Raimbaut', 'b_d': datetime.datetime(1249, 9, 23, 0, 0), 'd_d': datetime.datetime(1267, 5, 8, 0, 0), 'c_d': 'death_dungeon', 'killer': 845225, 'lge': 845225, 'fat': 851682, 'mot': 864774, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [851682, 864774], 'rparents': [851682, 864774], 'generation': 16}}
#
#
# {'descendent': {'_id': 860123, 'bn': 'Yves', 'b_d': datetime.datetime(1238, 3, 1, 0, 0), 'd_d': datetime.datetime(1302, 12, 3, 0, 0), 'c_d': 'death_battle', 'killer': 907988, 'lge': 892694, 'fat': 846255, 'mot': 843724, 'dnt': 315, 'spouse': [862680], 'parents': [846255, 843724], 'rparents': [846255, 843724], 'generation': 16}}
#
#
# {'descendent': {'_id': 853232, 'bn': 'Othon', 'b_d': datetime.datetime(1229, 11, 18, 0, 0), 'd_d': datetime.datetime(1255, 3, 8, 0, 0), 'c_d': 'death_murder', 'killer': 855519, 'lge': 837979, 'fat': 837979, 'mot': 819236, 'cul': 'german', 'dnt': 315, 'spouse': [847213], 'parents': [837979, 819236], 'rparents': [837979, 819236], 'generation': 16}}
#
#
# {'descendent': {'_id': 853238, 'bn': 'Aude', 'fem': 1, 'b_d': datetime.datetime(1229, 11, 18, 0, 0), 'd_d': datetime.datetime(1257, 1, 23, 0, 0), 'c_d': 'death_dungeon', 'killer': 850817, 'lge': 825882, 'fat': 837979, 'mot': 836134, 'dnt': 315, 'spouse': [852604], 'parents': [837979, 836134], 'rparents': [837979, 836134], 'generation': 16}}
#
#
# {'descendent': {'_id': 850094, 'bn': 'Aldéric', 'b_d': datetime.datetime(1225, 10, 25, 0, 0), 'd_d': datetime.datetime(1279, 8, 15, 0, 0), 'c_d': 'death_dungeon', 'killer': 876347, 'lge': 845225, 'fat': 816195, 'mot': 835152, 'cul': 'frankish', 'dnt': 25061, 'parents': [816195, 835152], 'rparents': [816195, 835152], 'generation': 16}}
#
#
# {'descendent': {'_id': 840184, 'bn': 'Amédée', 'nick': 'nick_the_chaste', 'b_d': datetime.datetime(1213, 10, 15, 0, 0), 'd_d': datetime.datetime(1258, 7, 17, 0, 0), 'c_d': 'death_dungeon', 'killer': 837979, 'lge': 837979, 'fat': 821891, 'mot': 817838, 'cul': 'saxon', 'dnt': 315, 'spouse': [839524], 'parents': [821891, 817838], 'rparents': [821891, 817838], 'generation': 15}}
#
#
# {'descendent': {'_id': 837491, 'bn': 'Aliénor', 'fem': 1, 'b_d': datetime.datetime(1210, 7, 14, 0, 0), 'd_d': datetime.datetime(1253, 7, 25, 0, 0), 'c_d': 'death_battle', 'killer': 854647, 'lge': 834333, 'fat': 807955, 'mot': 807673, 'dnt': 10297032, 'spouse': [837143, 848941], 'parents': [807955, 807673], 'rparents': [807955, 807673], 'generation': 15}}
#
#
# {'descendent': {'_id': 829976, 'bn': 'Almodis', 'fem': 1, 'b_d': datetime.datetime(1201, 2, 9, 0, 0), 'd_d': datetime.datetime(1242, 9, 1, 0, 0), 'c_d': 'death_dungeon', 'killer': 830095, 'lge': 830095, 'fat': 800653, 'mot': 798848, 'cul': 'saxon', 'dnt': 315, 'spouse': [810986, 823404], 'parents': [800653, 798848], 'rparents': [800653, 798848], 'generation': 14}}
#
#
# {'descendent': {'_id': 823922, 'bn': 'Evrard', 'b_d': datetime.datetime(1193, 7, 25, 0, 0), 'd_d': datetime.datetime(1259, 11, 7, 0, 0), 'c_d': 'death_murder_unknown_drowning', 'killer': 855519, 'lge': 837979, 'fat': 804220, 'mot': 791416, 'cul': 'saxon', 'dnt': 315, 'spouse': [836497], 'parents': [804220, 791416], 'rparents': [804220, 791416], 'generation': 14}}
#
#
# {'descendent': {'_id': 823610, 'bn': 'Othon', 'nick': 'nick_the_hammer', 'b_d': datetime.datetime(1193, 3, 9, 0, 0), 'd_d': datetime.datetime(1225, 1, 1, 0, 0), 'c_d': 'death_murder_unknown_butchered', 'killer': 804615, 'fat': 800653, 'mot': 798848, 'dnt': 315, 'spouse': [822046], 'parents': [800653, 798848], 'rparents': [800653, 798848], 'generation': 14}}
#
#
# {'descendent': {'_id': 821891, 'bn': 'Bertrand', 'b_d': datetime.datetime(1191, 2, 25, 0, 0), 'd_d': datetime.datetime(1236, 12, 26, 0, 0), 'c_d': 'death_battle', 'killer': 841034, 'lge': 837979, 'fat': 804220, 'mot': 791416, 'cul': 'saxon', 'dnt': 315, 'spouse': [817838], 'parents': [804220, 791416], 'rparents': [804220, 791416], 'generation': 14}}
#
#
# {'descendent': {'_id': 814373, 'bn': 'Aymar', 'b_d': datetime.datetime(1182, 2, 23, 0, 0), 'd_d': datetime.datetime(1207, 5, 1, 0, 0), 'c_d': 'death_execution_burning', 'killer': 810575, 'lge': 810575, 'fat': 794976, 'mot': 797294, 'cul': 'frankish', 'dnt': 25061, 'spouse': [810575], 'parents': [794976, 797294], 'rparents': [794976, 797294], 'generation': 15}}
#
#
# {'descendent': {'_id': 810694, 'bn': 'Ogier', 'b_d': datetime.datetime(1177, 10, 6, 0, 0), 'd_d': datetime.datetime(1215, 11, 14, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 816195, 'lge': 823610, 'fat': 789804, 'mot': 785069, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [811865, 797727, 818853], 'parents': [789804, 785069], 'rparents': [789804, 785069], 'generation': 15}}
#
#
# {'descendent': {'_id': 805195, 'bn': 'Nicolas', 'b_d': datetime.datetime(1171, 5, 14, 0, 0), 'd_d': datetime.datetime(1195, 11, 8, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 785069, 'lge': 789804, 'fat': 769421, 'mot': 778469, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [801746], 'parents': [769421, 778469], 'rparents': [769421, 778469], 'generation': 14}}
#
#
# {'descendent': {'_id': 804220, 'bn': 'Amédée', 'b_d': datetime.datetime(1170, 4, 5, 0, 0), 'd_d': datetime.datetime(1205, 10, 5, 0, 0), 'c_d': 'death_dungeon', 'killer': 823610, 'lge': 823610, 'fat': 767775, 'mot': 777480, 'cul': 'saxon', 'dnt': 315, 'spouse': [791416], 'parents': [767775, 777480], 'rparents': [767775, 777480], 'generation': 13}}
#
#
# {'descendent': {'_id': 795095, 'bn': 'Benoît', 'b_d': datetime.datetime(1159, 6, 25, 0, 0), 'd_d': datetime.datetime(1184, 9, 19, 0, 0), 'c_d': 'death_battle', 'killer': 804389, 'fat': 751957, 'mot': 779292, 'cul': 'frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [783043], 'parents': [751957, 779292], 'rparents': [751957, 779292], 'generation': 12}}
#
#
# {'descendent': {'_id': 792222, 'bn': 'Aldéric', 'b_d': datetime.datetime(1155, 12, 19, 0, 0), 'd_d': datetime.datetime(1185, 6, 10, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 796246, 'lge': 785362, 'fat': 762921, 'mot': 772398, 'cul': 'old_frankish', 'dnt': 10297032, 'spouse': [780979], 'parents': [762921, 772398], 'rparents': [762921, 772398], 'generation': 13}}
#
#
# {'descendent': {'_id': 786761, 'bn': 'Ebbon', 'b_d': datetime.datetime(1149, 4, 15, 0, 0), 'd_d': datetime.datetime(1156, 9, 18, 0, 0), 'c_d': 'death_execution_eaten', 'killer': 765342, 'lge': 765342, 'fat': 759652, 'mot': 771330, 'cul': 'frankish', 'dnt': 25061, 'parents': [759652, 771330], 'rparents': [759652, 771330], 'generation': 13}}
#
#
# {'descendent': {'_id': 772295, 'bn': 'Mascarose', 'fem': 1, 'b_d': datetime.datetime(1131, 8, 4, 0, 0), 'd_d': datetime.datetime(1156, 8, 9, 0, 0), 'c_d': 'death_execution_eaten', 'killer': 765342, 'lge': 765342, 'fat': 747196, 'mot': 748891, 'cul': 'pictish', 'dnt': 25061, 'parents': [747196, 748891], 'rparents': [747196, 748891], 'generation': 13}}
#
#
# {'descendent': {'_id': 769300, 'bn': 'Édouard', 'b_d': datetime.datetime(1127, 10, 5, 0, 0), 'd_d': datetime.datetime(1151, 12, 1, 0, 0), 'c_d': 'death_dungeon', 'killer': 746254, 'lge': 747216, 'fat': 748630, 'rfat': 764997, 'mot': 747216, 'cul': 'frankish', 'dnt': 25061, 'parents': [748630, 747216], 'rparents': [764997, 747216], 'generation': 12}}
#
#
# {'descendent': {'_id': 747196, 'bn': 'Aymar', 'b_d': datetime.datetime(1100, 5, 21, 0, 0), 'd_d': datetime.datetime(1155, 5, 17, 0, 0), 'c_d': 'death_dungeon', 'killer': 756608, 'lge': 756608, 'fat': 732807, 'mot': 732388, 'cul': 'pictish', 'dnt': 25061, 'spouse': [748891], 'parents': [732807, 732388], 'rparents': [732807, 732388], 'generation': 12}}
#
#
# {'descendent': {'_id': 734914, 'bn': 'Arnaud', 'b_d': datetime.datetime(1085, 1, 12, 0, 0), 'd_d': datetime.datetime(1108, 10, 17, 0, 0), 'c_d': 'death_rabble', 'killer': 752805, 'lge': 706174, 'fat': 717483, 'mot': 712891, 'cul': 'saxon', 'dnt': 25061, 'parents': [717483, 712891], 'rparents': [717483, 712891], 'generation': 11}}
#
#
# {'descendent': {'_id': 734449, 'bn': 'Édouard', 'b_d': datetime.datetime(1084, 6, 10, 0, 0), 'd_d': datetime.datetime(1128, 3, 10, 0, 0), 'c_d': 'death_dungeon', 'killer': 746302, 'lge': 746302, 'fat': 704710, 'mot': 708437, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [734268, 740424, 730506], 'parents': [704710, 708437], 'rparents': [704710, 708437], 'generation': 10}}
#
#
# {'descendent': {'_id': 732807, 'bn': 'Aymar', 'nick': 'nick_the_holy', 'b_d': datetime.datetime(1082, 6, 7, 0, 0), 'd_d': datetime.datetime(1131, 12, 30, 0, 0), 'c_d': 'death_battle', 'killer': 759268, 'fat': 717483, 'mot': 718010, 'cul': 'frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [732388], 'parents': [717483, 718010], 'rparents': [717483, 718010], 'generation': 11}}
#
#
# {'descendent': {'_id': 729069, 'bn': 'Thibault', 'b_d': datetime.datetime(1077, 12, 7, 0, 0), 'd_d': datetime.datetime(1110, 10, 5, 0, 0), 'c_d': 'death_battle', 'killer': 708614, 'lge': 724104, 'fat': 715693, 'mot': 713838, 'cul': 'frankish', 'dnt': 25061, 'spouse': [735483], 'parents': [715693, 713838], 'rparents': [715693, 713838], 'generation': 10}}
#
#
# {'descendent': {'_id': 727264, 'bn': 'Antoine', 'nick': 'nick_the_wise', 'b_d': datetime.datetime(1075, 10, 15, 0, 0), 'd_d': datetime.datetime(1105, 10, 15, 0, 0), 'c_d': 'death_battle', 'killer': 748004, 'lge': 743151, 'fat': 701852, 'mot': 708162, 'cul': 'old_frankish', 'dnt': 315, 'spouse': [727128], 'parents': [701852, 708162], 'rparents': [701852, 708162], 'generation': 10}}
#
#
# {'descendent': {'_id': 722875, 'bn': 'Amédée', 'b_d': datetime.datetime(1070, 3, 13, 0, 0), 'd_d': datetime.datetime(1092, 6, 20, 0, 0), 'c_d': 'death_murder_unknown_poison', 'killer': 708445, 'lge': 686906, 'fat': 705834, 'mot': 697968, 'cul': 'old_frankish', 'dnt': 25061, 'parents': [705834, 697968], 'rparents': [705834, 697968], 'generation': 10}}
#
#
# {'descendent': {'_id': 720459, 'bn': 'Clotaire', 'b_d': datetime.datetime(1067, 1, 19, 0, 0), 'd_d': datetime.datetime(1112, 5, 14, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 730556, 'lge': 717060, 'fat': 698612, 'mot': 699710, 'rel': 'cathar', 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [738314], 'parents': [698612, 699710], 'rparents': [698612, 699710], 'generation': 10}}
#
#
# {'descendent': {'_id': 713180, 'bn': 'André', 'b_d': datetime.datetime(1057, 12, 19, 0, 0), 'd_d': datetime.datetime(1076, 5, 9, 0, 0), 'c_d': 'death_battle', 'killer': 700873, 'lge': 712365, 'fat': 698612, 'mot': 699710, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [708710], 'parents': [698612, 699710], 'rparents': [698612, 699710], 'generation': 10}}
#
#
# {'descendent': {'_id': 712365, 'bn': 'Pierre', 'b_d': datetime.datetime(1056, 12, 9, 0, 0), 'd_d': datetime.datetime(1076, 11, 22, 0, 0), 'c_d': 'death_battle', 'killer': 725220, 'fat': 694313, 'mot': 697208, 'cul': 'frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [706856], 'parents': [694313, 697208], 'rparents': [694313, 697208], 'generation': 10}}
#
#
# {'descendent': {'_id': 701852, 'bn': 'Bernard', 'b_d': datetime.datetime(1043, 3, 2, 0, 0), 'd_d': datetime.datetime(1076, 1, 13, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 702740, 'lge': 688200, 'fat': 676136, 'rfat': 699315, 'mot': 676160, 'cul': 'frankish', 'dnt': 25061, 'spouse': [694089, 708162], 'parents': [676136, 676160], 'rparents': [699315, 676160], 'generation': 9}}
#
#
# {'descendent': {'_id': 697450, 'bn': 'Jacques', 'b_d': datetime.datetime(1037, 6, 18, 0, 0), 'd_d': datetime.datetime(1067, 11, 27, 0, 0), 'c_d': 'death_murder_unknown_fall', 'killer': 704710, 'lge': 704710, 'fat': 669002, 'mot': 676945, 'cul': 'lombard', 'dnt': 25061, 'spouse': [684738, 700538], 'parents': [669002, 676945], 'rparents': [669002, 676945], 'generation': 9}}
#
#
# {'descendent': {'_id': 679800, 'bn': 'Archambaud', 'b_d': datetime.datetime(1013, 2, 25, 0, 0), 'd_d': datetime.datetime(1034, 6, 5, 0, 0), 'c_d': 'death_battle', 'killer': 675954, 'lge': 669817, 'fat': 649153, 'mot': 651556, 'cul': 'occitan', 'dnt': 25061, 'parents': [649153, 651556], 'rparents': [649153, 651556], 'generation': 8}}
#
#
# {'descendent': {'_id': 645195, 'bn': 'Ingfrid', 'fem': 1, 'b_d': datetime.datetime(972, 12, 11, 0, 0), 'd_d': datetime.datetime(1009, 11, 12, 0, 0), 'c_d': 'death_rabble', 'killer': 674193, 'lge': 642485, 'fat': 632840, 'mot': 629758, 'cul': 'saxon', 'dnt': 25061, 'spouse': [642485], 'parents': [632840, 629758], 'rparents': [632840, 629758], 'generation': 7}}
#
#
# {'descendent': {'_id': 638216, 'bn': 'Agathe', 'fem': 1, 'b_d': datetime.datetime(963, 1, 11, 0, 0), 'd_d': datetime.datetime(997, 5, 13, 0, 0), 'c_d': 'death_dungeon', 'killer': 635355, 'lge': 635355, 'fat': 591244, 'mot': 613994, 'cul': 'old_saxon', 'dnt': 25061, 'spouse': [635355], 'parents': [591244, 613994], 'rparents': [591244, 613994], 'generation': 5}}
#
#
# {'descendent': {'_id': 610811, 'bn': 'Raynaud', 'nick': 'nick_the_monster', 'b_d': datetime.datetime(924, 2, 1, 0, 0), 'd_d': datetime.datetime(945, 12, 16, 0, 0), 'c_d': 'death_battle', 'killer': 620647, 'fat': 562370, 'rfat': 579771, 'mot': 600018, 'cul': 'german', 'dnt': 25061, 'spouse': [609767], 'parents': [562370, 600018], 'rparents': [579771, 600018], 'generation': 3}}
#
#
# {'descendent': {'_id': 577938, 'bn': 'Reinoud', 'b_d': datetime.datetime(875, 10, 20, 0, 0), 'd_d': datetime.datetime(901, 3, 8, 0, 0), 'c_d': 'death_duel', 'killer': 576020, 'lge': 562370, 'fat': 562370, 'mot': 572787, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [569064, 581216], 'parents': [562370, 572787], 'rparents': [562370, 572787], 'generation': 3}}
#
#
# {'descendent': {'_id': 575971, 'bn': 'Margareta', 'fem': 1, 'b_d': datetime.datetime(873, 1, 20, 0, 0), 'd_d': datetime.datetime(893, 8, 13, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 569502, 'lge': 569502, 'fat': 562370, 'mot': 572787, 'cul': 'frisian', 'dnt': 25061, 'spouse': [578051], 'parents': [562370, 572787], 'rparents': [562370, 572787], 'generation': 3}}
#
#
# {'descendent': {'_id': 544164, 'bn': 'Berneri', 'b_d': datetime.datetime(826, 8, 17, 0, 0), 'd_d': datetime.datetime(862, 5, 1, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 529360, 'lge': 562370, 'fat': 529737, 'rfat': 514936, 'mot': 527032, 'cul': 'old_frankish', 'dnt': 25061, 'spouse': [542750], 'parents': [529737, 527032], 'rparents': [514936, 527032], 'generation': 2}}
#
#
# {'descendent': {'_id': 541883, 'bn': 'Karl', 'b_d': datetime.datetime(823, 1, 21, 0, 0), 'd_d': datetime.datetime(830, 12, 18, 0, 0), 'c_d': 'death_murder_fall', 'killer': 517095, 'lge': 518940, 'fat': 516515, 'mot': 540112, 'dnt': 25061, 'parents': [516515, 540112], 'rparents': [516515, 540112], 'generation': 1}}
#
#
# {'descendent': {'_id': 533280, 'bn': 'Ceslin', 'b_d': datetime.datetime(809, 11, 13, 0, 0), 'd_d': datetime.datetime(843, 4, 11, 0, 0), 'c_d': 'death_murder', 'killer': 514586, 'fat': 510022, 'mot': 527728, 'cul': 'frankish', 'dnt': 25061, 'spouse': [533489], 'parents': [510022, 527728], 'rparents': [510022, 527728], 'generation': 1}}
#
#
# {'descendent': {'_id': 528641, 'bn': 'Charles', 'nick': 'nick_the_monster', 'b_d': datetime.datetime(803, 2, 3, 0, 0), 'd_d': datetime.datetime(853, 11, 26, 0, 0), 'c_d': 'death_battle', 'killer': 554473, 'fat': 514936, 'mot': 514586, 'cul': 'italian', 'dnt': 25061, 'spouse': [517583, 540756], 'parents': [514936, 514586], 'rparents': [514936, 514586], 'generation': 1}}
#
#
# {'descendent': {'_id': 516515, 'bn': 'Burchard', 'nick': 'nick_the_depraved', 'b_d': datetime.datetime(783, 7, 25, 0, 0), 'd_d': datetime.datetime(822, 9, 30, 0, 0), 'c_d': 'death_battle', 'killer': 540797, 'fat': 6392, 'mot': 509092, 'dnt': 25061, 'spouse': [522709, 540112], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
# {'descendent': {'_id': 514936, 'bn': 'Grimald', 'nick': 'nick_the_holy', 'b_d': datetime.datetime(780, 9, 25, 0, 0), 'd_d': datetime.datetime(832, 2, 1, 0, 0), 'c_d': 'death_murder_unknown', 'killer': 525936, 'fat': 6392, 'mot': 509092, 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [514586], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}
#
#
# {'descendent': {'_id': 510022, 'bn': 'Ceslin', 'b_d': datetime.datetime(773, 1, 25, 0, 0), 'd_d': datetime.datetime(809, 6, 11, 0, 0), 'c_d': 'death_battle', 'killer': 530445, 'fat': 6392, 'mot': 509092, 'cul': 'old_frankish', 'dnt': 25061, 'spawned_bastards': 1, 'spouse': [527728], 'parents': [6392, 509092], 'rparents': [6392, 509092], 'generation': 0}}

# %% [markdown]
# ## Dynasties Married Into By Direct Descendents

# %% [markdown]
# This cell groups the dynasties that Charlemagne's descendents have married into. This would be his children, his grandchildren through his sons, his great grandchildren through his grandsons etc. Most marriages have been within the family (this is double counted?), the Alachisling dynasty would rule France and Italy, the Abbonid's would also rule France and through their marriage into the Karling family the Irish Eóganacht-Locha Léin would very briefly rule Aquitaine.
#
# A list of all families to rule a Kingdom or Empire level title and the titles they held is shown in notebook 7.1 Titles per Dynasty.

# %%
pipeline = [{
    "$match" : { "_id" : 6392}
},
    {
    
      "$graphLookup": {
      "from": "characters",
      "startWith": "$_id",
      "connectFromField": "_id",
      "connectToField": "fat",
      "as": "descendent",
      "depthField": "generation"
   }},
    {"$unwind" : "$descendent"},
    {"$unwind" : "$descendent.spouse"},
    {"$lookup" :
     {
            "from" : "characters",
            "localField" : "descendent.spouse",
            "foreignField" : "_id",
            "as" : "spouse_data"
        }
    },
    {"$unwind" : "$spouse_data" },
    {"$lookup" :
     {
            "from" : "dynasties",
            "localField" : "spouse_data.dnt",
            "foreignField" : "_id",
            "as" : "spouse_dyn"
        }
    },
    {"$unwind" : "$spouse_dyn" },
    {
        "$group":
        {
            "_id" : "$spouse_dyn.name",
            "total" : {"$sum" : 1}
        }
    },
    {"$sort" : { "total" : -1 } },
    #{"$limit" : 10}
]

# %%
karl = characters.aggregate(pipeline)
for char in karl:
    print(char)
# Out:
# {'_id': 'Karling', 'total': 49}
# {'_id': 'du Perche', 'total': 26}
# {'_id': 'Vuodi', 'total': 14}
# {'_id': 'de Preuilly', 'total': 12}
# {'_id': 'Alachisling', 'total': 11}
# {'_id': 'de Trith', 'total': 9}
# {'_id': 'de Flotte', 'total': 9}
# {'_id': 'Ulfing', 'total': 9}
# {'_id': 'Abbonid', 'total': 9}
# {'_id': 'Eóganacht-Locha Léin', 'total': 9}
# {'_id': 'de Lagery', 'total': 8}
# {'_id': 'Nibelunging', 'total': 6}
# {'_id': 'Uuidoch', 'total': 6}
# {'_id': 'de Lyon', 'total': 5}
# {'_id': 'de Soissons', 'total': 5}
# {'_id': 'Rorgonides', 'total': 4}
# {'_id': 'de Lusignan', 'total': 4}
# {'_id': 'de Hainault', 'total': 4}
# {'_id': 'Cerdicing', 'total': 3}
# {'_id': "de l'Aigle", 'total': 3}
# {'_id': 'Munichingi', 'total': 3}
# {'_id': 'Erenolding', 'total': 3}
# {'_id': 'de Chaumontois', 'total': 3}
# {'_id': 'Capet', 'total': 3}
# {'_id': 'Mel', 'total': 3}
# {'_id': 'Emichid', 'total': 3}
# {'_id': 'de Namur', 'total': 3}
# {'_id': 'Ua Flaithbertaig', 'total': 3}
# {'_id': 'Iceling', 'total': 3}
# {'_id': 'Khunzakhal', 'total': 3}
# {'_id': 'Agilolfing', 'total': 2}
# {'_id': 'of Northumbria', 'total': 2}
# {'_id': 'Unruochinger', 'total': 2}
# {'_id': 'de Bourgogne', 'total': 2}
# {'_id': 'de Sarvay', 'total': 2}
# {'_id': 'Fergant', 'total': 2}
# {'_id': 'Hahilinga', 'total': 2}
# {'_id': 'de Sémur-en-Brionnais', 'total': 2}
# {'_id': 'de Baalun', 'total': 2}
# {'_id': 'de Foix', 'total': 2}
# {'_id': "d'Avesnes", 'total': 2}
# {'_id': 'de Mauléon', 'total': 2}
# {'_id': 'a Korsun', 'total': 2}
# {'_id': 'Gautske', 'total': 2}
# {'_id': 'de Vannes', 'total': 2}
# {'_id': 'Liutprandingi', 'total': 2}
# {'_id': 'von Beilstein', 'total': 2}
# {'_id': 'Mac Finnachta', 'total': 1}
# {'_id': 'af Meaux', 'total': 1}
# {'_id': 'Galbaio', 'total': 1}
# {'_id': 'de Gontaut', 'total': 1}
# {'_id': 'de Roucy', 'total': 1}
# {'_id': 'Leon', 'total': 1}
# {'_id': 'Gwerthrynion', 'total': 1}
# {'_id': 'Kundaçiqid', 'total': 1}
# {'_id': 'Taillefer', 'total': 1}
# {'_id': 'de Burgh', 'total': 1}
# {'_id': 'Roding', 'total': 1}
# {'_id': 'de la Rochefoucauld', 'total': 1}
# {'_id': "de Montfort-l'Amaury", 'total': 1}
# {'_id': 'de Joigny', 'total': 1}
# {'_id': 'Hästesko', 'total': 1}
# {'_id': 'Herja', 'total': 1}
# {'_id': "d'Avaugour", 'total': 1}
# {'_id': 'Liutfredingi', 'total': 1}
# {'_id': 'Flod', 'total': 1}
# {'_id': 'Sorrenti', 'total': 1}
# {'_id': 'Çatn', 'total': 1}
# {'_id': 'of Burgundy', 'total': 1}
# {'_id': 'Mac Máil na mBó', 'total': 1}
# {'_id': 'Toki', 'total': 1}
# {'_id': 'von Neuenburg', 'total': 1}
# {'_id': 'de Warwick', 'total': 1}
# {'_id': 'de Taunton', 'total': 1}
# {'_id': 'de Montlhéry', 'total': 1}
# {'_id': "d'Urgell", 'total': 1}
# {'_id': 'Clifford', 'total': 1}
# {'_id': 'de Trainel', 'total': 1}
# {'_id': 'de Chalon', 'total': 1}
# {'_id': 'Walpertingi', 'total': 1}
# {'_id': 'de Bruyeres', 'total': 1}
# {'_id': 'Rhos', 'total': 1}
# {'_id': 'Neapolites', 'total': 1}
# {'_id': 'Hrafn', 'total': 1}
# {'_id': 'Svan', 'total': 1}
# {'_id': 'Theodingi', 'total': 1}
# {'_id': 'Yeçtirekid', 'total': 1}
# {'_id': 'Maudit', 'total': 1}
# {'_id': 'Fromonides', 'total': 1}
# {'_id': 'des Roches', 'total': 1}
# {'_id': 'de la Tour du Pin', 'total': 1}
# {'_id': 'Bukhal', 'total': 1}
# {'_id': 'de Carolui', 'total': 1}
# {'_id': 'de Menou', 'total': 1}
# {'_id': 'af Finnmark', 'total': 1}
# {'_id': "d'Éolienne", 'total': 1}
# {'_id': 'Carew', 'total': 1}
# {'_id': 'Adelards', 'total': 1}
# {'_id': 'de Chacim', 'total': 1}
# {'_id': 'Petringi', 'total': 1}
# {'_id': 'de Lévis', 'total': 1}
# {'_id': 'Wechtaringi', 'total': 1}
# {'_id': 'of Durham', 'total': 1}
# {'_id': 'de Mortemart', 'total': 1}
# {'_id': 'de Trier', 'total': 1}
# {'_id': 'Griphuvud', 'total': 1}
# {'_id': 'Jerome-Karling', 'total': 1}
# {'_id': 'de Comps', 'total': 1}
# {'_id': 'Yantsukh', 'total': 1}
# {'_id': 'Läma', 'total': 1}
# {'_id': 'Mochnant', 'total': 1}
# {'_id': 'Crwthor', 'total': 1}
# {'_id': 'Baugulfson', 'total': 1}
# {'_id': 'Morgannwg', 'total': 1}
# {'_id': 'Caliu', 'total': 1}
# {'_id': 'de Fenouillet', 'total': 1}
# {'_id': 'Paldoling', 'total': 1}
# {'_id': 'de Rodez', 'total': 1}
# {'_id': 'af Munsö', 'total': 1}
# {'_id': 'Rzewuski', 'total': 1}
# {'_id': 'af Uusimaa', 'total': 1}
