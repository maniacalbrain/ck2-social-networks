# %%
from pymongo import MongoClient
import pandas as pd
import datetime

# %%
client = MongoClient()
characters = client.ck2.characters

# %% [markdown]
# ## Descendents of Charlemagne

# %% [markdown]
# Same calculation as in notebook 2 but now including all descendents through female descendents as well by using the parents array ([fat, mot]) instead of just the fat value for connectToField. Over the 26 generations found in notebook 2 there are 48,000 characters that claim descent from Charlemagne.

# %%
pipeline = [
    {
        "$match" : {"_id" : 6392}
    },      
    {
        "$graphLookup": 
        {
            "from": "characters",
            "startWith": "$_id",
            "connectFromField": "_id",
            "connectToField": "parents",
            "as": "descendent"
        }},
    {"$project" : { "bn" : 1, "descendents" : {"$size" : "$descendent"} }    }
]

# %%
karl = characters.aggregate(pipeline)

# %%
for char in karl:
    print(char)
# Out:
# {'_id': 6392, 'bn': 'Charles', 'descendents': 48501}

# %% [markdown]
# ## Groupby Family

# %% [markdown]
# Most marriages by Charlemagne's descendents have been into the Alachisling dynasty. The Isauros rule Byzantium for a while before eventually losing power to the Kyritzios. The Uuidoch rule Scotland and briefly a crusade liberated Greece while the Penikis rise to power in Bulgaria, Finland and Russia. Charlemagne has many descendents and they marry into many of the most powerful houses in Europe.
#
# A list of all families to rule a Kingdom or Empire level title and the titles they held is shown in notebook 7.1 Titles per Dynasty.

# %%
pipeline = [
    {
        "$match" : {"_id" : 6392}
    },      
    {
        "$graphLookup": 
        {
            "from": "characters",
            "startWith": "$_id",
            "connectFromField": "_id",
            "connectToField": "parents",
            "as": "descendent",
            "depthField": "generation"
            #"maxDepth" : 1
        }
    },    
    {"$unwind" : "$descendent" },
    {"$lookup" :
     {
            "from" : "dynasties",
            "localField" : "descendent.dnt",
            "foreignField" : "_id",
            "as" : "descendent_dyn"
        }
    },
    {"$unwind" : "$descendent_dyn" },
    {
        "$group":
        {
            "_id" : "$descendent_dyn.name",
            "total" : {"$sum" : 1}
        }
    },
    {"$sort" : { "total" : -1 } },
    {"$limit" : 10}
]

# %%
karl = characters.aggregate(pipeline)
for char in karl:
    print(char)
# Out:
# {'_id': 'Alachisling', 'total': 728}
# {'_id': 'Isauros', 'total': 613}
# {'_id': 'Penikis', 'total': 506}
# {'_id': 'Abbasid', 'total': 488}
# {'_id': 'Uuidoch', 'total': 485}
# {'_id': 'Rangabes', 'total': 465}
# {'_id': 'Makrembolites', 'total': 451}
# {'_id': 'Palemonaitis', 'total': 447}
# {'_id': 'Kyritzios', 'total': 439}
# {'_id': 'Uzur', 'total': 366}

# %% [markdown]
# ## Real Descent

# %% [markdown]
# This cell uses the rparents value. Thus the rfat value will be used if it is set, if not the fat value will be set. The rfat value will be set where the character was born out of wedlock or their stated father isn't their real father. This calculation will drop any descendents, and their descendents, where their real father isn't a descendent of Charlemagne. It will include children who are descendents but are illegitimate don't know their true heritage.

# %%
pipeline = [
    {
        "$match" : {"_id" : 6392}
    },      
    {
        "$graphLookup": 
        {
            "from": "characters",
            "startWith": "$_id",
            "connectFromField": "_id",
            "connectToField": "rparents",
            "as": "descendent"
        }},
    {"$project" : { "bn" : 1, "descendents" : {"$size" : "$descendent"} }    }
]

# %%
for char in characters.aggregate(pipeline):
    print(char)
# Out:
# {'_id': 6392, 'bn': 'Charles', 'descendents': 49216}

# %% [markdown]
# # Real GroupBy Family

# %%
pipeline = [
    {
        "$match" : {"_id" : 6392}
    },      
    {
        "$graphLookup": 
        {
            "from": "characters",
            "startWith": "$_id",
            "connectFromField": "_id",
            "connectToField": "rparents",
            "as": "descendent",
            "depthField": "generation"
        }},    
    {"$unwind" : "$descendent" },
    {"$lookup" :
     {
            "from" : "dynasties",
            "localField" : "descendent.dnt",
            "foreignField" : "_id",
            "as" : "descendent_dyn"
        }
    },
    {"$unwind" : "$descendent_dyn" },
    {
        "$group":
        {
            "_id" : "$descendent_dyn.name",
            "total" : {"$sum" : 1}
        }
    },
    {"$sort" : { "total" : -1 } },
    {"$limit" : 10}
]

# %%
karl = characters.aggregate(pipeline)
for char in karl:
    print(char)
# Out:
# {'_id': 'Alachisling', 'total': 715}
# {'_id': 'Isauros', 'total': 610}
# {'_id': 'Penikis', 'total': 498}
# {'_id': 'Uuidoch', 'total': 487}
# {'_id': 'Abbasid', 'total': 478}
# {'_id': 'Rangabes', 'total': 459}
# {'_id': 'Makrembolites', 'total': 450}
# {'_id': 'Palemonaitis', 'total': 446}
# {'_id': 'Kyritzios', 'total': 428}
# {'_id': 'Kritopolos', 'total': 361}

# %% [markdown]
# # Shared Descendents

# %% [markdown]
# This is something I looked at only quickly. I take two characters, in this case Charlemagne and Cobthach Eóganacht-Locha Léin, Count of Thomond, died 789, and find all descendents that they have in common. In total Cobhtach has 14000 descendents so the two lines mearge early on. Both men share over 10000 descendents in common. Most of those descendents are members of the Scottish Uuidoch dynasty, but also of the Mel dynasty that forms England and the de Chaumontois rulers of Lotharingia.

# %%
pipeline = [
    {
        "$match" : {"_id" : 6392} #Charlemagne
    },      
    {
        "$graphLookup": 
        {
            "from": "characters",
            "startWith": "$_id",
            "connectFromField": "_id",
            "connectToField": "parents",
            "as": "descendent"
        }
    },
    {
        "$unwind" : "$descendent"
    },
    {
        "$project" : { "_id" : 0, "charId" : "$descendent._id" }
    }
]

# %%
char1 = set()

for karl in characters.aggregate(pipeline):
    char1.add(karl["charId"])

# %%
pipeline = [
    {
        "$match" : {"_id" : 83791} #Cobthach Count of Thomond 745-789
    },      
    {
        "$graphLookup": 
        {
            "from": "characters",
            "startWith": "$_id",
            "connectFromField": "_id",
            "connectToField": "parents",
            "as": "descendent"
        }
    },
    {
        "$unwind" : "$descendent"
    },
    {
        "$project" : { "_id" : 0, "charId" : "$descendent._id" }
    }
]

# %%
char2 = set()

for karl in characters.aggregate(pipeline):
    char2.add(karl["charId"])

# %%
comb = char1.intersection(char2)
len(comb)
# Out:
# 10414

# %%
pipeline = [
    {
        "$match" : {"_id" : {"$in" : list(comb)}}
    },      
    {
        "$lookup": 
        {
            "from": "dynasties",
            "localField": "dnt",
            "foreignField": "_id",
            "as": "dynasty"
        }
    },
    {
        "$unwind" : "$dynasty"
    },
    {
       "$group" : { "_id" : "$dynasty._id", "name" : {"$first" : "$dynasty.name"}, "total" : {"$sum" : 1} }
    },
    {
        "$sort" : {"total" : -1}
    }
]

# %%
for karl in characters.aggregate(pipeline):
    print(karl)
# Out:
# {'_id': 1040016, 'name': 'Uuidoch', 'total': 473}
# {'_id': 25060, 'name': 'de Chaumontois', 'total': 263}
# {'_id': 1044053, 'name': 'Alachisling', 'total': 256}
# {'_id': 10295042, 'name': 'Mel', 'total': 221}
# {'_id': 1044115, 'name': 'Abbonid', 'total': 201}
# {'_id': 25061, 'name': 'Karling', 'total': 173}
# {'_id': 1044116, 'name': 'Nibelunging', 'total': 150}
# {'_id': 623, 'name': 'de Lagery', 'total': 144}
# {'_id': 9230, 'name': 'Eóganacht-Locha Léin', 'total': 142}
# {'_id': 544, 'name': 'de Soissons', 'total': 137}
# {'_id': 356, 'name': 'de Baalun', 'total': 115}
# {'_id': 306, 'name': 'du Perche', 'total': 111}
# {'_id': 1044100, 'name': 'Emichid', 'total': 109}
# {'_id': 9231, 'name': 'Mac Finnachta', 'total': 109}
# {'_id': 10305082, 'name': 'Adalbertingi', 'total': 101}
# {'_id': 10308289, 'name': 'de Trier', 'total': 98}
# {'_id': 10297465, 'name': 'Falco', 'total': 97}
# {'_id': 1044084, 'name': 'Liutprandingi', 'total': 92}
# {'_id': 360, 'name': 'Estouteville', 'total': 90}
# {'_id': 10302654, 'name': 'of Bamburgh', 'total': 89}
# {'_id': 4010, 'name': 'Clifford', 'total': 87}
# {'_id': 319, 'name': 'de Laval', 'total': 82}
# {'_id': 4013, 'name': 'Carew', 'total': 82}
# {'_id': 339, 'name': 'de Crecy', 'total': 78}
# {'_id': 10297032, 'name': 'de Sarvay', 'total': 76}
# {'_id': 9314, 'name': 'Australdling', 'total': 74}
# {'_id': 14261, 'name': 'Mochnant', 'total': 72}
# {'_id': 415, 'name': 'de Hainault', 'total': 71}
# {'_id': 1044052, 'name': 'Munichingi', 'total': 67}
# {'_id': 502, 'name': 'af Munsö', 'total': 66}
# {'_id': 715, 'name': 'de Lorraine', 'total': 65}
# {'_id': 20036, 'name': 'Bethell', 'total': 64}
# {'_id': 1022292, 'name': 'Karteroukas', 'total': 63}
# {'_id': 10303031, 'name': 'Caliu', 'total': 62}
# {'_id': 10305045, 'name': 'Araslan', 'total': 60}
# {'_id': 10299793, 'name': 'Lampertingi', 'total': 60}
# {'_id': 298, 'name': 'de Flotte', 'total': 58}
# {'_id': 5060, 'name': "d'Avesnes", 'total': 58}
# {'_id': 742, 'name': 'de Sémur-en-Brionnais', 'total': 57}
# {'_id': 10303247, 'name': 'Ce', 'total': 57}
# {'_id': 101737, 'name': 'Anchabadze', 'total': 56}
# {'_id': 696, 'name': 'Mac Cennétig', 'total': 56}
# {'_id': 4021, 'name': 'Howard', 'total': 55}
# {'_id': 10305746, 'name': 'de Savona', 'total': 54}
# {'_id': 301, 'name': 'de Champagne', 'total': 53}
# {'_id': 4022, 'name': 'Maudit', 'total': 53}
# {'_id': 10305524, 'name': 'Harodingian', 'total': 53}
# {'_id': 9218, 'name': 'Ua Briúin Bréifne', 'total': 53}
# {'_id': 10295491, 'name': 'Rodoaldingi', 'total': 53}
# {'_id': 814, 'name': 'of Northumbria', 'total': 51}
# {'_id': 9220, 'name': 'Ua Conchobar Sligig', 'total': 51}
# {'_id': 315, 'name': 'de Preuilly', 'total': 49}
# {'_id': 9329, 'name': 'Vuodi', 'total': 48}
# {'_id': 9313, 'name': 'Adelards', 'total': 48}
# {'_id': 9530, 'name': 'Penikis', 'total': 47}
# {'_id': 100024, 'name': 'of Surrey', 'total': 47}
# {'_id': 101709, 'name': 'Marshal', 'total': 47}
# {'_id': 20137, 'name': 'de Vannes', 'total': 47}
# {'_id': 340, 'name': 'de Bellegarde', 'total': 46}
# {'_id': 20088, 'name': 'Rowe', 'total': 45}
# {'_id': 14114, 'name': 'Ua Cathasaigh', 'total': 44}
# {'_id': 1040011, 'name': 'Uib', 'total': 44}
# {'_id': 5062, 'name': 'Clément', 'total': 43}
# {'_id': 712, 'name': "d'Archiac", 'total': 43}
# {'_id': 100073, 'name': 'of Kent', 'total': 43}
# {'_id': 101946, 'name': 'Olkhunut', 'total': 42}
# {'_id': 693, 'name': 'Mac Máil na mBó', 'total': 42}
# {'_id': 9211, 'name': 'Ua Fáeláin', 'total': 42}
# {'_id': 9116, 'name': 'Palemonaitis', 'total': 41}
# {'_id': 821, 'name': 'Ulfing', 'total': 41}
# {'_id': 10314290, 'name': 'Sviriskis', 'total': 40}
# {'_id': 5035, 'name': 'de Menou', 'total': 40}
# {'_id': 83, 'name': 'de Châtillion', 'total': 40}
# {'_id': 565, 'name': 'of Canterbury', 'total': 40}
# {'_id': 10306062, 'name': 'Uib', 'total': 39}
# {'_id': 1047006, 'name': 'Cerdicing', 'total': 39}
# {'_id': 8639, 'name': 'Murzuphlos', 'total': 38}
# {'_id': 10302342, 'name': 'z Roztoki', 'total': 38}
# {'_id': 25065, 'name': 'Jerome-Karling', 'total': 38}
# {'_id': 10298986, 'name': 'de Trith', 'total': 37}
# {'_id': 10315197, 'name': 'de Mark', 'total': 37}
# {'_id': 1044066, 'name': 'Walpertingi', 'total': 37}
# {'_id': 10304805, 'name': 'Giselbertingi', 'total': 35}
# {'_id': 102013, 'name': 'Skjöldung', 'total': 35}
# {'_id': 10307987, 'name': 'of Cemren', 'total': 35}
# {'_id': 10313254, 'name': 'of Canterbury', 'total': 34}
# {'_id': 10302007, 'name': 'Lampertingi', 'total': 33}
# {'_id': 10316322, 'name': 'Mesanaktis', 'total': 32}
# {'_id': 14284, 'name': 'Rhos', 'total': 32}
# {'_id': 14109, 'name': 'Burke', 'total': 31}
# {'_id': 10309357, 'name': 'Liutprandingi', 'total': 30}
# {'_id': 10318436, 'name': 'de Comps', 'total': 29}
# {'_id': 100061, 'name': 'of Lincoln', 'total': 29}
# {'_id': 10315340, 'name': 'Liutprandingi', 'total': 29}
# {'_id': 10294504, 'name': 'Velmaykid', 'total': 29}
# {'_id': 10309770, 'name': 'Petringi', 'total': 29}
# {'_id': 1044094, 'name': 'Hahilinga', 'total': 29}
# {'_id': 10303306, 'name': 'Baghid', 'total': 28}
# {'_id': 100017, 'name': 'of Hereford', 'total': 28}
# {'_id': 7208, 'name': 'de Bures', 'total': 28}
# {'_id': 9130, 'name': 'of the Golensizi', 'total': 28}
# {'_id': 5002, 'name': 'de Mortemart', 'total': 28}
# {'_id': 10313247, 'name': 'Engelbertingi', 'total': 27}
# {'_id': 14121, 'name': 'Ua Dubgaill', 'total': 27}
# {'_id': 10314281, 'name': 'Suvalkija', 'total': 26}
# {'_id': 56, 'name': 'von Kärnten', 'total': 26}
# {'_id': 5029, 'name': 'de Tournemire', 'total': 25}
# {'_id': 5071, 'name': 'de Melun', 'total': 24}
# {'_id': 10320047, 'name': 'de Fontiès', 'total': 23}
# {'_id': 3108, 'name': 'Mac Gregoir', 'total': 23}
# {'_id': 1040017, 'name': 'Ce', 'total': 23}
# {'_id': 10311449, 'name': 'de Lausitz', 'total': 23}
# {'_id': 9119, 'name': 'of Palenke', 'total': 22}
# {'_id': 10321985, 'name': 'Ua Flaithbertaig', 'total': 22}
# {'_id': 3106, 'name': 'na Ceardadh', 'total': 22}
# {'_id': 100068, 'name': 'of Northampton', 'total': 22}
# {'_id': 5034, 'name': 'Chabot', 'total': 22}
# {'_id': 687, 'name': 'a Dúin Chaillden', 'total': 22}
# {'_id': 7364, 'name': 'de Marash', 'total': 21}
# {'_id': 7265, 'name': 'Grenier', 'total': 21}
# {'_id': 1040228, 'name': 'Saaremaa', 'total': 21}
# {'_id': 136, 'name': 'Ulv', 'total': 21}
# {'_id': 10314282, 'name': 'Palemonaitis', 'total': 20}
# {'_id': 100062, 'name': 'of Leicester', 'total': 20}
# {'_id': 9303, 'name': 'de Saint-Valery', 'total': 19}
# {'_id': 8766, 'name': 'de Fenouillet', 'total': 19}
# {'_id': 10319493, 'name': 'Tatingi', 'total': 19}
# {'_id': 1003, 'name': 'Bese', 'total': 19}
# {'_id': 1031008, 'name': 'Ciesla', 'total': 19}
# {'_id': 100058, 'name': 'of Lancaster', 'total': 19}
# {'_id': 9569, 'name': 'Rorgonides', 'total': 19}
# {'_id': 8646, 'name': 'Isauros', 'total': 19}
# {'_id': 730, 'name': 'Bontemps', 'total': 19}
# {'_id': 100021, 'name': 'of Gloucester', 'total': 19}
# {'_id': 3103, 'name': 'Mac Néill', 'total': 19}
# {'_id': 10306364, 'name': 'de Lévis', 'total': 19}
# {'_id': 10321605, 'name': 'de Blanchegard', 'total': 19}
# {'_id': 10314746, 'name': 'Radvila', 'total': 18}
# {'_id': 10311525, 'name': 'Theodingi', 'total': 18}
# {'_id': 10310982, 'name': 'Kichayid', 'total': 18}
# {'_id': 1029003, 'name': 'Gwerthrynion', 'total': 18}
# {'_id': 10307668, 'name': 'Metropoulos', 'total': 17}
# {'_id': 3109, 'name': 'Mac Dubgaill', 'total': 17}
# {'_id': 23115, 'name': 'de Brienne', 'total': 17}
# {'_id': 10321279, 'name': 'Roderissingi', 'total': 17}
# {'_id': 731, 'name': 'de Boullion', 'total': 17}
# {'_id': 1044117, 'name': 'Erenolding', 'total': 17}
# {'_id': 5024, 'name': 'de Noailles', 'total': 17}
# {'_id': 100025, 'name': 'of Sussex', 'total': 17}
# {'_id': 10320873, 'name': 'Leodwalding', 'total': 16}
# {'_id': 10315644, 'name': 'of York', 'total': 16}
# {'_id': 11121, 'name': 'Radziwill', 'total': 16}
# {'_id': 100069, 'name': 'of Bedford', 'total': 16}
# {'_id': 10315893, 'name': 'of Exeter', 'total': 16}
# {'_id': 4024, 'name': 'Berkeley', 'total': 16}
# {'_id': 4031, 'name': 'Grey', 'total': 16}
# {'_id': 10322944, 'name': 'Walbertingi', 'total': 16}
# {'_id': 2037, 'name': 'Holter', 'total': 16}
# {'_id': 10322979, 'name': 'Zeffun', 'total': 15}
# {'_id': 10308597, 'name': 'Syrikos', 'total': 15}
# {'_id': 10313289, 'name': 'Temujin', 'total': 15}
# {'_id': 796, 'name': 'Fromonides', 'total': 15}
# {'_id': 100063, 'name': 'of Derby', 'total': 15}
# {'_id': 7207, 'name': 'de Neuilly', 'total': 15}
# {'_id': 10307329, 'name': 'Paksyayid', 'total': 15}
# {'_id': 388, 'name': 'de Vasconia', 'total': 15}
# {'_id': 146, 'name': 'Skarsholm', 'total': 15}
# {'_id': 10321538, 'name': 'Korybut', 'total': 14}
# {'_id': 10316461, 'name': 'Aristenos', 'total': 14}
# {'_id': 12235, 'name': "d'Enghien", 'total': 14}
# {'_id': 10319559, 'name': 'Roderissingi', 'total': 14}
# {'_id': 12199, 'name': 'Ismailid', 'total': 14}
# {'_id': 10310503, 'name': 'Sortes', 'total': 14}
# {'_id': 684, 'name': 'de Foix', 'total': 14}
# {'_id': 10312717, 'name': 'Liutprandling', 'total': 14}
# {'_id': 7256, 'name': "d'Erville", 'total': 14}
# {'_id': 1038, 'name': 'Tre Rutor', 'total': 14}
# {'_id': 404, 'name': 'de Tilly', 'total': 14}
# {'_id': 4009, 'name': 'Cornwallis', 'total': 14}
# {'_id': 10317266, 'name': 'Bavarae', 'total': 14}
# {'_id': 14256, 'name': 'Rhufoniog', 'total': 14}
# {'_id': 8644, 'name': 'Rangabes', 'total': 13}
# {'_id': 8752, 'name': 'de Lacarre', 'total': 13}
# {'_id': 10314229, 'name': 'Billoingi', 'total': 13}
# {'_id': 1051100, 'name': 'Uzur', 'total': 13}
# {'_id': 10316202, 'name': 'Marapas', 'total': 13}
# {'_id': 14111, 'name': 'Ua Cathail', 'total': 13}
# {'_id': 23113, 'name': 'de Châtillon', 'total': 12}
# {'_id': 10320251, 'name': 'Westminsterid', 'total': 12}
# {'_id': 10321753, 'name': 'Alelkaitis', 'total': 12}
# {'_id': 10297267, 'name': 'Ansprandling', 'total': 12}
# {'_id': 10323536, 'name': 'Puttoc', 'total': 11}
# {'_id': 10309353, 'name': 'Tachipertingi', 'total': 11}
# {'_id': 10319849, 'name': 'Petringi', 'total': 11}
# {'_id': 1047014, 'name': 'Beorming', 'total': 11}
# {'_id': 14285, 'name': 'Crwthor', 'total': 11}
# {'_id': 8693, 'name': 'de Motluel', 'total': 11}
# {'_id': 10299067, 'name': 'Uerturio', 'total': 11}
# {'_id': 101949, 'name': 'Tsookhor', 'total': 10}
# {'_id': 10320743, 'name': 'Walbertingi', 'total': 10}
# {'_id': 10319603, 'name': 'Faroaldingi', 'total': 10}
# {'_id': 10302916, 'name': 'Meltsaykid', 'total': 10}
# {'_id': 101422, 'name': 'Myrelaetes', 'total': 10}
# {'_id': 10311348, 'name': 'of Harbijah', 'total': 10}
# {'_id': 7241, 'name': "d'Ardres", 'total': 10}
# {'_id': 357, 'name': 'de Vernon', 'total': 10}
# {'_id': 5015, 'name': 'de Polignac', 'total': 10}
# {'_id': 101351, 'name': 'Kritopolos', 'total': 10}
# {'_id': 1057, 'name': 'Guldtupp', 'total': 10}
# {'_id': 2019, 'name': 'Kiil', 'total': 10}
# {'_id': 9201, 'name': 'Mac Mathgamna', 'total': 10}
# {'_id': 304, 'name': "d'Eu", 'total': 10}
# {'_id': 100070, 'name': 'of Norfolk', 'total': 10}
# {'_id': 84, 'name': "d'Avaugour", 'total': 10}
# {'_id': 819, 'name': 'Dál Fiatach', 'total': 10}
# {'_id': 10323881, 'name': 'Bavarae', 'total': 9}
# {'_id': 20035, 'name': 'de Rethel', 'total': 9}
# {'_id': 101287, 'name': 'Haplorabdes', 'total': 9}
# {'_id': 100071, 'name': 'of Suffolk', 'total': 9}
# {'_id': 521, 'name': 'von Beilstein', 'total': 9}
# {'_id': 23110, 'name': 'de Joinville', 'total': 9}
# {'_id': 1047021, 'name': 'Leodwalding', 'total': 9}
# {'_id': 10320238, 'name': 'Mubarakid', 'total': 8}
# {'_id': 10320716, 'name': 'Xylaloes', 'total': 8}
# {'_id': 10299836, 'name': 'Ghalibid', 'total': 8}
# {'_id': 10324186, 'name': 'Nasrid', 'total': 8}
# {'_id': 20103, 'name': 'Leon', 'total': 8}
# {'_id': 7264, 'name': 'La Ferté', 'total': 8}
# {'_id': 1023, 'name': 'Marsvin', 'total': 8}
# {'_id': 10312523, 'name': 'Palemonaitis', 'total': 8}
# {'_id': 10323816, 'name': 'Arioldling', 'total': 8}
# {'_id': 14116, 'name': 'Ua Cleirigh', 'total': 8}
# {'_id': 10316241, 'name': 'Katakylas', 'total': 8}
# {'_id': 10311511, 'name': 'Waldulfingi', 'total': 8}
# {'_id': 13106, 'name': 'de Matha', 'total': 8}
# {'_id': 377, 'name': 'of Burgundy', 'total': 8}
# {'_id': 10316143, 'name': 'Hlebowicius', 'total': 8}
# {'_id': 4019, 'name': 'de Ros', 'total': 8}
# {'_id': 23114, 'name': 'de la Roche', 'total': 8}
# {'_id': 93, 'name': 'de Lusignan', 'total': 8}
# {'_id': 10322038, 'name': 'Abbonid', 'total': 7}
# {'_id': 101407, 'name': 'Mitylenaios', 'total': 7}
# {'_id': 40004, 'name': 'de Lescar', 'total': 7}
# {'_id': 100754, 'name': 'Basilakios', 'total': 7}
# {'_id': 10323315, 'name': 'Gafurid', 'total': 7}
# {'_id': 1044, 'name': 'Virske', 'total': 7}
# {'_id': 10315327, 'name': 'Mountanis', 'total': 7}
# {'_id': 10316323, 'name': 'Neapolites', 'total': 7}
# {'_id': 100004, 'name': 'Connachta', 'total': 7}
# {'_id': 10310899, 'name': 'Mangirdaitis', 'total': 7}
# {'_id': 10314446, 'name': 'Wechtaringi', 'total': 7}
# {'_id': 526, 'name': 'Brunswick', 'total': 7}
# {'_id': 10303088, 'name': 'of Herakleia', 'total': 7}
# {'_id': 20017, 'name': 'Leon', 'total': 7}
# {'_id': 231, 'name': 'de Cleriuex', 'total': 7}
# {'_id': 1044119, 'name': 'Hugonid', 'total': 7}
# {'_id': 1029030, 'name': 'Dyfed', 'total': 7}
# {'_id': 1040001, 'name': 'Dál Birn', 'total': 7}
# {'_id': 10317794, 'name': 'Anemas', 'total': 6}
# {'_id': 10322945, 'name': 'Roderissingi', 'total': 6}
# {'_id': 10323231, 'name': 'Athollid', 'total': 6}
# {'_id': 8696, 'name': 'de Valromey', 'total': 6}
# {'_id': 9305, 'name': 'de Dun', 'total': 6}
# {'_id': 10322869, 'name': 'Gaidoaldingi', 'total': 6}
# {'_id': 10321359, 'name': 'Sant Mikael', 'total': 6}
# {'_id': 149, 'name': 'Griphuvud', 'total': 6}
# {'_id': 10309368, 'name': 'Maurozoumis', 'total': 6}
# {'_id': 100028, 'name': 'of Somerset', 'total': 6}
# {'_id': 10314283, 'name': 'Sviriskis', 'total': 6}
# {'_id': 11127, 'name': 'Zamojski', 'total': 6}
# {'_id': 10320714, 'name': 'de Coligny', 'total': 6}
# {'_id': 10312004, 'name': 'Walpertingi', 'total': 6}
# {'_id': 10320744, 'name': 'Gausian', 'total': 6}
# {'_id': 4046, 'name': 'FitzPatrick', 'total': 6}
# {'_id': 87, 'name': 'von Neuenburg', 'total': 6}
# {'_id': 10322376, 'name': 'Khudu', 'total': 6}
# {'_id': 10321752, 'name': 'Radvila', 'total': 6}
# {'_id': 551, 'name': 'Mac Murchada', 'total': 6}
# {'_id': 10324999, 'name': 'Hatt', 'total': 5}
# {'_id': 10314433, 'name': 'Logothetes', 'total': 5}
# {'_id': 10324447, 'name': 'Mac Torfinn', 'total': 5}
# {'_id': 1144, 'name': 'Tre Sjöblad', 'total': 5}
# {'_id': 1022111, 'name': 'Kyrdiniatis', 'total': 5}
# {'_id': 20062, 'name': 'de Montlhéry', 'total': 5}
# {'_id': 10318282, 'name': 'of Mercia', 'total': 5}
# {'_id': 7210, 'name': 'de Chappes', 'total': 5}
# {'_id': 10320234, 'name': 'Sami', 'total': 5}
# {'_id': 10315264, 'name': 'de Blois', 'total': 5}
# {'_id': 100022, 'name': 'of Oxford', 'total': 5}
# {'_id': 10309341, 'name': 'Liutfredingi', 'total': 5}
# {'_id': 100053, 'name': 'of Cumberland', 'total': 5}
# {'_id': 10313314, 'name': 'de Crussol', 'total': 5}
# {'_id': 10312378, 'name': 'Clifford', 'total': 5}
# {'_id': 10302245, 'name': 'Tachipertingi', 'total': 5}
# {'_id': 1044098, 'name': 'Hardrading', 'total': 5}
# {'_id': 101603, 'name': 'Tynedale', 'total': 5}
# {'_id': 1047000, 'name': 'Wuffing', 'total': 5}
# {'_id': 10318376, 'name': 'Ua Cruadláich', 'total': 5}
# {'_id': 10324009, 'name': 'Qawurdid', 'total': 4}
# {'_id': 10320398, 'name': 'Abdullahid', 'total': 4}
# {'_id': 9540, 'name': 'Wilks', 'total': 4}
# {'_id': 10324238, 'name': 'Palemonaitis', 'total': 4}
# {'_id': 10304381, 'name': 'Kashgarid', 'total': 4}
# {'_id': 10320522, 'name': 'Kantakouzenos', 'total': 4}
# {'_id': 10317549, 'name': 'Samirid', 'total': 4}
# {'_id': 101601, 'name': 'Crawford', 'total': 4}
# {'_id': 10315077, 'name': 'de Penthièvre', 'total': 4}
# {'_id': 101479, 'name': 'Romaios', 'total': 4}
# {'_id': 5030, 'name': 'de Curières', 'total': 4}
# {'_id': 688, 'name': 'Mac Ailpin', 'total': 4}
# {'_id': 10311846, 'name': 'de Gontaut', 'total': 4}
# {'_id': 10309931, 'name': 'Roderissingi', 'total': 4}
# {'_id': 10315739, 'name': 'Bacon', 'total': 4}
# {'_id': 100072, 'name': 'of Wessex', 'total': 4}
# {'_id': 1022270, 'name': 'Kyritzios', 'total': 4}
# {'_id': 10302695, 'name': 'Orc', 'total': 4}
# {'_id': 10317258, 'name': 'de Blois', 'total': 4}
# {'_id': 10323763, 'name': 'Gausian', 'total': 4}
# {'_id': 10317394, 'name': 'Yabghu', 'total': 4}
# {'_id': 10300009, 'name': 'Hafizid', 'total': 4}
# {'_id': 40014, 'name': 'de Guéret', 'total': 4}
# {'_id': 7258, 'name': 'de Glane', 'total': 4}
# {'_id': 10311298, 'name': 'de Tourraine', 'total': 4}
# {'_id': 10322566, 'name': 'de Termes', 'total': 4}
# {'_id': 40009, 'name': 'de Fezenzaguet', 'total': 4}
# {'_id': 850, 'name': 'Blackadder', 'total': 4}
# {'_id': 165, 'name': "d'Ibelin", 'total': 4}
# {'_id': 547, 'name': 'Morgannwg', 'total': 4}
# {'_id': 10324676, 'name': "d'Armagnac", 'total': 3}
# {'_id': 10324129, 'name': 'Pandulfingi', 'total': 3}
# {'_id': 10323930, 'name': 'of Northumbria', 'total': 3}
# {'_id': 10324845, 'name': 'du Perche', 'total': 3}
# {'_id': 10317424, 'name': 'Machetarios', 'total': 3}
# {'_id': 1058, 'name': 'Ulfsax', 'total': 3}
# {'_id': 10314289, 'name': 'Radvila', 'total': 3}
# {'_id': 10322551, 'name': 'Beleoingi', 'total': 3}
# {'_id': 10316646, 'name': 'Phokas', 'total': 3}
# {'_id': 10314285, 'name': 'Pacas', 'total': 3}
# {'_id': 10323383, 'name': 'de Montcatanier', 'total': 3}
# {'_id': 10323673, 'name': 'Ansfridingi', 'total': 3}
# {'_id': 10317835, 'name': 'Areobindenos', 'total': 3}
# {'_id': 10322345, 'name': 'of Syria', 'total': 3}
# {'_id': 1050, 'name': 'Läma', 'total': 3}
# {'_id': 1020, 'name': 'Lake', 'total': 3}
# {'_id': 10320348, 'name': 'de Penthievre', 'total': 3}
# {'_id': 10322710, 'name': 'Gandulfingi', 'total': 3}
# {'_id': 10318788, 'name': 'di Brunforte', 'total': 3}
# {'_id': 10317867, 'name': 'de Napoli', 'total': 3}
# {'_id': 10319132, 'name': 'Liutprandingi', 'total': 3}
# {'_id': 10315209, 'name': 'Faroaldingi', 'total': 3}
# {'_id': 10319457, 'name': 'de Guines', 'total': 3}
# {'_id': 10320237, 'name': 'Durhamid', 'total': 3}
# {'_id': 10315780, 'name': 'de Montacute', 'total': 3}
# {'_id': 10316086, 'name': 'de Cuiseaux', 'total': 3}
# {'_id': 10319413, 'name': 'of Devon', 'total': 3}
# {'_id': 10323812, 'name': 'de Brienne', 'total': 3}
# {'_id': 10314732, 'name': 'de Burgund', 'total': 3}
# {'_id': 10325304, 'name': 'de Pins', 'total': 3}
# {'_id': 10312693, 'name': 'de Brisebarre', 'total': 3}
# {'_id': 10311864, 'name': 'of Bedford', 'total': 3}
# {'_id': 10309909, 'name': 'Çatid', 'total': 3}
# {'_id': 10310961, 'name': 'Yerneslu', 'total': 3}
# {'_id': 10324931, 'name': 'Alelkaitis', 'total': 3}
# {'_id': 10309528, 'name': 'Ua Briain', 'total': 3}
# {'_id': 10324094, 'name': 'Harodingian', 'total': 3}
# {'_id': 10307549, 'name': 'Barrois', 'total': 3}
# {'_id': 10306884, 'name': 'Uuidoch', 'total': 3}
# {'_id': 9222, 'name': 'Ua Conchobar Donn', 'total': 3}
# {'_id': 10325003, 'name': "d'Apchier", 'total': 3}
# {'_id': 10306051, 'name': 'Cadfeal', 'total': 3}
# {'_id': 9215, 'name': 'Ua Rubann', 'total': 3}
# {'_id': 10305565, 'name': 'Mac Máil na mBó', 'total': 3}
# {'_id': 10305804, 'name': 'Craig', 'total': 3}
# {'_id': 10324233, 'name': 'Daufingi', 'total': 3}
# {'_id': 9121, 'name': 'Sieradzki', 'total': 3}
# {'_id': 10322166, 'name': 'de Joinville', 'total': 3}
# {'_id': 14258, 'name': 'Penllyn', 'total': 3}
# {'_id': 20016, 'name': 'de Nantes', 'total': 3}
# {'_id': 9225, 'name': 'Eóganacht-Chaisil', 'total': 3}
# {'_id': 12110, 'name': 'Unruochinger', 'total': 3}
# {'_id': 10312525, 'name': 'de Luxembourg', 'total': 3}
# {'_id': 10320295, 'name': 'Iceling', 'total': 3}
# {'_id': 1043, 'name': 'Vinstorpa', 'total': 3}
# {'_id': 10293494, 'name': 'Kubasarid', 'total': 3}
# {'_id': 10293230, 'name': 'Hildradson', 'total': 3}
# {'_id': 10314969, 'name': 'de Voisins', 'total': 3}
# {'_id': 10316555, 'name': 'de Guincamp', 'total': 3}
# {'_id': 10321109, 'name': 'of Schaffhausen', 'total': 3}
# {'_id': 10312257, 'name': 'de Druyes', 'total': 3}
# {'_id': 10322198, 'name': "d'Apulia", 'total': 3}
# {'_id': 2010, 'name': 'Bratt', 'total': 3}
# {'_id': 1022268, 'name': 'Avastaktos', 'total': 3}
# {'_id': 10323694, 'name': 'Libadas', 'total': 3}
# {'_id': 1046, 'name': 'Vingad Lilja', 'total': 2}
# {'_id': 10324619, 'name': 'Mac Gregoir', 'total': 2}
# {'_id': 10323486, 'name': 'Valmantaitis', 'total': 2}
# {'_id': 1032, 'name': 'Sture', 'total': 2}
# {'_id': 10325514, 'name': 'Kesgailos', 'total': 2}
# {'_id': 10316832, 'name': 'Gafurid', 'total': 2}
# {'_id': 10311853, 'name': 'Karbonopsis', 'total': 2}
# {'_id': 10308643, 'name': 'Pekoules', 'total': 2}
# {'_id': 25053, 'name': 'de Malveisin', 'total': 2}
# {'_id': 10324130, 'name': 'Ua hUalgairg', 'total': 2}
# {'_id': 10322239, 'name': 'Beorming', 'total': 2}
# {'_id': 10322937, 'name': "d'Evreux", 'total': 2}
# {'_id': 10322583, 'name': 'Wigeriche', 'total': 2}
# {'_id': 10320394, 'name': 'de Montignac', 'total': 2}
# {'_id': 3111, 'name': 'Mac in Rothaich', 'total': 2}
# {'_id': 10320244, 'name': 'Ramadan', 'total': 2}
# {'_id': 7352, 'name': 'de Petra', 'total': 2}
# {'_id': 8694, 'name': 'de Salvaing', 'total': 2}
# {'_id': 10313365, 'name': 'Dokeianos', 'total': 2}
# {'_id': 10320827, 'name': 'de Fezensac', 'total': 2}
# {'_id': 10314278, 'name': 'Palemonaitis', 'total': 2}
# {'_id': 10314323, 'name': 'Radvila', 'total': 2}
# {'_id': 10322088, 'name': 'Kundaçid', 'total': 2}
# {'_id': 10320161, 'name': 'de Stromoncourt', 'total': 2}
# {'_id': 10308089, 'name': 'Neustongios', 'total': 2}
# {'_id': 10320250, 'name': 'Jabirid', 'total': 2}
# {'_id': 10323049, 'name': "d'Aargau", 'total': 2}
# {'_id': 10316580, 'name': 'Yavanteyid', 'total': 2}
# {'_id': 1018, 'name': 'Knoppe', 'total': 2}
# {'_id': 40020, 'name': 'de Thiers', 'total': 2}
# {'_id': 10318631, 'name': 'de Nanteuil', 'total': 2}
# {'_id': 10318624, 'name': 'de Montaigu', 'total': 2}
# {'_id': 10318675, 'name': 'Varbertingi', 'total': 2}
# {'_id': 10318835, 'name': 'de Nanteuil', 'total': 2}
# {'_id': 10315702, 'name': 'Kataphloros', 'total': 2}
# {'_id': 10318368, 'name': 'Mac Alaxandair', 'total': 2}
# {'_id': 100059, 'name': 'of Chester', 'total': 2}
# {'_id': 10324253, 'name': 'de la Roche Aymon', 'total': 2}
# {'_id': 10319323, 'name': 'de Gourdon', 'total': 2}
# {'_id': 10315892, 'name': 'Coenwalhing', 'total': 2}
# {'_id': 10318747, 'name': 'Henry', 'total': 2}
# {'_id': 10316428, 'name': 'Reresby', 'total': 2}
# {'_id': 10315596, 'name': 'Reresby', 'total': 2}
# {'_id': 40015, 'name': 'de Martel', 'total': 2}
# {'_id': 10319233, 'name': 'Mac Cainnig', 'total': 2}
# {'_id': 10315109, 'name': 'Brahe', 'total': 2}
# {'_id': 10319828, 'name': 'Chamillart', 'total': 2}
# {'_id': 10314888, 'name': 'Cataibh', 'total': 2}
# {'_id': 10313810, 'name': "d'Artois", 'total': 2}
# {'_id': 10325472, 'name': 'Jogailaitis', 'total': 2}
# {'_id': 10313913, 'name': 'Pudsey', 'total': 2}
# {'_id': 10325339, 'name': 'Munichingi', 'total': 2}
# {'_id': 10313790, 'name': 'of Derby', 'total': 2}
# {'_id': 10312891, 'name': 'de Cardaillac', 'total': 2}
# {'_id': 20034, 'name': 'de Baugency', 'total': 2}
# {'_id': 10314268, 'name': "d'Aulnay", 'total': 2}
# {'_id': 5004, 'name': 'de la Rochefoucauld', 'total': 2}
# {'_id': 10311280, 'name': 'Falk', 'total': 2}
# {'_id': 10325248, 'name': 'Fleming', 'total': 2}
# {'_id': 10312543, 'name': 'Wallace', 'total': 2}
# {'_id': 10320231, 'name': 'Yahyid', 'total': 2}
# {'_id': 10315341, 'name': 'de Chacim', 'total': 2}
# {'_id': 10325226, 'name': 'Alšeniškis', 'total': 2}
# {'_id': 10312592, 'name': 'Borg', 'total': 2}
# {'_id': 10323402, 'name': 'Tamworid', 'total': 2}
# {'_id': 10308056, 'name': 'Romoaldingi', 'total': 2}
# {'_id': 101424, 'name': 'Nabatenos', 'total': 2}
# {'_id': 10314144, 'name': 'Eadricing', 'total': 2}
# {'_id': 10324012, 'name': 'de Talleyrand', 'total': 2}
# {'_id': 10318392, 'name': 'Chordolibas', 'total': 2}
# {'_id': 10315274, 'name': "d'Aumale", 'total': 2}
# {'_id': 10308759, 'name': 'de Conversano', 'total': 2}
# {'_id': 10323474, 'name': 'de la Tour du Pin', 'total': 2}
# {'_id': 5005, 'name': 'de Caumont', 'total': 2}
# {'_id': 10308710, 'name': 'Theodericing', 'total': 2}
# {'_id': 13109, 'name': 'de Die', 'total': 2}
# {'_id': 10312760, 'name': 'de Genève', 'total': 2}
# {'_id': 101708, 'name': 'Pudsey', 'total': 2}
# {'_id': 10316857, 'name': 'Guldsmed', 'total': 2}
# {'_id': 5078, 'name': 'de Voisins', 'total': 2}
# {'_id': 10309038, 'name': 'Huntingdon', 'total': 2}
# {'_id': 10309305, 'name': 'Pudsey', 'total': 2}
# {'_id': 4028, 'name': 'Colvile', 'total': 2}
# {'_id': 10310850, 'name': 'Kundaçiqid', 'total': 2}
# {'_id': 10320393, 'name': 'Mac Drostan', 'total': 2}
# {'_id': 10313203, 'name': 'de Gramont', 'total': 2}
# {'_id': 10311574, 'name': 'Mubarakid', 'total': 2}
# {'_id': 10319752, 'name': 'Bachantid', 'total': 2}
# {'_id': 10318191, 'name': 'Litpolden', 'total': 2}
# {'_id': 10305826, 'name': 'Rhufoniog', 'total': 2}
# {'_id': 10324909, 'name': 'Rorgonides', 'total': 2}
# {'_id': 10299416, 'name': 'de Ville-Bride', 'total': 2}
# {'_id': 414, 'name': 'de Mons', 'total': 2}
# {'_id': 3146, 'name': 'Randolph', 'total': 2}
# {'_id': 10310971, 'name': 'of Warta', 'total': 2}
# {'_id': 10302619, 'name': 'Ursingi', 'total': 2}
# {'_id': 7374, 'name': 'Saint-Abraham', 'total': 2}
# {'_id': 10314551, 'name': 'Astikaitis', 'total': 2}
# {'_id': 10322469, 'name': 'de Chartres', 'total': 2}
# {'_id': 10324864, 'name': 'Radvila', 'total': 2}
# {'_id': 10323563, 'name': 'Daufingi', 'total': 2}
# {'_id': 10314498, 'name': 'Stenkyrka', 'total': 2}
# {'_id': 10296833, 'name': 'Ua Gallchobair', 'total': 2}
# {'_id': 1047002, 'name': 'Iceling', 'total': 2}
# {'_id': 10324336, 'name': 'de Tír Chonaill', 'total': 2}
# {'_id': 10310789, 'name': 'Hyakinthiotis', 'total': 2}
# {'_id': 10311120, 'name': 'Ua hUalgairg', 'total': 2}
# {'_id': 10322548, 'name': 'Bradnigh', 'total': 2}
# {'_id': 10312734, 'name': 'de Saint-Valéry', 'total': 2}
# {'_id': 10319576, 'name': 'Mouzelis', 'total': 2}
# {'_id': 10314940, 'name': 'de Montesquiou', 'total': 2}
# {'_id': 10307747, 'name': 'de Rosello', 'total': 2}
# {'_id': 548, 'name': 'Mathrafal', 'total': 2}
# {'_id': 10314506, 'name': 'de Dreaux', 'total': 2}
# {'_id': 10308057, 'name': 'Alachisling', 'total': 2}
# {'_id': 10308025, 'name': 'Theodericing', 'total': 2}
# {'_id': 1022170, 'name': 'Sellokalas', 'total': 2}
# {'_id': 10312277, 'name': 'Synkellos', 'total': 1}
# {'_id': 10325414, 'name': 'de Vannes', 'total': 1}
# {'_id': 10325407, 'name': 'of Tmutarakan', 'total': 1}
# {'_id': 10316500, 'name': 'Samirid', 'total': 1}
# {'_id': 10325307, 'name': 'de Jylland', 'total': 1}
# {'_id': 10325269, 'name': 'Clydesdale', 'total': 1}
# {'_id': 10318350, 'name': 'Patrasid', 'total': 1}
# {'_id': 10324592, 'name': 'de Bezieres', 'total': 1}
# {'_id': 10325132, 'name': 'de Cremona', 'total': 1}
# {'_id': 10325084, 'name': 'Walpertingi', 'total': 1}
# {'_id': 10325063, 'name': 'de Jylland', 'total': 1}
# {'_id': 10325035, 'name': 'of Paphlagonia', 'total': 1}
# {'_id': 10324962, 'name': 'de Napoli', 'total': 1}
# {'_id': 10324914, 'name': 'af Uppland', 'total': 1}
# {'_id': 10324889, 'name': 'de Sjælland', 'total': 1}
# {'_id': 40012, 'name': 'de Talmont', 'total': 1}
# {'_id': 10324854, 'name': 'of Galich', 'total': 1}
# {'_id': 10324815, 'name': "d'Amalfi", 'total': 1}
# {'_id': 10324726, 'name': 'of Albania', 'total': 1}
# {'_id': 10324532, 'name': "d'Amalfi", 'total': 1}
# {'_id': 10324199, 'name': 'de Montignac', 'total': 1}
# {'_id': 10320142, 'name': 'Gonitis', 'total': 1}
# {'_id': 10324385, 'name': 'of Rascia', 'total': 1}
# {'_id': 10324335, 'name': 'de Bologna', 'total': 1}
# {'_id': 10324290, 'name': 'de Spoleto', 'total': 1}
# {'_id': 10324282, 'name': 'de Spoleto', 'total': 1}
# {'_id': 10324173, 'name': 'de Vannes', 'total': 1}
# {'_id': 10324069, 'name': 'de Forcalquier', 'total': 1}
# {'_id': 10323824, 'name': "d'Ancona", 'total': 1}
# {'_id': 10311095, 'name': 'Valladolid', 'total': 1}
# {'_id': 10323783, 'name': 'de Gent', 'total': 1}
# {'_id': 10323756, 'name': 'de Connachta', 'total': 1}
# {'_id': 10323717, 'name': 'iš Vologda', 'total': 1}
# {'_id': 10323700, 'name': 'of Fejer', 'total': 1}
# {'_id': 10323681, 'name': 'de Treviso', 'total': 1}
# {'_id': 10323631, 'name': 'de Noailles', 'total': 1}
# {'_id': 10323622, 'name': 'de Genoa', 'total': 1}
# {'_id': 10325366, 'name': 'Qawurdid', 'total': 1}
# {'_id': 10323470, 'name': 'Karpela', 'total': 1}
# {'_id': 10323485, 'name': 'de Laigin', 'total': 1}
# {'_id': 10325138, 'name': 'de Jylland', 'total': 1}
# {'_id': 10323405, 'name': "d'Uppland", 'total': 1}
# {'_id': 10319172, 'name': 'Kurtikainos', 'total': 1}
# {'_id': 10303513, 'name': 'Tobrukid', 'total': 1}
# {'_id': 10323302, 'name': 'de Spoleto', 'total': 1}
# {'_id': 22004, 'name': 'de Tonnerre', 'total': 1}
# {'_id': 10323111, 'name': "d'Anhalt", 'total': 1}
# {'_id': 10323065, 'name': 'de St Ethelberts', 'total': 1}
# {'_id': 10322997, 'name': 'de Jylland', 'total': 1}
# {'_id': 10322947, 'name': "d'Orvieto", 'total': 1}
# {'_id': 10322798, 'name': 'Hayles', 'total': 1}
# {'_id': 10322861, 'name': 'de Galloway', 'total': 1}
# {'_id': 10322816, 'name': 'de Halland', 'total': 1}
# {'_id': 10322732, 'name': 'de Charolais', 'total': 1}
# {'_id': 10322644, 'name': 'de Jylland', 'total': 1}
# {'_id': 10322622, 'name': 'de Galloway', 'total': 1}
# {'_id': 10322333, 'name': 'de Paris', 'total': 1}
# {'_id': 10322230, 'name': 'Ursingi', 'total': 1}
# {'_id': 10324872, 'name': 'Waldulfingi', 'total': 1}
# {'_id': 10322300, 'name': 'de Sjælland', 'total': 1}
# {'_id': 10311798, 'name': 'Isakiotes', 'total': 1}
# {'_id': 10322250, 'name': 'de Lombardy', 'total': 1}
# {'_id': 10322110, 'name': 'of Ulster', 'total': 1}
# {'_id': 13111, 'name': 'de Montboissier', 'total': 1}
# {'_id': 10324839, 'name': 'af Tjust', 'total': 1}
# {'_id': 10323205, 'name': 'de Jylland', 'total': 1}
# {'_id': 10322563, 'name': 'de Florens', 'total': 1}
# {'_id': 10321956, 'name': "d'Uppland", 'total': 1}
# {'_id': 10321839, 'name': "d'Uppland", 'total': 1}
# {'_id': 10321763, 'name': 'de Connachta', 'total': 1}
# {'_id': 10321584, 'name': 'de Genoa', 'total': 1}
# {'_id': 10325150, 'name': 'de Lubusz', 'total': 1}
# {'_id': 10321421, 'name': 'of Dunseverick', 'total': 1}
# {'_id': 10314891, 'name': 'of Lowestoft', 'total': 1}
# {'_id': 10321254, 'name': 'de Forcalquier', 'total': 1}
# {'_id': 10319776, 'name': 'de Comborn', 'total': 1}
# {'_id': 10320905, 'name': 'de Gelre', 'total': 1}
# {'_id': 10320843, 'name': "d'Auvergne", 'total': 1}
# {'_id': 10320704, 'name': 'iš Chernigov', 'total': 1}
# {'_id': 10320687, 'name': 'de Périgord', 'total': 1}
# {'_id': 10320683, 'name': 'de Vivarais', 'total': 1}
# {'_id': 10320989, 'name': 'Peloponnesites', 'total': 1}
# {'_id': 10320674, 'name': 'de Rouen', 'total': 1}
# {'_id': 10320641, 'name': 'de Rostock', 'total': 1}
# {'_id': 10320604, 'name': 'de Rouen', 'total': 1}
# {'_id': 10320599, 'name': 'iš Belo Ozero', 'total': 1}
# {'_id': 10320124, 'name': 'Kogsegu', 'total': 1}
# {'_id': 10320585, 'name': 'de Jylland', 'total': 1}
# {'_id': 10323082, 'name': 'iš Torzhok', 'total': 1}
# {'_id': 10320419, 'name': "d'Anhalt", 'total': 1}
# {'_id': 10320276, 'name': 'de Dijon', 'total': 1}
# {'_id': 10320268, 'name': 'of Monemvasia', 'total': 1}
# {'_id': 10322034, 'name': 'de Liege', 'total': 1}
# {'_id': 10320067, 'name': 'of Westmorland', 'total': 1}
# {'_id': 10319689, 'name': 'of Northampton', 'total': 1}
# {'_id': 10319762, 'name': 'de Valais', 'total': 1}
# {'_id': 10319699, 'name': 'de Provence', 'total': 1}
# {'_id': 10319686, 'name': 'de Calatrava', 'total': 1}
# {'_id': 10324455, 'name': 'de Lubusz', 'total': 1}
# {'_id': 10319655, 'name': 'de Gelre', 'total': 1}
# {'_id': 10322395, 'name': 'de Gent', 'total': 1}
# {'_id': 10319628, 'name': 'of Ulster', 'total': 1}
# {'_id': 10319580, 'name': "d'Armagnac", 'total': 1}
# {'_id': 1026, 'name': 'Pik', 'total': 1}
# {'_id': 10319577, 'name': 'of Cumberland', 'total': 1}
# {'_id': 10319574, 'name': 'of Middlesex', 'total': 1}
# {'_id': 10319564, 'name': 'de Provence', 'total': 1}
# {'_id': 10319500, 'name': 'de Gelre', 'total': 1}
# {'_id': 10319325, 'name': 'de Gelre', 'total': 1}
# {'_id': 10319146, 'name': 'de Gelre', 'total': 1}
# {'_id': 10319088, 'name': 'of Adrianopolis', 'total': 1}
# {'_id': 10318952, 'name': 'de Gelre', 'total': 1}
# {'_id': 10320418, 'name': 'Ansfridingi', 'total': 1}
# {'_id': 10319678, 'name': 'de Léon', 'total': 1}
# {'_id': 10318914, 'name': 'of Suffolk', 'total': 1}
# {'_id': 10318791, 'name': 'of York', 'total': 1}
# {'_id': 10318760, 'name': 'de Gniezno', 'total': 1}
# {'_id': 10318727, 'name': 'de Vermandois', 'total': 1}
# {'_id': 10318684, 'name': 'of Cumberland', 'total': 1}
# {'_id': 10318627, 'name': 'di Benevento', 'total': 1}
# {'_id': 10317988, 'name': 'de Pontevès', 'total': 1}
# {'_id': 10323850, 'name': 'de Pescara', 'total': 1}
# {'_id': 10318878, 'name': 'de Vermandois', 'total': 1}
# {'_id': 10318390, 'name': 'de Rome', 'total': 1}
# {'_id': 10318279, 'name': 'de Siena', 'total': 1}
# {'_id': 10318236, 'name': 'di Benevento', 'total': 1}
# {'_id': 10318063, 'name': 'de Laigin', 'total': 1}
# {'_id': 10301177, 'name': 'Abdullahid', 'total': 1}
# {'_id': 10318037, 'name': 'de Genoa', 'total': 1}
# {'_id': 10318023, 'name': 'af Agder', 'total': 1}
# {'_id': 10317922, 'name': 'de Genoa', 'total': 1}
# {'_id': 10319128, 'name': 'Sicard', 'total': 1}
# {'_id': 10317769, 'name': 'de Feher', 'total': 1}
# {'_id': 10317698, 'name': 'de Provence', 'total': 1}
# {'_id': 10317747, 'name': 'de Feher', 'total': 1}
# {'_id': 10317644, 'name': 'of Árta', 'total': 1}
# {'_id': 10317625, 'name': 'of Kalamata', 'total': 1}
# {'_id': 10317622, 'name': 'de Vermandois', 'total': 1}
# {'_id': 10317618, 'name': 'de Caithness', 'total': 1}
# {'_id': 10322736, 'name': 'de Halland', 'total': 1}
# {'_id': 10318846, 'name': 'de Blois', 'total': 1}
# {'_id': 10319437, 'name': 'Maudit', 'total': 1}
# {'_id': 3104, 'name': 'Mac Áeda', 'total': 1}
# {'_id': 10315605, 'name': 'of Lesbos', 'total': 1}
# {'_id': 10317322, 'name': 'de Argyll', 'total': 1}
# {'_id': 10312708, 'name': 'Duhokid', 'total': 1}
# {'_id': 10317256, 'name': "d'Anjou", 'total': 1}
# {'_id': 10317248, 'name': 'of Bedford', 'total': 1}
# {'_id': 10317238, 'name': 'of Maldon', 'total': 1}
# {'_id': 10317200, 'name': 'of Suffolk', 'total': 1}
# {'_id': 10317166, 'name': 'de Metz', 'total': 1}
# {'_id': 10323101, 'name': 'de Mantua', 'total': 1}
# {'_id': 10318389, 'name': 'de Ponthieu', 'total': 1}
# {'_id': 10322549, 'name': 'de Galloway', 'total': 1}
# {'_id': 10317071, 'name': "d'Amiens", 'total': 1}
# {'_id': 10317070, 'name': 'of Árta', 'total': 1}
# {'_id': 10316955, 'name': 'of Derby', 'total': 1}
# {'_id': 10317234, 'name': "d'Anjou", 'total': 1}
# {'_id': 10323492, 'name': 'de Genoa', 'total': 1}
# {'_id': 10316939, 'name': 'de Stafford', 'total': 1}
# {'_id': 10316768, 'name': 'de Fife', 'total': 1}
# {'_id': 10316711, 'name': 'of Árta', 'total': 1}
# {'_id': 10316491, 'name': 'de Lyon', 'total': 1}
# {'_id': 7245, 'name': 'de Baudement', 'total': 1}
# {'_id': 10316284, 'name': 'de Metz', 'total': 1}
# {'_id': 10323471, 'name': 'de Cúil Rathain', 'total': 1}
# {'_id': 10316231, 'name': 'of Kempten', 'total': 1}
# {'_id': 10316191, 'name': 'of Derby', 'total': 1}
# {'_id': 10316109, 'name': 'de Hedeby', 'total': 1}
# {'_id': 10316103, 'name': 'of Sussex', 'total': 1}
# {'_id': 10319438, 'name': 'of Westmorland', 'total': 1}
# {'_id': 100526, 'name': 'Tarnowski', 'total': 1}
# {'_id': 10315960, 'name': 'of Wessex', 'total': 1}
# {'_id': 10316201, 'name': 'de Dijon', 'total': 1}
# {'_id': 10316340, 'name': 'de Hamburg', 'total': 1}
# {'_id': 10319341, 'name': 'de Gelre', 'total': 1}
# {'_id': 10319059, 'name': "d'Ascoli", 'total': 1}
# {'_id': 10315681, 'name': 'von Bereg', 'total': 1}
# {'_id': 10315598, 'name': 'of Shropshire', 'total': 1}
# {'_id': 10315593, 'name': 'de Gent', 'total': 1}
# {'_id': 10322659, 'name': "d'Este", 'total': 1}
# {'_id': 10317400, 'name': 'de Charolais', 'total': 1}
# {'_id': 10315585, 'name': 'de Schwaben', 'total': 1}
# {'_id': 10321568, 'name': 'af Medelpad', 'total': 1}
# {'_id': 10315191, 'name': 'de Teviotdale', 'total': 1}
# {'_id': 10315827, 'name': 'de Gent', 'total': 1}
# {'_id': 10320923, 'name': 'de Halland', 'total': 1}
# {'_id': 10323408, 'name': 'de Mzab', 'total': 1}
# {'_id': 10314910, 'name': 'de Vannes', 'total': 1}
# {'_id': 10321145, 'name': 'of Adrianopolis', 'total': 1}
# {'_id': 10314661, 'name': 'of Leicester', 'total': 1}
# {'_id': 10323606, 'name': 'de Vannes', 'total': 1}
# {'_id': 10318937, 'name': 'di Benevento', 'total': 1}
# {'_id': 10314445, 'name': 'Giselbertingi', 'total': 1}
# {'_id': 10316279, 'name': 'Despencer', 'total': 1}
# {'_id': 10322974, 'name': 'de Halland', 'total': 1}
# {'_id': 10314483, 'name': "d'Altmark", 'total': 1}
# {'_id': 10315332, 'name': 'de Zeeland', 'total': 1}
# {'_id': 10317006, 'name': 'de Argyll', 'total': 1}
# {'_id': 10314461, 'name': 'of Constantinople', 'total': 1}
# {'_id': 10314636, 'name': 'de Piemonte', 'total': 1}
# {'_id': 10314173, 'name': "d'Altmark", 'total': 1}
# {'_id': 10320242, 'name': 'Hussayn', 'total': 1}
# {'_id': 21023, 'name': 'Polkozic', 'total': 1}
# {'_id': 5066, 'name': 'de Campistron', 'total': 1}
# {'_id': 10319063, 'name': 'of Monemvasia', 'total': 1}
# {'_id': 10314018, 'name': 'of Gloucester', 'total': 1}
# {'_id': 10313918, 'name': 'de Brioude', 'total': 1}
# {'_id': 10313834, 'name': 'de Gowrie', 'total': 1}
# {'_id': 10322859, 'name': 'Mac in Baird', 'total': 1}
# {'_id': 10319781, 'name': 'of Norfolk', 'total': 1}
# {'_id': 10313711, 'name': 'de Litomerice', 'total': 1}
# {'_id': 10313333, 'name': "d'Amiens", 'total': 1}
# {'_id': 10313297, 'name': "d'Anjou", 'total': 1}
# {'_id': 10313287, 'name': 'de Chur', 'total': 1}
# {'_id': 10313283, 'name': 'de Luzern', 'total': 1}
# {'_id': 10313278, 'name': "d'Orléans", 'total': 1}
# {'_id': 10317085, 'name': 'de Bihar', 'total': 1}
# {'_id': 10315981, 'name': 'of Sussex', 'total': 1}
# {'_id': 10313241, 'name': 'de Dijon', 'total': 1}
# {'_id': 10314741, 'name': 'Westfrieslandid', 'total': 1}
# {'_id': 10317318, 'name': 'Barton', 'total': 1}
# {'_id': 10319184, 'name': 'kohta Trakai', 'total': 1}
# {'_id': 10320513, 'name': 'iš Chernigov', 'total': 1}
# {'_id': 100066, 'name': 'of Shrewsbury', 'total': 1}
# {'_id': 10318434, 'name': 'of Faversham', 'total': 1}
# {'_id': 10312913, 'name': 'de Gowrie', 'total': 1}
# {'_id': 10317177, 'name': 'de Saone', 'total': 1}
# {'_id': 10317385, 'name': 'de Narbonne', 'total': 1}
# {'_id': 10317105, 'name': 'de Villeneuve', 'total': 1}
# {'_id': 10312839, 'name': 'de Tír Chonaill', 'total': 1}
# {'_id': 10314067, 'name': 'de Litomerice', 'total': 1}
# {'_id': 10314725, 'name': 'of Korinthos', 'total': 1}
# {'_id': 10321088, 'name': 'of Constantinople', 'total': 1}
# {'_id': 10312659, 'name': 'of Krakow', 'total': 1}
# {'_id': 10316903, 'name': 'of Árta', 'total': 1}
# {'_id': 10316039, 'name': 'of Ulster', 'total': 1}
# {'_id': 10316020, 'name': 'de Évreux', 'total': 1}
# {'_id': 10312504, 'name': "d'Armagnac", 'total': 1}
# {'_id': 10325061, 'name': 'de Namur', 'total': 1}
# {'_id': 10312461, 'name': "d'Osnabrück", 'total': 1}
# {'_id': 10312380, 'name': "d'Armagnac", 'total': 1}
# {'_id': 10312324, 'name': "d'Amiens", 'total': 1}
# {'_id': 10318199, 'name': 'de Gwynedd', 'total': 1}
# {'_id': 10312295, 'name': 'of Derby', 'total': 1}
# {'_id': 10317033, 'name': 'de Innse Gall', 'total': 1}
# {'_id': 10316923, 'name': 'de Argyll', 'total': 1}
# {'_id': 10318513, 'name': 'of Cumberland', 'total': 1}
# {'_id': 10317564, 'name': 'de Benserade', 'total': 1}
# {'_id': 10312120, 'name': 'de Gent', 'total': 1}
# {'_id': 10313820, 'name': 'of Suffolk', 'total': 1}
# {'_id': 10312026, 'name': 'von Poitiers', 'total': 1}
# {'_id': 10313725, 'name': "d'Amiens", 'total': 1}
# {'_id': 10311827, 'name': 'de Thouars', 'total': 1}
# {'_id': 10322767, 'name': 'of Schwaben', 'total': 1}
# {'_id': 10311668, 'name': 'de Bourges', 'total': 1}
# {'_id': 10319374, 'name': 'de Provence', 'total': 1}
# {'_id': 10317661, 'name': 'of Bedford', 'total': 1}
# {'_id': 10311287, 'name': 'de Argyll', 'total': 1}
# {'_id': 10311202, 'name': 'de Reims', 'total': 1}
# {'_id': 10316200, 'name': 'de Metz', 'total': 1}
# {'_id': 10316921, 'name': 'de Warwick', 'total': 1}
# {'_id': 10311200, 'name': 'de Bourges', 'total': 1}
# {'_id': 20065, 'name': 'Gavalas', 'total': 1}
# {'_id': 10314022, 'name': 'de Boulogne', 'total': 1}
# {'_id': 10322634, 'name': 'de Sens', 'total': 1}
# {'_id': 10311037, 'name': 'de Argyll', 'total': 1}
# {'_id': 10310917, 'name': 'de Taranto', 'total': 1}
# {'_id': 5025, 'name': 'de Mostuejouls', 'total': 1}
# {'_id': 10316732, 'name': 'de Demetrias', 'total': 1}
# {'_id': 10325143, 'name': 'de Mzab', 'total': 1}
# {'_id': 10314225, 'name': 'de Compiègne', 'total': 1}
# {'_id': 10311254, 'name': 'de Bourges', 'total': 1}
# {'_id': 10322093, 'name': 'de Szekelyföld', 'total': 1}
# {'_id': 10310596, 'name': 'de Argyll', 'total': 1}
# {'_id': 10310495, 'name': 'de Argyll', 'total': 1}
# {'_id': 10310868, 'name': 'de Fife', 'total': 1}
# {'_id': 10324224, 'name': 'de Hainaut', 'total': 1}
# {'_id': 10310310, 'name': 'de Westfriesland', 'total': 1}
# {'_id': 5105, 'name': 'de Gontaut', 'total': 1}
# {'_id': 10310217, 'name': 'de Vermandois', 'total': 1}
# {'_id': 21022, 'name': 'Ogonczyk', 'total': 1}
# {'_id': 10310044, 'name': 'de Périgord', 'total': 1}
# {'_id': 10321036, 'name': 'Gedgaudis', 'total': 1}
# {'_id': 10314501, 'name': 'of Dorset', 'total': 1}
# {'_id': 10309973, 'name': 'de Meissen', 'total': 1}
# {'_id': 10309836, 'name': 'de Hesbaie', 'total': 1}
# {'_id': 10314666, 'name': 'of Korinthos', 'total': 1}
# {'_id': 10315667, 'name': 'de Fife', 'total': 1}
# {'_id': 10320610, 'name': 'de Sjælland', 'total': 1}
# {'_id': 10309750, 'name': 'de Liege', 'total': 1}
# {'_id': 10316459, 'name': 'de Demetrias', 'total': 1}
# {'_id': 10309703, 'name': 'of Wiltshire', 'total': 1}
# {'_id': 10309558, 'name': 'Uib', 'total': 1}
# {'_id': 10324792, 'name': 'de Scania', 'total': 1}
# {'_id': 10311352, 'name': 'de Thouars', 'total': 1}
# {'_id': 10309139, 'name': 'de Chur', 'total': 1}
# {'_id': 10312546, 'name': 'de Bourges', 'total': 1}
# {'_id': 743, 'name': 'Capet', 'total': 1}
# {'_id': 10322833, 'name': "d'Ancona", 'total': 1}
# {'_id': 10310067, 'name': 'de Lyon', 'total': 1}
# {'_id': 10313842, 'name': 'de Boulogne', 'total': 1}
# {'_id': 10322209, 'name': 'de Jylland', 'total': 1}
# {'_id': 10310032, 'name': "d'Amiens", 'total': 1}
# {'_id': 295, 'name': "de l'Aigle", 'total': 1}
# {'_id': 10320533, 'name': 'de Genoa', 'total': 1}
# {'_id': 10308761, 'name': 'de Bourges', 'total': 1}
# {'_id': 7266, 'name': 'de Brisebarre', 'total': 1}
# {'_id': 10308714, 'name': 'de Atholl', 'total': 1}
# {'_id': 10316962, 'name': 'de Rom', 'total': 1}
# {'_id': 10308586, 'name': 'of Ternyllwg', 'total': 1}
# {'_id': 10310820, 'name': 'de Périgord', 'total': 1}
# {'_id': 10308437, 'name': 'de Genève', 'total': 1}
# {'_id': 10308346, 'name': 'of Chester', 'total': 1}
# {'_id': 10309838, 'name': 'de Meissen', 'total': 1}
# {'_id': 10308320, 'name': 'de Ploni', 'total': 1}
# {'_id': 10318880, 'name': 'of Ulster', 'total': 1}
# {'_id': 10308274, 'name': 'of Chester', 'total': 1}
# {'_id': 10316609, 'name': 'of Árta', 'total': 1}
# {'_id': 10319832, 'name': 'de Piemonte', 'total': 1}
# {'_id': 10307309, 'name': 'Kubasarid', 'total': 1}
# {'_id': 10317370, 'name': 'de Provence', 'total': 1}
# {'_id': 10317247, 'name': 'de Bihar', 'total': 1}
# {'_id': 10307433, 'name': 'of Kiel', 'total': 1}
# {'_id': 10307907, 'name': 'de Connachta', 'total': 1}
# {'_id': 10318619, 'name': 'de Taranto', 'total': 1}
# {'_id': 10310272, 'name': 'de Bourges', 'total': 1}
# {'_id': 10316111, 'name': 'of Middlesex', 'total': 1}
# {'_id': 10296428, 'name': 'Bilge', 'total': 1}
# {'_id': 746, 'name': 'Fergant', 'total': 1}
# {'_id': 10316023, 'name': 'de Vermandois', 'total': 1}
# {'_id': 10316339, 'name': 'of Wessex', 'total': 1}
# {'_id': 10319071, 'name': "d'Armagnac", 'total': 1}
# {'_id': 10308112, 'name': 'van Périgord', 'total': 1}
# {'_id': 10316235, 'name': 'de Chur', 'total': 1}
# {'_id': 10306259, 'name': 'de Redon', 'total': 1}
# {'_id': 10313470, 'name': 'de Chinon', 'total': 1}
# {'_id': 10320913, 'name': 'de Vivarais', 'total': 1}
# {'_id': 10307133, 'name': 'of Essex', 'total': 1}
# {'_id': 10305916, 'name': 'of Oxford', 'total': 1}
# {'_id': 10309025, 'name': 'de Forres', 'total': 1}
# {'_id': 10305801, 'name': 'af Jämtland', 'total': 1}
# {'_id': 11109, 'name': 'Feofilaktovich', 'total': 1}
# {'_id': 10322519, 'name': 'de Cill Dara', 'total': 1}
# {'_id': 10314742, 'name': 'de Mecklenburg', 'total': 1}
# {'_id': 10306558, 'name': 'of Westmorland', 'total': 1}
# {'_id': 10310148, 'name': 'de Besancon', 'total': 1}
# {'_id': 10323488, 'name': 'of Palenke', 'total': 1}
# {'_id': 10311023, 'name': 'de Piombino', 'total': 1}
# {'_id': 10316937, 'name': 'of Leicester', 'total': 1}
# {'_id': 10315979, 'name': 'of Suffolk', 'total': 1}
# {'_id': 140, 'name': 'Brahe', 'total': 1}
# {'_id': 10305727, 'name': 'of Bedford', 'total': 1}
# {'_id': 10312765, 'name': 'de Meissen', 'total': 1}
# {'_id': 10322918, 'name': "d'Orvieto", 'total': 1}
# {'_id': 10305792, 'name': 'de Tír Chonaill', 'total': 1}
# {'_id': 10317213, 'name': 'de Tuadhmhumhain', 'total': 1}
# {'_id': 10317107, 'name': 'de Lubusz', 'total': 1}
# {'_id': 10316774, 'name': 'de Vermandois', 'total': 1}
# {'_id': 10309701, 'name': 'de Orkney', 'total': 1}
# {'_id': 10308826, 'name': 'de Tír Eoghain', 'total': 1}
# {'_id': 10304360, 'name': 'de Paris', 'total': 1}
# {'_id': 10311817, 'name': 'de Innse Gall', 'total': 1}
# {'_id': 10310086, 'name': 'of Oxford', 'total': 1}
# {'_id': 10304353, 'name': 'de Tuadhmhumhain', 'total': 1}
# {'_id': 10316242, 'name': 'de Innse Gall', 'total': 1}
# {'_id': 10323236, 'name': 'de Mahdia', 'total': 1}
# {'_id': 10304292, 'name': 'de Deasmhumhain', 'total': 1}
# {'_id': 9207, 'name': 'Ua Maíl Ruanaid', 'total': 1}
# {'_id': 10308528, 'name': 'de Narbonne', 'total': 1}
# {'_id': 10303987, 'name': 'de Gwynedd', 'total': 1}
# {'_id': 10303870, 'name': 'of Gwynedd', 'total': 1}
# {'_id': 10317331, 'name': "d'Armagnac", 'total': 1}
# {'_id': 10308448, 'name': 'Richfriding', 'total': 1}
# {'_id': 10304974, 'name': 'Clwyd', 'total': 1}
# {'_id': 10304375, 'name': 'de Oca', 'total': 1}
# {'_id': 100374, 'name': 'Goštautas', 'total': 1}
# {'_id': 10310627, 'name': 'Strathearn', 'total': 1}
# {'_id': 10312466, 'name': 'of Dorset', 'total': 1}
# {'_id': 10314408, 'name': 'de Saintonge', 'total': 1}
# {'_id': 10313896, 'name': 'Giselbertling', 'total': 1}
# {'_id': 10296168, 'name': 'de Lyon', 'total': 1}
# {'_id': 10304291, 'name': 'Ua Cruadláich', 'total': 1}
# {'_id': 10307017, 'name': 'of Westmorland', 'total': 1}
# {'_id': 10313144, 'name': 'Bontemps', 'total': 1}
# {'_id': 10308293, 'name': 'of Ternyllwg', 'total': 1}
# {'_id': 10308288, 'name': 'van Périgord', 'total': 1}
# {'_id': 10314526, 'name': 'of Korinthos', 'total': 1}
# {'_id': 10320134, 'name': 'of Wessex', 'total': 1}
# {'_id': 10316825, 'name': 'of Ulster', 'total': 1}
# {'_id': 10316842, 'name': 'de Bihar', 'total': 1}
# {'_id': 10314712, 'name': 'des Roches', 'total': 1}
# {'_id': 10313372, 'name': 'Shirgugetu', 'total': 1}
# {'_id': 10313868, 'name': 'of Lincoln', 'total': 1}
# {'_id': 10312684, 'name': 'de Thouars', 'total': 1}
# {'_id': 10304221, 'name': 'Ua Fergail', 'total': 1}
# {'_id': 10316830, 'name': 'de Feher', 'total': 1}
# {'_id': 10302585, 'name': 'de Glamorgan', 'total': 1}
# {'_id': 10310767, 'name': 'Uib', 'total': 1}
# {'_id': 10314747, 'name': 'de Venaissin', 'total': 1}
# {'_id': 1042, 'name': 'Vasa', 'total': 1}
# {'_id': 10317731, 'name': 'Xiphias', 'total': 1}
# {'_id': 10322925, 'name': "d'Alsace", 'total': 1}
# {'_id': 10307430, 'name': 'de Bourbon', 'total': 1}
# {'_id': 10315943, 'name': "d'Yperen", 'total': 1}
# {'_id': 10322950, 'name': 'iš Orsha', 'total': 1}
# {'_id': 10317446, 'name': 'de Grandson', 'total': 1}
# {'_id': 10324829, 'name': 'de Mzab', 'total': 1}
# {'_id': 10311745, 'name': 'de Bar', 'total': 1}
# {'_id': 10317081, 'name': 'de Rom', 'total': 1}
# {'_id': 10314500, 'name': "d'Amiens", 'total': 1}
# {'_id': 4002, 'name': 'Despencer', 'total': 1}
# {'_id': 10324483, 'name': 'de Gent', 'total': 1}
# {'_id': 10308239, 'name': 'de Tír Eoghain', 'total': 1}
# {'_id': 10312056, 'name': "d'Agder", 'total': 1}
# {'_id': 10323225, 'name': 'Sulayman', 'total': 1}
# {'_id': 214011, 'name': 'Naimanid', 'total': 1}
# {'_id': 10321347, 'name': "d'Uppland", 'total': 1}
# {'_id': 10309940, 'name': 'of Shropshire', 'total': 1}
# {'_id': 10314257, 'name': 'de Jülich', 'total': 1}
# {'_id': 10314407, 'name': 'de Fiennes', 'total': 1}
# {'_id': 10311222, 'name': 'de Cumberland', 'total': 1}
# {'_id': 10318970, 'name': 'of Constantinople', 'total': 1}
# {'_id': 10306839, 'name': 'de Connachta', 'total': 1}
# {'_id': 9570, 'name': 'Khunzakhal', 'total': 1}
# {'_id': 10316315, 'name': 'de Évreux', 'total': 1}
# {'_id': 10310840, 'name': 'de Innse Gall', 'total': 1}
# {'_id': 10315329, 'name': 'Çatn', 'total': 1}
# {'_id': 10309476, 'name': 'de Teviotdale', 'total': 1}
# {'_id': 10310885, 'name': 'de Périgord', 'total': 1}
# {'_id': 5056, 'name': 'de Mayenne', 'total': 1}
# {'_id': 10309936, 'name': 'de Bourges', 'total': 1}
# {'_id': 10305971, 'name': 'of Northampton', 'total': 1}
# {'_id': 101438, 'name': 'Palaiologos Komnenos', 'total': 1}
# {'_id': 10308015, 'name': 'de Rosello', 'total': 1}
# {'_id': 10323355, 'name': 'de St Satur', 'total': 1}
# {'_id': 10314072, 'name': 'de Dohna', 'total': 1}
# {'_id': 5069, 'name': 'de Garlande', 'total': 1}
# {'_id': 10314270, 'name': 'Kundaçiqid', 'total': 1}
# {'_id': 10318131, 'name': 'de Provence', 'total': 1}
# {'_id': 10300018, 'name': 'Wechtaringi', 'total': 1}
# {'_id': 10316343, 'name': 'of Sussex', 'total': 1}
# {'_id': 10320236, 'name': 'Bahirid', 'total': 1}
# {'_id': 10309887, 'name': 'von Thouars', 'total': 1}
# {'_id': 10320352, 'name': 'de Shetland', 'total': 1}
# {'_id': 1044110, 'name': 'Hessing', 'total': 1}
# {'_id': 10304222, 'name': 'de Deasmhumhain', 'total': 1}
# {'_id': 10314505, 'name': 'de Borkum', 'total': 1}
# {'_id': 1047022, 'name': 'Eadwulfing', 'total': 1}
# {'_id': 10303118, 'name': 'of Ulster', 'total': 1}
# {'_id': 10311333, 'name': 'de Chalons', 'total': 1}
# {'_id': 10318967, 'name': 'de Léon', 'total': 1}
# {'_id': 10308877, 'name': 'Unwanid', 'total': 1}
# {'_id': 199, 'name': 'Ua Néill Noígiallaich', 'total': 1}
# {'_id': 10309569, 'name': 'de Sjælland', 'total': 1}
# {'_id': 10308051, 'name': 'van Périgord', 'total': 1}

# %% [markdown]
# # Descent from Muhammad Aleppo

# %% [markdown]
# In the next notebook Muhammad Aleppo (died 994) will show up with the record number of children. They won't aid him in securing a legacy however as he has only 3435 descendents in total by the end of the game. As many are illegitimate this may have made it difficult to find spouses and indeed there is a high number of murders, 326 of them are killed. Both the Sami and the Muradid dynasties will rule Persia but there are no other big name title holding dynasties in the top 10 that are descended from him.

# %%
pipeline = [
    {
        "$match" : {"_id" : 629398}
    },      
    {
        "$graphLookup": 
        {
            "from": "characters",
            "startWith": "$_id",
            "connectFromField": "_id",
            "connectToField": "rparents",
            "as": "descendent"
        }},
    {"$project" : { "bn" : 1, "descendents" : {"$size" : "$descendent"} }    }
]

# %%
for karl in characters.aggregate(pipeline):
    print(karl)
# Out:
# {'_id': 629398, 'bn': 'Muhammad', 'descendents': 3435}

# %% [markdown]
# ## Dynasties Descended from Muhammad Aleppo

# %%
pipeline = [
    {
        "$match" : {"_id" : 629398}
    },      
    {
        "$graphLookup": 
        {
            "from": "characters",
            "startWith": "$_id",
            "connectFromField": "_id",
            "connectToField": "rparents",
            "as": "descendent",
            "depthField": "generation"
        }},    
    {"$unwind" : "$descendent" },
    {"$lookup" :
     {
            "from" : "dynasties",
            "localField" : "descendent.dnt",
            "foreignField" : "_id",
            "as" : "descendent_dyn"
        }
    },
    {"$unwind" : "$descendent_dyn" },
    {
        "$group":
        {
            "_id" : "$descendent_dyn.name",
            "total" : {"$sum" : 1}
        }
    },
    {"$sort" : { "total" : -1 } },
    {"$limit" : 10}
]

# %%
for karl in characters.aggregate(pipeline):
    print(karl)
# Out:
# {'_id': 'Amrubid', 'total': 396}
# {'_id': 'Sami', 'total': 299}
# {'_id': 'Khaireddin', 'total': 152}
# {'_id': 'Aligoodarzid', 'total': 139}
# {'_id': 'Muradid', 'total': 132}
# {'_id': 'Ali', 'total': 120}
# {'_id': 'Karen', 'total': 112}
# {'_id': 'Tatikid', 'total': 111}
# {'_id': 'Sajrid', 'total': 103}
# {'_id': 'Shujahid', 'total': 97}

# %% [markdown]
# ## Descendents who were Killed

# %%
pipeline = [   
    {
    
    "$match" : { "_id" : 629398}
    },
    {
    
      "$graphLookup": {
      "from": "characters",
      "startWith": "$_id",
      "connectFromField": "_id",
      "connectToField": "rparents",
      "as": "descendent",
      "depthField": "generation"
   }},
    {"$unwind" : "$descendent"},
    {"$sort" : { "descendent.b_d": -1 }},
    {"$match" : {"descendent.killer" : {"$exists" : True}}},
    #{"$project" : {"_id" : 0, "descendent" : 1}}
    {"$group" : {"_id" : None, "total" : {"$sum" : 1}}}
]

# %%
for karl in characters.aggregate(pipeline):
    print(karl)
# Out:
# {'_id': None, 'total': 326}
